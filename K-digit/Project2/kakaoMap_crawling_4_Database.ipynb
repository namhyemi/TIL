# %%
# 2021.08.12
# kakaoMap_crawling_2.ipynb 수정버전
# 수정사항 : 지역구 맛집 검색 및 CSV 저장 자동화 수정, 데이터 변수 종류 및 오류 수정(리뷰 코드, 가게 코드 추가, 비어있는 값은 None값으로 통일)
# 추가사항 : 데이터 저장 방식 변경(클래스 추가)

# 문제점 : DB 연결

# %%
import os

from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup

import pymysql as my
import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')

##########################################################################
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')


driver = webdriver.Chrome('./webdriver/chromedriver')



##### 가게 정보를 담는 클레스
class STORE_Info:
    place_code = ''
    place_name = ''
    place_address = ''
    place_local  = ''
    place_category  = ''
    
    # 생성자
    def __init__(self, store_code = None, place_name = None, place_address = None, place_local = None, place_category = None):
        self.store_code = store_code
        self.place_name =  place_name
        self.place_address = place_address
        self.place_local  = place_local
        self.place_category  = place_category
        
    # 데이터 확인
    def data_check(self):
        print('가게코드 : %s, 가계명 : %s, 주소 : %s, 지역 : %s, 종류 : %s' %(self.store_code, self.place_name, self.place_address, 
                                                                 self.place_local, self.place_category))
        
        
##### 리뷰 정보를 담는 클레스
class REVIEW_Info:
    review_code = ''
    place_code = ''
    comment = ''
    rating = ''
    user_id  = ''
    timestamp  = ''

    
    # 생성자
    def __init__(self, review_code=None, store_code =None ,comment = None, rating = None, user_id = None, timestamp = None):
        self.review_code = review_code
        self.store_code = store_code
        self.comment =  comment
        self.rating = rating
        self.user_id  = user_id
        self.timestamp  = timestamp 

    # 데이터 확인
    def data_check(self):
        print('리뷰코드 : %s, 가게코드 : %s, ID : %s, 리뷰 : %s, 평점 : %s, 날짜 : %s' %(self.review_code, self.store_code, 
                                                                           self.user_id,self.comment, self.rating, self.timestamp))

        
### DB 다루는 클래스
class DBHelper:
    '''
    맴버변수 : 커넥션 
    '''
    conn = None
    '''
    생성자
    '''
    def __init__(self):
        self.db_init()
    '''
    맴버 함수
    '''
    def db_init(self):
        self.conn = my.connect(
                        host='3.34.111.86',
                        user='root',
                        password='123456',
                        db='test',
                        charset='utf8mb4',
                        cursorclass=my.cursors.DictCursor
        )


        


    def db_free(self):
        if self.conn:
            self.conn.close()
            
    def db_selectKeyword_STORE(self):
        # 커서 오픈
        # with => 닫기를 처리를 자동으로 처리해준다 => I/O 많이 사용
        rows = None
        with self.conn.cursor() as cursor:
            sql  = "select * from STORE;"
            cursor.execute(sql)
            rows = cursor.fetchall()
        return rows           
    
    def db_selectKeyword_REVIEW(self):
        # 커서 오픈
        # with => 닫기를 처리를 자동으로 처리해준다 => I/O 많이 사용
        rows = None
        with self.conn.cursor() as cursor:
            sql  = "select * from REVIEW;"
            cursor.execute(sql)
            rows = cursor.fetchall()
        return rows      

    def db_insertCrawlingData_STORE(self, store_code, place_name, place_address, place_local, place_category):
        with self.conn.cursor() as cursor:
            sql = "INSERT INTO STORE (STORE_CODE, STORE_NAME, ADDRESS, LOCAL_CODE, CATRGORY_CODE) VALUES( %s, %s, %s, %s, %s )"
            cursor.execute(sql, (store_code, place_name, place_address, place_local, place_category)) 
        self.conn.commit()
        
    
    def db_insertCrawlingData_REVIEW(self, review_code, store_code, user_id, rating, comment, timestamp):
        with self.conn.cursor() as cursor:
            sql = "INSERT INTO REVIEW (REVIEW_CODE, STORE_CODE,  USER_ID, SCORE, REVIEW, UPLOAD_DATE) VALUES( %s, %s, %s, %s, %s, %s )"
            cursor.execute(sql, (review_code, store_code, user_id, rating, comment, timestamp))
        self.conn.commit()
    


rating_df = pd.DataFrame()
restaurant_df = pd.DataFrame()
db = DBHelper()


        
        
##### 메인 코드 #####
def main():
    global driver, load_wb, review_num, local, number_local, number_store

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

     #### 검색할 목록
#     place_infos = ['종로구 맛집', '중구 맛집', ' 용산구 맛집', '성동구 맛집', '광진구 맛집', '동대문구 맛집', '중랑구 맛집', '성북구 맛집', '강북구 맛집']
#     place_infos = ['도봉구 맛집', '노원구 맛집', '은평구 맛집', '서대문구 맛집', '마포구 맛집', '양천구 맛집', '강서구 맛집','구로구 맛집']
#     place_infos = ['금천구 맛집', '영등포구 맛집', '동작구 맛집', '관악구 맛집', '서초구 맛집', '강남구 맛집', '송파구 맛집','강동구 맛집']

    place_infos = ['금천구 맛집']

    for i, place in enumerate(place_infos):
        print("##### {0} : {1}".format(i,place))
        number_local = 0
        number_store = 0
        
        local = read_local_code(place)
        search(place, local)
        create_csv_file(place)

    driver.quit()
    print("finish")

#     db.db_selectKeyword_STORE()
#     db.db_selectKeyword_REVIEW()
    


#### 가게 정보 찾기
def search(place, local):
    """
    검색한 페이지 음식점 정보 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    """
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER) # 더보기
    
    xPath = '//*[@id="info.search.page.no1"]'
    driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER) # 첫번째 페이지로 이동
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem') # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, local, place_lists)

    # 전체 페이지
    while True:
        try:
#            2~ 5페이지 읽기
            for i in range(2, 6):
                # 페이지 넘기기
                xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
                driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
                sleep(1)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                place_lists = soup.select('.placelist > .PlaceItem') # 장소 목록 list
                
                crawling(place, local, place_lists)
                
                # 다음 페이지 넘기기
                if i==5:
                    driver.find_element_by_xpath('//*[@id="info.search.page.next"]').send_keys(Keys.ENTER)

        except ElementNotInteractableException:
            print('end page')
            break
            
        finally:
            search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')
            search_area.clear()


#### 가게 정보 크롤링 하기
def crawling(place, local, place_lists):
    """
    페이지 목록을 받아서 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    :param place_lists : 페이지 내에 있는 음식점 목록
    """
    
    global restaurant_df, number_store, db

    while_flag = False
    for i, place in enumerate(place_lists):
        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address
        place_local = place.select('.info_item > .addr > .lot_number')[0].text
        place_category = place.select('.head_item > .subcategory')[0].text
        place_detail = place.select('.info_item > .contact> .moreview')[0].get('href') # place detail
        
        number_store += 1
        store_code = str('STORE_') + local + str(number_store).zfill(4) # 가게 코드 (ex. STORE_GC0001)
        
        store_Info = STORE_Info(store_code, place_name, place_address, place_local, place_category)
        store_Info.data_check()
        
        
        #### DataFrame 저장 ####
        row = {'store_code': store_code, "ItemID":place_name, "address": place_address, "local" : place_local, "category": place_category}
        row = pd.DataFrame(row, index=[1])
        restaurant_df = restaurant_df.append(row, ignore_index=True)
        
        
        #### 데이터 베이스 저장 #####
        db.db_insertCrawlingData_STORE(store_code, place_name, place_address, place_local, place_category)
        

        
        #### 리뷰 크롤링 ####
        driver.execute_script('window.open("about:blank", "_blank");')
        driver.switch_to.window(driver.window_handles[-1])
        driver.get(place_detail) # 상세정보 탭으로 변환
        sleep(1)
        
        print('####', place_name)
        sleep(1)
        # 첫 페이지
        extract_review(place_name, store_code , local) # 리뷰 추출

        # 2-5 페이지
        idx = 3
        try:
            page_num = len(driver.find_elements_by_class_name('link_page')) # 페이지 수 찾기
            for i in range(page_num-1):
                # css selector를 이용해 페이지 버튼 누르기
                driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name, store_code, local)
                idx += 1
            driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 5페이지가 넘는 경우 다음 버튼 누르기
            
            sleep(1)
            extract_review(place_name, store_code, local) # 리뷰 추출
            
            # 그 이후 페이지
            while True:
                idx = 4
                page_num = len(driver.find_elements_by_class_name('link_page')) #페이지 수 찾기
                for i in range(page_num-1):
                    driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                    sleep(1)
                    extract_review(place_name, store_code, local)
                    idx += 1
                driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 10페이지 이상으로 넘어가기 위한 다음 버튼 클릭
                sleep(1)
                extract_review(place_name, store_code, local) # 리뷰 추출            
            
        except (NoSuchElementException, ElementNotInteractableException):
            print("no review in crawling")

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환


#### 리뷰 크롤링 하기
def extract_review(place_name, store_code, local):
    """
    리뷰 크롤링 하는 함수
    :param place_place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    """
    
    global driver, rating_df, number_local, db

    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')

    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        for i, review in enumerate(review_lists):
            comment = review.select('.txt_comment > span') # 리뷰
            rating = review.select('.grade_star > em') # 별점
            user_id = review.select('.append_item > a[data-userid]') # user-id 정보 html 파싱
#             user_name = review.select('.append_item > a[data-username]') # user-name 정보 html 파싱
            timestamp = review.select(' div > span.time_write') #시간정보
            number_local += 1
                  

            #### 리뷰 클래스에 정보 담기 ####
            review_info = REVIEW_Info()
            
            review_info.review_code = local + str(number_local).zfill(6) # 리뷰 코드 (ex. GC000001)
            review_info.store_code = store_code
            

            if len(comment) != 0: # 리뷰
                if comment[0].text:
                    review_info.comment = comment[0].text 
                else:
                    review_info.comment = None
            else:
                review_info.comment = None
            
            if len(rating) != 0: # 별점
                review_info.rating = rating[0].text.replace('점', '')
            else:
                review_info.rating = None

            if(len(user_id) != 0): # 유저id
                if(user_id[0].get('data-userid')):
                    review_info.user_id = user_id[0].get('data-userid')
                else:
                    review_info.user_id = None
            else:
                review_info.user_id = None

            if len(timestamp) != 0: # 시간
                review_info.timestamp = timestamp[0].text
            else:
                review_info.timestamp = None
                
            review_info.data_check()
            
            
            
            #### DB 에 정보 담기 ####
            db.db_insertCrawlingData_REVIEW(review_info.review_code, review_info.store_code, review_info.user_id, review_info.rating, review_info.comment, review_info.timestamp)
            
            
            #### DataFrame 에 정보 담기 ####
            try:
                row = {"review_code" : review_info.review_code, "place_code": review_info.store_code, "ItemID": place_name, 
                       "UserID":review_info.user_id, "review" : review_info.comment,
                       "Rating":review_info.rating, "Timestamp":review_info.timestamp}
                row = pd.DataFrame(row, index=[i])
                rating_df = rating_df.append(row, ignore_index=True)
            
            except:
                row = {"review_code" : review_info.review_code, "place_code": store_code, "ItemID":place_name, 
                       "UserID": None, "review" : None, "Rating":None, "Timestamp":review_info.timestamp}
                row = pd.DataFrame(row, index=[i])
                rating_df = rating_df.append(row, ignore_index=True)
                
    else:
        print('no review in extract')
        ret = False

    return ret



#### CSV 파일로 저장 ####
def create_csv_file(place):
    global rating_df, restaurant_df

    rating_df.to_csv('%s_rating_df.csv' %place)
    rating_df.to_csv('%s_rating_df_ko.csv' %place, sep=',', na_rep='NaN', encoding='utf-8-sig')
        
    restaurant_df.to_csv('%s_restaurant_df.csv'  %place)
    restaurant_df.to_csv('%s_restaurant_df_ko.csv'  %place, sep=',', na_rep='NaN', encoding='utf-8-sig')
    
    

#### 지역구 코드 뽑아오기 ####
def read_local_code(place):
    
    local_place = place.split(' ')[0]

    local_code = pd.read_csv('local_code.csv', encoding='utf-8', index_col = 'local')
    return local_code.at[local_place, 'local_code']

#### 메인 ####
if __name__ == "__main__":
    main()
# Out:
# ##### 0 : 금천구 맛집
# 가게코드 : STORE_GC0001, 가계명 : 광고만두라, 주소 : 서울 금천구 시흥대로 97 BB53호, 지역 : (지번) 시흥동 984, 종류 : 한식
# #### 광고만두라
# 리뷰코드 : GC000001, 가게코드 : STORE_GC0001, ID : tghmif, 리뷰 : 드뎌열은듯? 전화가네 , 평점 : 4, 날짜 : 2021.08.12.
# 리뷰코드 : GC000002, 가게코드 : STORE_GC0001, ID : 1m4d6dq, 리뷰 : ㅜㅜ 방문했는데 아직 안열었네요ㅠㅠ 맛보고싶었는데ㅜ, 평점 : 4, 날짜 : 2021.07.22.
# 리뷰코드 : GC000003, 가게코드 : STORE_GC0001, ID : ssnvg6, 리뷰 : 주변 상인들 말로는 6월달부터 영업하신다고 전달받았는데 아직까지도 영업하지 않으심.. 5월 중순부터 3번은 찾아가본 듯 한데 언제쯤 먹어볼 수 있을지…, 평점 : 3, 날짜 : 2021.06.16.
# 리뷰코드 : GC000004, 가게코드 : STORE_GC0001, ID : 8uv76b, 리뷰 : 못먹어봐서 ㅠ 6월10일 어제 갔는데 개인 사정으로 당분간 쉰다고 적혀 있었어요 ㅠ 언제까지 쉬는지는 잘 모름 안적혀 있었음., 평점 : 3, 날짜 : 2021.06.11.
# 리뷰코드 : GC000005, 가게코드 : STORE_GC0001, ID : n1gc3v, 리뷰 : 만두로는 최고, 평점 : 5, 날짜 : 2021.05.19.
# 리뷰코드 : GC000006, 가게코드 : STORE_GC0001, ID : 11b08qg, 리뷰 : 금천구 맛집 찾다가 들렸는데 김치만두 최고네요~~ 속도 꽉차고 3개 먹으니 너무 배불르네요, 평점 : 5, 날짜 : 2020.11.27.
# 리뷰코드 : GC000007, 가게코드 : STORE_GC0001, ID : 1bvq504, 리뷰 : None, 평점 : 5, 날짜 : 2020.10.22.
# 리뷰코드 : GC000008, 가게코드 : STORE_GC0001, ID : 1bpbrba, 리뷰 : 우연히 예전 방송에 나온거 보고 갑자기 먹고 싶어서 방문했는데 동네 만두집하고 큰 차이는 모르겠어요 ㅠㅠ, 평점 : 3, 날짜 : 2020.09.05.
# 리뷰코드 : GC000009, 가게코드 : STORE_GC0001, ID : bfrqdf, 리뷰 : 통만두 맛집, 평점 : 5, 날짜 : 2020.08.21.
# 리뷰코드 : GC000010, 가게코드 : STORE_GC0001, ID : ec1ve9, 리뷰 : 만두 맛집이라고해서 따라가서 먹은 집. 김치만두만 먹어서 김치만두국 먹었는데, 김치만두는 정말 별로였음.., 평점 : 2, 날짜 : 2020.08.09.
# 리뷰코드 : GC000011, 가게코드 : STORE_GC0001, ID : 1b1ftqu, 리뷰 : 맛은 그럭저럭 평범하고 불친절해요, 평점 : 2, 날짜 : 2020.08.07.
# 리뷰코드 : GC000012, 가게코드 : STORE_GC0001, ID : csgujd, 리뷰 : 공구단지내 종사자와 방문객들의 오랜 사랑을 받고 있는 집으로 속이 비치는 육향가득 통만두가 맛이 좋다., 평점 : 4, 날짜 : 2020.04.25.
# 리뷰코드 : GC000013, 가게코드 : STORE_GC0001, ID : 9jrrcp, 리뷰 : 통만두는 맛있지만 김치만두는 최악.만두국도 맛없고 김치만두가 맛있어야 진짜 잘하는집인데, 일반 시장통 만두집에 비해 별차이없는 흔한맛에 공구상가 월세가 비쌀리도 없는데 모든 메뉴가 비싼편이고 만두는 3500원, 만두국은 6천원 받아야 적당한 가격임. , 평점 : 1, 날짜 : 2020.02.21.
# 리뷰코드 : GC000014, 가게코드 : STORE_GC0001, ID : pn0fj5, 리뷰 : 김치통만두랑 만둣국 시켰음 매장안은 깔끔하고 만두도 금방 나옴 매장분들 모두 정말 친절하심 김치만두는 평소에 비려서 많이 안좋아하는데 굉장히 부드럽고 공장만두보다 간이 삼삼해서 좋음 만둣국은 사골국물에 물만두가 나오는데  정말정말 부드러워서 후루룩 마셔먹을수 있음 만족만족 대만족 재방문 의사 있음, 평점 : 5, 날짜 : 2020.01.15.
# 리뷰코드 : GC000015, 가게코드 : STORE_GC0001, ID : 10mgd53, 리뷰 : 만두피가 얇고 부드러워요. 만두 속도 잘 다져져있어서 피랑 굉장히 잘어울려요. 만둣국이랑 김치만두 먹었는데 둘다 최고!! 만둣국은 사골국물이 진하고 김치만두는 속이 비리지않고 김치맛이 적당히 나서 좋았어요ㅠㅠ 가격도 저렴하고 서비스도 훌륭해요. 만둣국 시키면 밥을 주시는데 리필 가능한 듯 해요!! 많이들 가셨으면 좋겠습니다:-D, 평점 : 5, 날짜 : 2020.01.15.
# 리뷰코드 : GC000016, 가게코드 : STORE_GC0001, ID : m8c8qs, 리뷰 : None, 평점 : 3, 날짜 : 2019.12.26.
# 리뷰코드 : GC000017, 가게코드 : STORE_GC0001, ID : tknu55, 리뷰 : None, 평점 : 5, 날짜 : 2019.02.09.
# 리뷰코드 : GC000018, 가게코드 : STORE_GC0001, ID : 7lro0a, 리뷰 : 부들부들한 만두피에 한 입에 먹기 좋은 만두가 가득 들어있는 사골만두국이 이 집의 Top. 더 달라하면 얼마든지 내주는 밥과 겉절이김치까지 먹을 수 있다. 주인 내외분들도 친절하시고, 가게도 깨끗해서 다녀오면 기분까지 좋아지는 밥집이다. 점심 피크타임을 비켜 가면 주차도 한결 수월하다., 평점 : 5, 날짜 : 2018.11.16.
# 리뷰코드 : GC000019, 가게코드 : STORE_GC0001, ID : gfsi8i, 리뷰 : 정직한맛. 굳이 단점을 찾자면 주차장때문에 가기 꺼려진다.., 평점 : 5, 날짜 : 2018.11.15.
# 리뷰코드 : GC000020, 가게코드 : STORE_GC0001, ID : bgpuf2, 리뷰 : 맛나네용.  점심 먹으러 들렀는데 역시 육수가 좋아요, 평점 : 4, 날짜 : 2018.05.30.
# 리뷰코드 : GC000021, 가게코드 : STORE_GC0001, ID : lumufu, 리뷰 : 맛있어요, 평점 : 5, 날짜 : 2018.03.10.
# 리뷰코드 : GC000022, 가게코드 : STORE_GC0001, ID : msecl5, 리뷰 : None, 평점 : 5, 날짜 : 2017.08.13.
# 리뷰코드 : GC000023, 가게코드 : STORE_GC0001, ID : 7killg, 리뷰 : 시흥3동 954-21 공구상가4번건물 2번출입구, 평점 : 3, 날짜 : 2016.03.12.
# 리뷰코드 : GC000024, 가게코드 : STORE_GC0001, ID : None, 리뷰 : 맛으로는 8점, 친절과 위생, 가격을 더한다면 10점 만점... 기회(?)가 된다면 다시 가볼 것 같다..., 평점 : 5, 날짜 : 2019.04.04.
# 리뷰코드 : GC000025, 가게코드 : STORE_GC0001, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.10.28.
# 리뷰코드 : GC000026, 가게코드 : STORE_GC0001, ID : None, 리뷰 : None, 평점 : 5, 날짜 : 2018.10.19.
# 리뷰코드 : GC000027, 가게코드 : STORE_GC0001, ID : None, 리뷰 : 생활의 달인에 이어 수요미식회 만두 맛집~ 만두국이 특히 맛있었어요^^, 평점 : 4, 날짜 : 2018.10.17.
# 리뷰코드 : GC000028, 가게코드 : STORE_GC0001, ID : None, 리뷰 : "HOLY Mandu"  전세계 돌아 다녀도 이정도 가격에 이정도 가성비 찾기 힘듬.  상황상 군만두를 과감히 뺀거 보면 만두 아시는 분임.  다만 알바들이 문제....서비스 해본적 없는...분들 쓰시는듯...  단 메뉴 볼것 없고 통만두 2인분 모밀국수 1인분..만육천원으로 행복한 오후 보낸다.  부대시설 인테리어 화장실 이런건 안드로메다로 보내고 가야 ..., 평점 : 5, 날짜 : 2018.03.22.
# 리뷰코드 : GC000029, 가게코드 : STORE_GC0001, ID : None, 리뷰 : None, 평점 : 3, 날짜 : 2016.06.28.
# 리뷰코드 : GC000030, 가게코드 : STORE_GC0001, ID : None, 리뷰 : 꼭  방문하겠습니다, 평점 : 5, 날짜 : 2018.03.10.
# no review in crawling
# 가게코드 : STORE_GC0002, 가계명 : 가산물갈비&백년불고기, 주소 : 서울 금천구 가산디지털1로 128 STXV타워 1층 110호, 지역 : (지번) 가산동 371-37, 종류 : 불고기,두루치기
# #### 가산물갈비&백년불고기
# 리뷰코드 : GC000031, 가게코드 : STORE_GC0002, ID : 1kbkdss, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.15.
# 리뷰코드 : GC000032, 가게코드 : STORE_GC0002, ID : kl3tq0, 리뷰 : 회식 장소로는 갸우뚱. 하지만 동성 친구끼리 가성비 있게 먹을 장소로 제격입니다. 양 많고 맛 좋고 서비스 괜찮아요., 평점 : 5, 날짜 : 2021.05.23.
# 리뷰코드 : GC000033, 가게코드 : STORE_GC0002, ID : tl6oe5, 리뷰 : 여기가 맛있어요? 회식장소로 좋아요? 아 내돈 내산은 안좋다는거죠 갔을때 먹고, 아 여긴 두번다시 안올맛이다. 싶어요 한약재로 만들었다고 하는데,그게 진짜 사족의맛 이에요., 평점 : 1, 날짜 : 2021.05.13.
# 리뷰코드 : GC000034, 가게코드 : STORE_GC0002, ID : 9hhb1j, 리뷰 : 회식장소로 좋구요 오징어튀김이 별미예요 엄청 바삭해요 , 평점 : 5, 날짜 : 2021.04.23.
# 리뷰코드 : GC000035, 가게코드 : STORE_GC0002, ID : td5904, 리뷰 : 맛있음, 평점 : 5, 날짜 : 2021.03.27.
# 리뷰코드 : GC000036, 가게코드 : STORE_GC0002, ID : vcc55l, 리뷰 : 회식으로는 딱입니다, 평점 : 5, 날짜 : 2020.12.22.
# 리뷰코드 : GC000037, 가게코드 : STORE_GC0002, ID : 1boevfl, 리뷰 : 맛있어요 양도많고ㅋ, 평점 : 4, 날짜 : 2020.10.16.
# 리뷰코드 : GC000038, 가게코드 : STORE_GC0002, ID : 1cqonqd, 리뷰 : 맵찔이는 먹기 힘들어요! 그러나 오징어튀김 있으니까 괜찮아요 ㅋㅋㅋ 맛있음다, 평점 : 4, 날짜 : 2020.10.16.
# 리뷰코드 : GC000039, 가게코드 : STORE_GC0002, ID : 14fmv5f, 리뷰 : None, 평점 : 5, 날짜 : 2020.10.09.
# 리뷰코드 : GC000040, 가게코드 : STORE_GC0002, ID : 1auhdud, 리뷰 : 양도 많고 맛있어요, 평점 : 4, 날짜 : 2020.08.04.
# 리뷰코드 : GC000041, 가게코드 : STORE_GC0002, ID : n2m781, 리뷰 : 맛있는데 양이 진짜 너무많아서 4분이시면 3인분시키고 오징어튀김시키세요 오징어튀김 맛있어요! 인기가 많아서그런지 뭐.. 친절이나 서비스는 그저그렇습니다, 평점 : 5, 날짜 : 2020.07.08.
# 리뷰코드 : GC000042, 가게코드 : STORE_GC0002, ID : 13d08nb, 리뷰 : 칼칼하고 국물에 소고기면 정답인듯, 평점 : 5, 날짜 : 2020.02.12.
# 리뷰코드 : GC000043, 가게코드 : STORE_GC0002, ID : fmvbrr, 리뷰 : 맛있대서 갔는데 있던 입맛도 떨어지는 맛임 달고 짜고 채소 산더미 쌓아주고 고기조금올리고, 평점 : 1, 날짜 : 2020.01.27.
# 리뷰코드 : GC000044, 가게코드 : STORE_GC0002, ID : 7uqtcj, 리뷰 : 외형 : 위에 올라간 샤브샤브 고기와 아래 깔린 갈비, 버섯 두조각에 많은 콩나물. 양은 가격대비 적당.  식평 : 샤브고기 질 괜찮고 하단 갈비살은 비린향을 못잡음. 무엇보다 기본 육수가 지나치게 달아요. 육수맛때문에 다먹지도 못하고 남겼어요. 물려요. 회사건물에 광고 정말많이나오길래 가봤는데 기대이하.  어르신들은 음식이 단거 싫어하므로 가족외식용으로는..., 평점 : 2, 날짜 : 2020.01.05.
# 리뷰코드 : GC000045, 가게코드 : STORE_GC0002, ID : 107hlue, 리뷰 : None, 평점 : 4, 날짜 : 2019.10.20.
# 리뷰코드 : GC000046, 가게코드 : STORE_GC0002, ID : qfn4ci, 리뷰 : None, 평점 : 4, 날짜 : 2019.01.18.
# 리뷰코드 : GC000047, 가게코드 : STORE_GC0002, ID : rj2ppo, 리뷰 : 술안주로 좋다. 볶음밥이 아쉽다., 평점 : 4, 날짜 : 2018.12.06.
# 리뷰코드 : GC000048, 가게코드 : STORE_GC0002, ID : o3dogh, 리뷰 : 맛있습니다, 평점 : 5, 날짜 : 2018.11.23.
# 리뷰코드 : GC000049, 가게코드 : STORE_GC0002, ID : kb4m89, 리뷰 : 음 여기왜 점수 3.8점인지 모르겠네요. 고기는 평범한 약간 누린내가 있구요 국물은 달아요. 떡볶이맛이 나요.... 어른들 모시고 맛집일거라고 생각해서 왔는데. 실망이네요. 양은 많습니다. 2.5점이 적당해요. 그나마 제일맛있는건 동치미입니다. , 평점 : 2, 날짜 : 2018.09.25.
# 리뷰코드 : GC000050, 가게코드 : STORE_GC0002, ID : 7vor8t, 리뷰 : 광고보구갔다가 실망, 평점 : 2, 날짜 : 2018.08.24.
# 리뷰코드 : GC000051, 가게코드 : STORE_GC0002, ID : n7n6mp, 리뷰 : 불고기 짱~!, 평점 : 5, 날짜 : 2017.12.15.
# 리뷰코드 : GC000052, 가게코드 : STORE_GC0002, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.11.13.
# 리뷰코드 : GC000053, 가게코드 : STORE_GC0002, ID : None, 리뷰 : 국물이 달고 고기에서 아주약간 누린내가 난다. 가격도 비싸고… 어른들 모시고 갔다가 민망했음 ㅠㅠ, 평점 : 1, 날짜 : 2019.02.19.
# 리뷰코드 : GC000054, 가게코드 : STORE_GC0002, ID : None, 리뷰 : 점심먹으러갔는데 점심정식주문하니 다른비싼메뉴 소불고기 먹으라고함, 평점 : 1, 날짜 : 2018.12.11.
# no review in crawling
# 가게코드 : STORE_GC0003, 가계명 : 동흥관, 주소 : 서울 금천구 시흥대로63길 20, 지역 : (지번) 시흥동 115-10, 종류 : 중화요리
# #### 동흥관
# 리뷰코드 : GC000055, 가게코드 : STORE_GC0003, ID : mup5gm, 리뷰 :  , 평점 : 5, 날짜 : 2021.08.11.
# 리뷰코드 : GC000056, 가게코드 : STORE_GC0003, ID : n3320u, 리뷰 : 가격도 그렇게 비싼것도 아니고 맛도 괜찮았어요, 평점 : 3, 날짜 : 2021.07.07.
# 리뷰코드 : GC000057, 가게코드 : STORE_GC0003, ID : 1604arb, 리뷰 : 일부러 갈곳은 절대아님! 지나가다 배고파 갈곳없을때나 가볼까 하는집. 친절. 위생꽝이네요. 좀친절하고 위생과 맛에신경쓰면 괜찮은 기본은 있는 집인데!, 평점 : 1, 날짜 : 2021.07.06.
# 리뷰코드 : GC000058, 가게코드 : STORE_GC0003, ID : 16ghll5, 리뷰 : 고등학교때부터 쭉 다녀왔지만 옛날의 친절함이 다 사라졌다. 주문을 해도 들은둥 마는둥... 뭘 좀 더 갖다달라고 하면 3번을 말해야 갖다준다. 심지어 옆테이블에게 갖다준다 ㅋㅋㅋㅋ 직원들은 벽에 기대어 핸드폰이나 하고 이런게 중국인 종특인가싶다. 다시는 가지 않을것 같다., 평점 : 1, 날짜 : 2021.07.05.
# 리뷰코드 : GC000059, 가게코드 : STORE_GC0003, ID : lnn9im, 리뷰 : 개인적으로는 너무 맛잇고 프라이빗 하게 만나기 너무 좋은데 직원들분이 그렇게 친절 하진 않아서 5 점 만점을 못 드리겠는 …? , 평점 : 4, 날짜 : 2021.06.23.
# 리뷰코드 : GC000060, 가게코드 : STORE_GC0003, ID : f0ugns, 리뷰 : 삼성짬뽕이 너무짰어요 원래 컴플레인은 잘못해서 그냥 참고 먹었는데 그릇밑으로 내려갈수록 더 짜더군요 비싼 돈주고 멀 먹고나온건지 ..., 평점 : 1, 날짜 : 2021.05.20.
# 리뷰코드 : GC000061, 가게코드 : STORE_GC0003, ID : rnu9hd, 리뷰 : 유명하다길래 먹었지만 역시나 샤롱바오는 크리스탈제이드도 그저그런데 크리스탈제이드보다 못하다. 한국에는 진짜 딤섬맛집은 없는걸까, 평점 : 2, 날짜 : 2021.05.19.
# 리뷰코드 : GC000062, 가게코드 : STORE_GC0003, ID : ghki4k, 리뷰 : 기본 메뉴인 짜장 짬뽕 탕수육이 20여년전에는 진짜 맛있었음 그땐 짱깨가 아니라 진짜 짜장면이었지 지금은 짜장짬뽕은 그냥 보통수준으로 다운그래이드 됨.. 예전 맛을 아는 입장에서 정말 아쉽다.  탕수육은 여전히 맛있음 딤섬류가 짱임, 평점 : 2, 날짜 : 2021.05.04.
# 리뷰코드 : GC000063, 가게코드 : STORE_GC0003, ID : gnda2t, 리뷰 : 짬뽕 맛집입니다 만두 꼭 같이 시켜드세요, 평점 : 3, 날짜 : 2021.04.27.
# 리뷰코드 : GC000064, 가게코드 : STORE_GC0003, ID : 1eb6brn, 리뷰 : 전통 오래된 곳이라 가족들과 10년간 다녔는데 올때마다 스트레스 받고감. 이젠 절대 안갈 예정. 진짜 식기마다 고추가루, 뭐 묻어있고 조선족 서빙들 싸가x를 어디다 말아먹었는지 중자? 대자? 이딴식으로 ㅋㅋㅋㅋㅌㅋㅌ 맛도 점점 없어짐. 18살때 먹었던 짜장면 맛 어디감 ? , 평점 : 1, 날짜 : 2021.04.11.
# 리뷰코드 : GC000065, 가게코드 : STORE_GC0003, ID : rr8dj1, 리뷰 : 주로 대림이나 중국인(혹은조선족)주방장이 요리하는 작은식당에서  마라상궈. 꿔바로우 먹다가  동네 중국집이라서 먹어봤는데..  다른메뉴는 모르겠지만 이 두 메뉴는 비추천합니다.  재료는 좋은것을 씁니다.그래서 가격이 비싼것인지 모르겠지만  맛이 없습니다  꿔바로우에 바삭함이라고는 없는 눅눅함  마라상궈는 해물많고 향은 같은데  흔히먹는 대림식 마라상궈 와는..., 평점 : 1, 날짜 : 2021.03.26.
# 리뷰코드 : GC000066, 가게코드 : STORE_GC0003, ID : v0e2u8, 리뷰 : 배달전문 동흥관짱차우는 개판이었는데 이사가기 전에 혹시나 하고 본관 간짜장 먹어봄. 본관은 맛있네. 신기하게 짜파게티 향이 살짝 나는 듯?(개인적 느낌), 평점 : 4, 날짜 : 2021.03.26.
# 리뷰코드 : GC000067, 가게코드 : STORE_GC0003, ID : 11tfqcq, 리뷰 : 어릴적부터 먹어온 짬뽕인데...주방장님이,.. 사장님이...바뀌셨나요?  왜 맛이 바꼈죠? 왜이렇게 불 친절해졌을까요? 기억에 30년 넘게 갔던 가게인데..아쉽네요 그래도 다묵었네요.., 평점 : 2, 날짜 : 2021.03.20.
# 리뷰코드 : GC000068, 가게코드 : STORE_GC0003, ID : dahcrl, 리뷰 : 세트 메뉴먹음. 맛있음. , 평점 : 4, 날짜 : 2021.03.14.
# 리뷰코드 : GC000069, 가게코드 : STORE_GC0003, ID : bh58m8, 리뷰 : None, 평점 : 5, 날짜 : 2021.03.07.
# 리뷰코드 : GC000070, 가게코드 : STORE_GC0003, ID : 19nah7q, 리뷰 : 아직까지 자리잡고 영업하는것만 해도 감사한집. 32년전 첫 방문때의 감동은 아직도 잊을수 없다, 평점 : 4, 날짜 : 2021.02.05.
# 리뷰코드 : GC000071, 가게코드 : STORE_GC0003, ID : 1867jjm, 리뷰 : None, 평점 : 5, 날짜 : 2020.12.10.
# 리뷰코드 : GC000072, 가게코드 : STORE_GC0003, ID : 17if7pk, 리뷰 : 맛은 나름 내는데 들어가는재료를 잘 못쓰는 느낌의 음식점...  차짬은 시원한 느낌이였는데 콩나물이 들어가서 그런가 봤더니 콩나물은 없었고 고추를 넣어서 시원한 맛을 낸 느낌이다. 대신 짬뽕 특유의 진한맛은 없다. 흔히 알던 짬뽕은 아님.  삼선간짜장은 굿~ 하지만 들어가는 오징어가 너무 질겼음  꿔바로우는 다신 안시킬듯. 돼지잡내가 너무 심함. 잡내잡겠다..., 평점 : 2, 날짜 : 2020.11.19.
# 리뷰코드 : GC000073, 가게코드 : STORE_GC0003, ID : 13ga8i2, 리뷰 : 마싯당, 평점 : 5, 날짜 : 2020.11.11.
# 리뷰코드 : GC000074, 가게코드 : STORE_GC0003, ID : 7mkutk, 리뷰 : 갈 때마다 맛이 다름.  짬뽕은 매워요. 우동은 그냥 그랬고. 짜장은 평범. 탕수육은 괜찮았음., 평점 : 2, 날짜 : 2020.11.08.
# 리뷰코드 : GC000075, 가게코드 : STORE_GC0003, ID : tostbd, 리뷰 : 삼선짬뽕이 갑~이였으나 국물맛이 달라질때가 많아졌어요, 평점 : 3, 날짜 : 2020.10.12.
# 리뷰코드 : GC000076, 가게코드 : STORE_GC0003, ID : 12lknos, 리뷰 : 해물간짜장시켰는데 일반간짜장 인줄.. 돈아까워 다신안갈듯, 평점 : 1, 날짜 : 2020.10.02.
# 리뷰코드 : GC000077, 가게코드 : STORE_GC0003, ID : uthhdd, 리뷰 : 짬뽕은 떡같이 붙은 차가운 면 위에 짠물 붙고 홍합 몇개 얹고 줌..  동네 화교인지 조선족인지 오래됐는데 맛은 허접., 평점 : 1, 날짜 : 2020.09.22.
# 리뷰코드 : GC000078, 가게코드 : STORE_GC0003, ID : 1833s91, 리뷰 : 여기 왜 안망하는지 궁금. 주변 사시는 주민분들 모두 여기 별맛도없고 비싸던데 왜 항상 사람이 많은지 모르겠다고 ㅋㅋ 네이버는 정말 광고가 많나봐요. 여기 5점 준  후기가 왜그렇게 많은지 ㅋㅋㅋ, 평점 : 1, 날짜 : 2020.08.19.
# 리뷰코드 : GC000079, 가게코드 : STORE_GC0003, ID : qt6vqs, 리뷰 : 그냥 오지마세요 공손한 손님한테 승질만 내는 직원들 음식 수준운 동네 초짜 수준, 평점 : 1, 날짜 : 2020.07.24.
# 리뷰코드 : GC000080, 가게코드 : STORE_GC0003, ID : dp0f3j, 리뷰 : 이전과는 확실히 맛의 퀄리티가 떨어졌어요. 탕수육 고기는 너무 질기고 냄새가 났으며, 짜장은 싱거웠습니다.  20년 가까이 다녔지만 오늘 정말 최악이네요.  죄송하다 미안하다는 말도 전혀 없구요. 이제 안갈것 같습니다. , 평점 : 1, 날짜 : 2020.07.05.
# 리뷰코드 : GC000081, 가게코드 : STORE_GC0003, ID : csgujd, 리뷰 : 금천구 시흥동에서 가장 오래된 화상중국집으로 고풍스러운 인테리어가 분위기있다. 딤섬메뉴는 포장해 가거나 곁들여 주문할 만함 since 1951년, 평점 : 3, 날짜 : 2020.04.25.
# 리뷰코드 : GC000082, 가게코드 : STORE_GC0003, ID : h1pg00, 리뷰 : 괜찮아요, 평점 : 4, 날짜 : 2020.02.22.
# 리뷰코드 : GC000083, 가게코드 : STORE_GC0003, ID : 1317biu, 리뷰 : 시흥동에서 가장 오래된중국음식점으로 화교가운영하는70여년전통 금천구에서 모범음식점으로 선정됨, 평점 : 4, 날짜 : 2019.12.19.
# 리뷰코드 : GC000084, 가게코드 : STORE_GC0003, ID : 14u8i9o, 리뷰 : None, 평점 : 3, 날짜 : 2019.12.19.
# 리뷰코드 : GC000085, 가게코드 : STORE_GC0003, ID : 14u8hr6, 리뷰 : None, 평점 : 2, 날짜 : 2019.12.19.
# 리뷰코드 : GC000086, 가게코드 : STORE_GC0003, ID : 14u8h5k, 리뷰 : 서비스가좋았습니다, 평점 : 4, 날짜 : 2019.12.19.
# 리뷰코드 : GC000087, 가게코드 : STORE_GC0003, ID : 14u8d5h, 리뷰 : 별로 였습니다, 평점 : 3, 날짜 : 2019.12.19.
# 리뷰코드 : GC000088, 가게코드 : STORE_GC0003, ID : fl2iqn, 리뷰 : 그닥, 평점 : 1, 날짜 : 2019.11.08.
# 리뷰코드 : GC000089, 가게코드 : STORE_GC0003, ID : u97vh3, 리뷰 : 별로... 그냥 오래된 역사를 가진 집?이라는 것만 빼면 매우 평범함., 평점 : 1, 날짜 : 2019.10.20.
# 리뷰코드 : GC000090, 가게코드 : STORE_GC0003, ID : v74g55, 리뷰 : 간짜장이 맛있어요. 회식/모임 장소로 좋은 듯, 평점 : 4, 날짜 : 2019.09.21.
# 리뷰코드 : GC000091, 가게코드 : STORE_GC0003, ID : ldail0, 리뷰 : 요리에서 철 수세미나옴, 평점 : 1, 날짜 : 2019.09.09.
# 리뷰코드 : GC000092, 가게코드 : STORE_GC0003, ID : eemi7q, 리뷰 : 네 굳이 찾아갈 정도는 아니네요, 평점 : 2, 날짜 : 2019.08.29.
# 리뷰코드 : GC000093, 가게코드 : STORE_GC0003, ID : jti6dn, 리뷰 : 홍콩반점이 훨나은,,, 오래된곳인데 여태 유지하는게 신기하다, 평점 : 2, 날짜 : 2019.08.26.
# 리뷰코드 : GC000094, 가게코드 : STORE_GC0003, ID : n22c1c, 리뷰 : 솔직히 가격대비 양,맛이 좋은지는 모르겠다, 평점 : 1, 날짜 : 2019.08.06.
# 리뷰코드 : GC000095, 가게코드 : STORE_GC0003, ID : 11pdv5l, 리뷰 : 힘들었습니다., 평점 : 1, 날짜 : 2019.07.28.
# 리뷰코드 : GC000096, 가게코드 : STORE_GC0003, ID : mv0j90, 리뷰 : 간짜장 시켰는데 묽고 게다가 양파도 대충 썰어져 있고 고기도 없어요 완전 실망, 평점 : 1, 날짜 : 2019.06.08.
# 리뷰코드 : GC000097, 가게코드 : STORE_GC0003, ID : vmigjq, 리뷰 : None, 평점 : 4, 날짜 : 2019.04.13.
# 리뷰코드 : GC000098, 가게코드 : STORE_GC0003, ID : c296hv, 리뷰 : 가족 식사하기는 장소가 여유가 있는 듯, 평점 : 3, 날짜 : 2019.04.13.
# 리뷰코드 : GC000099, 가게코드 : STORE_GC0003, ID : 10a7u8i, 리뷰 : None, 평점 : 4, 날짜 : 2019.02.21.
# 리뷰코드 : GC000100, 가게코드 : STORE_GC0003, ID : n5so0b, 리뷰 : 유명하다고해서 왔는데 실망이었음. 여태껏 먹은 코스요리중 젤맛없네요., 평점 : 1, 날짜 : 2018.09.30.
# 리뷰코드 : GC000101, 가게코드 : STORE_GC0003, ID : r004hj, 리뷰 : 간짜장 이 제대로 , 잡탕밥도 맛있고 ㅎ, 평점 : 5, 날짜 : 2018.08.25.
# 리뷰코드 : GC000102, 가게코드 : STORE_GC0003, ID : ne7bta, 리뷰 : 7대 의회에 금천구 의회 의장단이 업무추진비 카드를 가장 많이 긁은 곳은? 동흥관 이네요! 총 16,390,500원을 썼어요. , 평점 : 3, 날짜 : 2018.06.01.
# 리뷰코드 : GC000103, 가게코드 : STORE_GC0003, ID : mr5ucd, 리뷰 : None, 평점 : 3, 날짜 : 2018.05.03.
# 리뷰코드 : GC000104, 가게코드 : STORE_GC0003, ID : mbp6m3, 리뷰 : 그냥저냥 보통. 맛도보통. 발레파킹해주는건 괜찮은 서비스., 평점 : 3, 날짜 : 2018.04.22.
# 리뷰코드 : GC000105, 가게코드 : STORE_GC0003, ID : g7u5g5, 리뷰 : 맛은 그럭저럭 평범함. 하지만 세트메뉴a에서 나오는 짜장면과 짬뽕을보고 애들 먹으라고 덜어준건줄알았네요. 경악스러웠습니다. 기대하고갔는데 먹는사람과 대접하는사람이 서로 민망했네요.., 평점 : 2, 날짜 : 2017.10.24.
# 리뷰코드 : GC000106, 가게코드 : STORE_GC0003, ID : 104ba8h, 리뷰 : 짬뽕 보통, 군만두 별로., 평점 : 2, 날짜 : 2016.09.24.
# 리뷰코드 : GC000107, 가게코드 : STORE_GC0003, ID : 10loopk, 리뷰 : 꿔바로우가 괜찮네요 짬뽕은 국물은 짜지않고 시원하니 좋으나 면발이 별로임! , 평점 : 3, 날짜 : 2016.09.18.
# 리뷰코드 : GC000108, 가게코드 : STORE_GC0003, ID : c7iojg, 리뷰 : 소룡포, 평점 : 4, 날짜 : 2016.05.25.
# 리뷰코드 : GC000109, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 엄청 오래된 중국집, 평점 : 5, 날짜 : 2018.09.04.
# 리뷰코드 : GC000110, 가게코드 : STORE_GC0003, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.06.05.
# 리뷰코드 : GC000111, 가게코드 : STORE_GC0003, ID : None, 리뷰 : None, 평점 : 3, 날짜 : 2018.01.19.
# 리뷰코드 : GC000112, 가게코드 : STORE_GC0003, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2017.11.11.
# 리뷰코드 : GC000113, 가게코드 : STORE_GC0003, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2016.09.12.
# 리뷰코드 : GC000114, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 깐풍기, 평점 : 3, 날짜 : 2016.09.04.
# 리뷰코드 : GC000115, 가게코드 : STORE_GC0003, ID : None, 리뷰 : None, 평점 : 1, 날짜 : 2016.08.28.
# 리뷰코드 : GC000116, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 정식15000에 양장피.탕수육.꽃빵.짜.짬 다먹을수 있음., 평점 : 4, 날짜 : 2016.07.17.
# 리뷰코드 : GC000117, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 가족외식, 평점 : 5, 날짜 : 2016.04.25.
# 리뷰코드 : GC000118, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 변함없는 중국집~~ 어려서 동흥관앞동네 살앗다능 ㅋ, 평점 : 3, 날짜 : 2016.03.25.
# 리뷰코드 : GC000119, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 오래된 화상중식, 평점 : None, 날짜 : 2015.12.02.
# 리뷰코드 : GC000120, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 짬뽕. 탕수육, 평점 : None, 날짜 : 2015.01.08.
# 리뷰코드 : GC000121, 가게코드 : STORE_GC0003, ID : None, 리뷰 : None, 평점 : None, 날짜 : 2014.12.12.
# 리뷰코드 : GC000122, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 짬뽕,탕수육, 평점 : None, 날짜 : 2014.10.30.
# 리뷰코드 : GC000123, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 짬뽕 탕수육 가고파, 평점 : None, 날짜 : 2014.10.10.
# 리뷰코드 : GC000124, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 라이딩후 첫끼 짜장에 탕수육! 무지 배고픔 장난아님 !!, 평점 : None, 날짜 : 2014.06.06.
# 리뷰코드 : GC000125, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 동흥관 금천구청역 짜장면집ㅇㅅ, 평점 : None, 날짜 : 2014.02.12.
# 리뷰코드 : GC000126, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 삼선짬뽕이 갑이다~~~, 평점 : None, 날짜 : 2013.11.21.
# 리뷰코드 : GC000127, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 조금 짜지만 않다면 더좋겠어요 오랜 역사^^, 평점 : None, 날짜 : 2013.10.09.
# 리뷰코드 : GC000128, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 괜찮은 곳이네요 특별나지는 않아요, 평점 : None, 날짜 : 2013.09.21.
# 리뷰코드 : GC000129, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 금천구청역 근처 괘안은 중국집 ~~~, 평점 : None, 날짜 : 2013.09.16.
# 리뷰코드 : GC000130, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 분위기도좋고 괜찮은 중국집 무난~~, 평점 : None, 날짜 : 2013.09.14.
# 리뷰코드 : GC000131, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 중식, 평점 : None, 날짜 : 2013.08.22.
# 리뷰코드 : GC000132, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 50년이 넘은 짬뽕 맛집! 탕수육도 엄청 많이 나오고 굿!, 평점 : None, 날짜 : 2013.08.16.
# 리뷰코드 : GC000133, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 여기 짬뽕하고 탕슉 주세요~, 평점 : None, 날짜 : 2013.08.16.
# 리뷰코드 : GC000134, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 여기보다 맛있는 중국집은 아주 많다, 다만 시흥토박이들이 가장 좋아하는 곳., 평점 : None, 날짜 : 2013.08.13.
# 리뷰코드 : GC000135, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 짜장면이 땡긴다면 이곳을 애용합니다 ㅋㅋ, 평점 : None, 날짜 : 2013.08.07.
# 리뷰코드 : GC000136, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 어릴때부터 갔던 중국집인데 항상 맛있어요!, 평점 : None, 날짜 : 2013.08.07.
# 리뷰코드 : GC000137, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 짬뽕, 평점 : None, 날짜 : 2013.08.05.
# 리뷰코드 : GC000138, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 활조개 짬뽕 맛있어요, 평점 : None, 날짜 : 2013.07.22.
# 리뷰코드 : GC000139, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 짬뽕 탕수육 짜장면  복음밥 먹음 짜장면은 조미료 투성이(일반중국집맛과동일) 짬뽕은 고추가루맛밖에없음, 복음밥 짜장과같이 나올때부터 의심 예상이 빗나가지않음, 탕수육 보통 다른집과 별반차이가없음.   아빠와아들 광명맛집투어 별점  (하나) :일부러 찾아갈정도는안임, 평점 : None, 날짜 : 2013.07.13.
# 리뷰코드 : GC000140, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 짱깨집, 평점 : None, 날짜 : 2013.06.09.
# 리뷰코드 : GC000141, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 지나만 다녔는데 다음엔 도전!!, 평점 : None, 날짜 : 2013.05.23.
# 리뷰코드 : GC000142, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 동흥관, 평점 : None, 날짜 : 2013.05.19.
# 리뷰코드 : GC000143, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 중국집 같으면서 가정집 같은 곳 하지만 맛은 좋았다는거, 평점 : None, 날짜 : 2013.03.20.
# 리뷰코드 : GC000144, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 남편과 함께 자주 가는 곳입니다. 다 맛있지만 샤오롱빠오 특히 맛있답니다. 남영동에 있는 맛집과 비교해도 손색 없었네요. 강추!!!, 평점 : 5, 날짜 : 2018.10.08.
# 리뷰코드 : GC000145, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 제가 10년째 다니는 맛집인데, 별이 하나라니... 어이가 없네요. 서비스 좋고 분위기 좋고 친절하고, 그리고 맛있습니다. 가족모임, 친구모임, 지인들 모임에 더할나위 없이 좋습니다. 적극 추천합니다., 평점 : 5, 날짜 : 2018.10.08.
# 리뷰코드 : GC000146, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 토요일에 아내랑 가보고나서 여기 별점보니 놀랍네요 이 정도 분위기 직원태도 음식맛으로 보면 중간 이상인데 별 하나라니 .... 뭐 취향이 다르니 그럴수도 있겠지만 잡탕밥은 내 취향이었고 아내는 간짜장 먹고 아주 만족했는데 , 평점 : 5, 날짜 : 2018.08.27.
# 리뷰코드 : GC000147, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 전 무지 괜찮아서 친구한테 추천해주려고 검색했는데..평점이 왜이러죠?전 네번 가봤고 맨빠우샤. 활조개짬뽕. 샤오롱빠오. 꿔바로우. 짜장면. 양장피 군만두 중국식냉면 먹었습니다., 평점 : 5, 날짜 : 2017.01.14.
# 리뷰코드 : GC000148, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 친정부모님과 갔는데 진짜맛이없어 다시는 가고싶지않습니다. 짬뽕내용두 정말 부실하고 짜장두 맛없구 동네 중국집보다 훨씬 맛없습니다.겉만화려하구 내용은 최악..., 평점 : 1, 날짜 : 2017.01.12.
# 리뷰코드 : GC000149, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 짬뽕이든 짜장이든 면과 국물이 따로 놉니다. 면이 떡이니까요.특히 짬뽕은 가관입니다. 떡진 면과 국물 그리고 홍합 대충 담아서 나옵니다. 맛은 짭니다...., 평점 : 1, 날짜 : 2016.07.20.
# 리뷰코드 : GC000150, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 갈수록 맛이 없어집니다. 삼선짬뽕, 짜장 시켰는데 해물이 덜익어 비린 맛이 엄청났습니다. 양도 많이 줄어들고 전에 식전에 물대신 주던 차도 안주더군요. 올해 먹어본 짬뽕, 짜장중 최악 이였습니다., 평점 : 1, 날짜 : 2016.06.16.
# 리뷰코드 : GC000151, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 정말 맛없네요ㅠㅠ 맛집이라고 블로그에 나온거 보고 갔는데 돈이 아까워요 그리고 탕수육 작은거 16000만원짜리 주문했는데 지네들 멋대로 22000원짜리 갖다줌 어이상실~~ 다른 손님들 앞에서 싫은소리 하기 싫어서 꾹참고 먹었는데 맛도 꽝입니다ㅠㅠ 겉만 화려하게 해놓으면 뭐합니까? 음식맛이 젤 중요한건데 음식맛도 별루 주문도 지네 멋대로 엉터리로 받고...., 평점 : 1, 날짜 : 2016.06.10.
# 리뷰코드 : GC000152, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 정말 맛있는 곳인데 이 댓글들은 뭔지 모르겠음. 짜장면, 짬뽕 다 맛있어요. 생각나서 또 가고 싶은 맛., 평점 : 5, 날짜 : 2015.08.24.
# 리뷰코드 : GC000153, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 맛드럽거없음..돈아까움..홍콩반점이백배는맛있음..여긴왜사람이많은지이해안감..별한개도아까움.., 평점 : 1, 날짜 : 2015.01.12.
# 리뷰코드 : GC000154, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 10년전에나 먹을만했지지금은 홈플러스 푸드코트보다 못해요 돈아까움, 평점 : 1, 날짜 : 2014.11.24.
# 리뷰코드 : GC000155, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 가서먹으면 먹을만하고 배달해서 먹으면 최악의 음식이 옵니다 , 평점 : 1, 날짜 : 2014.08.30.
# 리뷰코드 : GC000156, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 중국집에 시켜먹고 후회한집은 이집이 처음입니다 가격은 비싼데 양은 한젓가락에 맛은 최악 탕수육은 너무 바짝튀겨서  과자먹는 느낌에 고기는 씹히지도 않네요, 평점 : 1, 날짜 : 2013.11.07.
# 리뷰코드 : GC000157, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 태어나서 먹어본 짬뽕중에 제일 최악이네요 죄다 팅팅 불어 와서 이걸 먹으라고 가져온건지...리뷰가 13건이나 되는데 심히 의심이 되네요. 진심으로 별 1개도 아깝습니다., 평점 : 1, 날짜 : 2013.07.06.
# 리뷰코드 : GC000158, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 중국 읍단위에나 있을 법한 최악의 집.....맛도 최악. 이런 집이.... 값만 강남순준...... 탕수육에 배추로 범벅을 해 놓고....면은 싸구려에......., 평점 : 1, 날짜 : 2012.10.13.
# 리뷰코드 : GC000159, 가게코드 : STORE_GC0003, ID : None, 리뷰 : 오늘 홈서비스로 주문해서 먹었는데요 짜자면에 양념이 하나도 없고 면이 많이 불어서 전화했더니 어떻게 해달라는 거냐고 묻는다, 평점 : 1, 날짜 : 2012.10.07.
# 리뷰코드 : GC000160, 가게코드 : STORE_GC0003, ID : None, 리뷰 : '중국집' 스타일에서는 최고 수준! 무엇보다 주방장의 솜씨가 환상적이고, 재료가 아주 신선합니다. 약간 비싼 가격, 세트 메뉴의 부실함은 옥의 티. , 평점 : 5, 날짜 : 2012.01.02.
# no review in crawling
# 가게코드 : STORE_GC0004, 가계명 : 강강술래 시흥점, 주소 : 서울 금천구 시흥대로 193 금천ICT타워 2층, 지역 : (지번) 시흥동 991, 종류 : 육류,고기
# #### 강강술래 시흥점
# 리뷰코드 : GC000161, 가게코드 : STORE_GC0004, ID : 109p7k6, 리뷰 : None, 평점 : 4, 날짜 : 2021.06.14.
# 리뷰코드 : GC000162, 가게코드 : STORE_GC0004, ID : 18t6cjp, 리뷰 : 이전 이후 더 깔끔해지고 맛도 더 신경쓰시는 것 같습니다., 평점 : 4, 날짜 : 2021.05.30.
# 리뷰코드 : GC000163, 가게코드 : STORE_GC0004, ID : 19h1cpf, 리뷰 : 별 1점도 아까움. 고기 최악. 직원은 더 최악. 한우 질기고 맛없음. 직원 주문 받던 분이 빤히 쳐다보더니 위아래 흘겨봄. 다 먹지도 않았는데 불판 치워버림. 마감시간인줄. 비싼 돈 주고 먹다 체할뻔. 2번 다시는 안 옴. 손절. 그냥 줘도 안 먹음. 1성급이 5성급인 척 하는 느낌. 간만에 밥 먹고 기분 더럽., 평점 : 1, 날짜 : 2021.03.31.
# 리뷰코드 : GC000164, 가게코드 : STORE_GC0004, ID : obt6ck, 리뷰 : 돈 많이나올거 각오하고 가는 패밀리 고기 레스토랑, 평점 : 5, 날짜 : 2021.02.16.
# 리뷰코드 : GC000165, 가게코드 : STORE_GC0004, ID : bfk42a, 리뷰 : None, 평점 : 4, 날짜 : 2020.12.20.
# 리뷰코드 : GC000166, 가게코드 : STORE_GC0004, ID : akvbb1, 리뷰 : 가족 외식 하기 딱 좋은곳이에요.   비싼 소고기 말고 저렴한 돼지고기도 다 구워주시고,  반찬 무한 리필 해주시는 서비스에 감동했어요.   자주 오고 싶은 집입니다., 평점 : 5, 날짜 : 2020.11.22.
# 리뷰코드 : GC000167, 가게코드 : STORE_GC0004, ID : 1akflge, 리뷰 : 지인의 추천으로  남편 생일 축하겸...지난 7월31일 저녁에 방문하였습니다. 깨끗한 모습에 반했구요. 맛도 정말 맛있었습니다. 특히 직원들의 친절함이 너무나 감동 자체 였습니다., 평점 : 5, 날짜 : 2020.08.13.
# 리뷰코드 : GC000168, 가게코드 : STORE_GC0004, ID : 1auhdud, 리뷰 : 광고보고갔는데 별루.........., 평점 : 1, 날짜 : 2020.08.04.
# 리뷰코드 : GC000169, 가게코드 : STORE_GC0004, ID : 13lro7e, 리뷰 : 고기도 반찬도 다 맛있어요 주말이라서 그런지 좀 산만하고 정신 없긴한데 직원분들도 친절했구요 가족들 외식하러 가기 딱 좋습니다 입맛 까다로우신 저희 아부지도 맛있게 드셨어용 번창하세요, 평점 : 5, 날짜 : 2020.07.19.
# 리뷰코드 : GC000170, 가게코드 : STORE_GC0004, ID : bl1vvt, 리뷰 : 사람들 평점이 왜 이랬는지 알 것 같네요. 그날 응대하는 직원만 그런건지는 모르겠으나 구워줄 것처럼 두 테이블에 고기를 올려놓더니 늦게 와서 한우는 다 태워먹고, 핑계랍시고 다른 식사테이블들 대응하느라고 어쩔수 없었다고 합니다..계속 대응이 소홀할것 같아 고기도 우리가 굽겠다고 하고 가족모임이라 좋게좋게 넘어가려고 했는데 추가반찬이나 음료 등을 요청할때도 ..., 평점 : 1, 날짜 : 2020.07.12.
# 리뷰코드 : GC000171, 가게코드 : STORE_GC0004, ID : kb4m89, 리뷰 : 조금 아쉬워졌네요. 10년전부터 단골이었지만 고기하나만큼은 최고고 가격도 합리적이고 서비스도 좋아서 회식겸 자주갔던 곳인데. 시흥점이 문제인지는 모르겠습니다만. 고기에서 잡내가 생겼네요. 저는 향에 민감해서 아주 조금이라도 나면 잘 느끼긴 하지만 옛날에는 정말 맛있고 깔끔하고 푸짐했거든요. 국물은 그대로지만. 고기에서 약간 잡내가 납니다ㅜㅜ 아쉬웠어요. 서..., 평점 : 3, 날짜 : 2020.04.14.
# 리뷰코드 : GC000172, 가게코드 : STORE_GC0004, ID : f4bmj4, 리뷰 : 옮기고나서 너무 최악이 됐어요... 고기도 안좋아보이구 맛이 없어졌어요 직원들도 너무 불친절하고 우왕좌왕하더라구요 주차안내 해주시는 분이 제일 친절함....;; 옮기기전엔 꼬박꼬박 갔는데 이젠 안가렵니다...너무 최악의 경험이었어요, 평점 : 1, 날짜 : 2020.03.12.
# 리뷰코드 : GC000173, 가게코드 : STORE_GC0004, ID : 13n3fg9, 리뷰 : 옆에 신축빌딩으로 이전함 고기는 맛없고 서비스 엉망에 어른들 모시고 갔다가 난감함, 평점 : 1, 날짜 : 2020.01.14.
# 리뷰코드 : GC000174, 가게코드 : STORE_GC0004, ID : nb5cp8, 리뷰 : 완전 맛없음~~~ 한우고기를 먹었는데 곱창인줄!!!! 너무질기네요~~ , 평점 : 1, 날짜 : 2020.01.04.
# 리뷰코드 : GC000175, 가게코드 : STORE_GC0004, ID : nflj2q, 리뷰 : 고기도 맛있고 밑반찬도 다양하고 맛있어요 후식 과자와 차도 꿀맛, 평점 : 5, 날짜 : 2019.08.08.
# 리뷰코드 : GC000176, 가게코드 : STORE_GC0004, ID : me4ud3, 리뷰 : 주차넓고 발렛되는건 좋음. 그런데 직원교육을 제대로 시켜야할듯.. 가족끼리 5명이서 3층룸을 이용했음. 카카오맵에 나와있는 14000원 짜리 갈비시켰더니  주문받는 아주머니가 미.국.산 이요? 한돈말고 미.국.산 이요? 들리는 뉘앙스가 "비싸지만 맛있는 한돈안시키고 미국산갈비를 시키는게 맛나요?" 딱 이거였음. 네 그거주세요. 했고 음식이 나오고 직원아줌마..., 평점 : 1, 날짜 : 2018.09.23.
# 리뷰코드 : GC000177, 가게코드 : STORE_GC0004, ID : 10j07kd, 리뷰 : None, 평점 : 3, 날짜 : 2016.05.23.
# 리뷰코드 : GC000178, 가게코드 : STORE_GC0004, ID : 7kp6ed, 리뷰 : None, 평점 : 3, 날짜 : 2016.03.16.
# 리뷰코드 : GC000179, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.11.30.
# 리뷰코드 : GC000180, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.05.13.
# 리뷰코드 : GC000181, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 주차는 발래 파킹이며 뒷편에도 주차장이 있음 2층엔 아이들 놀수있는 공간도 있고 직원들도 친절함 아직 갈비탕만 먹어봐서 고기맛은 모르겠지만 갈비탕은 괜챦은편  아 정말 맛있어요 할정도는 아님 ㅋ 총점은 4.5정도 될거같음, 평점 : 5, 날짜 : 2018.04.20.
# 리뷰코드 : GC000182, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 2, 날짜 : 2018.03.04.
# 리뷰코드 : GC000183, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 5, 날짜 : 2018.02.19.
# 리뷰코드 : GC000184, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 2, 날짜 : 2017.02.04.
# 리뷰코드 : GC000185, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 시흥에서 외식할만 한 곳이 워낙 없어서 그중 제일~, 평점 : 3, 날짜 : 2017.01.29.
# 리뷰코드 : GC000186, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2017.01.13.
# 리뷰코드 : GC000187, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 3, 날짜 : 2016.08.22.
# 리뷰코드 : GC000188, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 1, 날짜 : 2016.08.16.
# 리뷰코드 : GC000189, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 2, 날짜 : 2016.07.26.
# 리뷰코드 : GC000190, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2016.05.09.
# 리뷰코드 : GC000191, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 우리가족모임은 무조건 여기. 예약필수. 사람엄청 많아서 정신없지만 직원들이 친절해서 기분좋게 먹고오는듯. 고기도 반찬도 맛있음 , 평점 : 4, 날짜 : 2016.05.03.
# 리뷰코드 : GC000192, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 시흥맛집감, 평점 : 5, 날짜 : 2016.04.28.
# 리뷰코드 : GC000193, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2016.04.16.
# 리뷰코드 : GC000194, 가게코드 : STORE_GC0004, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2016.03.15.
# 리뷰코드 : GC000195, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 좋음, 평점 : 4, 날짜 : 2016.03.15.
# 리뷰코드 : GC000196, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 갈비 먹었는데 맛괜찮은편인데 비싼듯함 참숯을 쓰지않아 좀 꺼림직함, 평점 : None, 날짜 : 2015.11.05.
# 리뷰코드 : GC000197, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 갈비탕, 평점 : None, 날짜 : 2015.08.27.
# 리뷰코드 : GC000198, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 갈비탕, 평점 : None, 날짜 : 2015.01.08.
# 리뷰코드 : GC000199, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 9000원갈비탕에 꼬기 듬뿍, 평점 : None, 날짜 : 2014.02.24.
# 리뷰코드 : GC000200, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 가끔가는 집 갈비탕에 갈비가 잔뜩 ㅎ2층엔 놀이방도 있음 1+1행사도  많이함, 평점 : None, 날짜 : 2013.09.16.
# 리뷰코드 : GC000201, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 갈비 맛나는곳!!!, 평점 : None, 날짜 : 2013.08.23.
# 리뷰코드 : GC000202, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 시흥맛집 갈비너무 맛있어요 ㅎ, 평점 : None, 날짜 : 2013.08.07.
# 리뷰코드 : GC000203, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 자주가는맛집!!, 평점 : None, 날짜 : 2013.08.06.
# 리뷰코드 : GC000204, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 돼지갈비, 평점 : None, 날짜 : 2013.08.05.
# 리뷰코드 : GC000205, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 갈비 갈비탕집, 평점 : None, 날짜 : 2013.06.09.
# 리뷰코드 : GC000206, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 갈비 맛나요ㅋ, 평점 : None, 날짜 : 2013.05.29.
# 리뷰코드 : GC000207, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 맛있음, 평점 : None, 날짜 : 2013.04.23.
# 리뷰코드 : GC000208, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 불친절~~고쳐주세용~!, 평점 : 1, 날짜 : 2017.12.26.
# 리뷰코드 : GC000209, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 맛있어요, 평점 : 5, 날짜 : 2017.07.16.
# 리뷰코드 : GC000210, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 여기 6년째 단골임. 서빙하는 아주머니들 무표정 하긴 해도 말안해도 열심히 반찬 가져다 주고 불판도 알아서 갈아 주고 친절한 편이에요. 주차도 편하고요. 단점 이라면 고기맛 평범과 시설 노후화를 들수있죠., 평점 : 4, 날짜 : 2016.06.26.
# 리뷰코드 : GC000211, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 맛은 맛있다 맛없다라고 평가는 둘째치고.. 점원들이 너무 불친절함... 자주가는 편은 아니지만.. 갈때마다 손님 무시하는거같고 자리에 앉기도 전에 무표정으로 대함. 손님 주문하는거에 귀 안기울릴꺼면 벨을 설치하던가..기분좋은날에 밥먹으러 갔다가 되려 기분나쁘게 나옴... 같이 간 가족이 한소리하니까 그제서야 찍소리 안하고 티안나는 친절베품, 평점 : 1, 날짜 : 2015.04.27.
# 리뷰코드 : GC000212, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 고기를 먹는내내  공기를 빨아들이는 곳에서  검은 기름이 쉴새없이  계속 떨어지고  식기는  제대로 씻지않아  남은음식이 묻어있고  정말 두번다시는 가고싶지 않고 저와같은경우를 당하실까 이렇게글을남깁니다, 평점 : 1, 날짜 : 2014.12.06.
# 리뷰코드 : GC000213, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 별하나  주기도 아까운곳입니다 점장부터가 손님알기를 우습게 알고  제가  여자라고  큰소리로 오히려 고객에게 화를 내더군요  신랑이 오고서야 미안하다며  억지사과를 하더군요 , 평점 : 1, 날짜 : 2014.12.06.
# 리뷰코드 : GC000214, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 두세번 이용한 입장에서 객관적으로 맛있거나 맛없다고 하기 힘듦, 그냥 평범히 어디서나 먹던 그런 음식맛.. 맛집이라 하기엔 글쎄고 ㅡㅡ; 가격도 대체적으로 평균.. 서비스는 개인적으로 최악. 작정한듯 늘 직원들 웃음은 전혀없고 돈쓰며 손님이 되려 기분상하고 불편함.. 반전은 정반대로 주차요원분들은 굉장히 친절함.. 아무튼 직접 가보고 각자 판단하시면 됨 !, 평점 : 2, 날짜 : 2014.10.17.
# 리뷰코드 : GC000215, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 갈비탕 짱 맛있습니다 ^.^ 엄마들 모임에 와서 갈비탕 먹어봤습니다! (전 전복갈비탕으로..>.<) 끝내줍니다!! 한 엄마가 여기 한돈양념구이가 맛있다고 아이들이 너무 좋아한다고 하니 주말에 가족들이랑 와봐야겠어요 !! 포인트카드 있으면 구이류 10%할인 해준다길래 오늘 만들었어요 ㅋㅋ 밑반찬도맛있고 언니들도 싹싹하고! 주말에 신랑이랑 아이랑 와야겠어요!, 평점 : 4, 날짜 : 2014.09.25.
# 리뷰코드 : GC000216, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 고기가 기가막히게 맛있고 ..  가격도 그정도면 괜찮았고~~ 9시이후에는 2+1까지..^^      강강술래 시흥점 만나게 먹고 갑니다, 탱큐~~~, 평점 : 5, 날짜 : 2014.09.25.
# 리뷰코드 : GC000217, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 강강술래 시흥점 ~~  너무 좋았어요~~  서빙하는 언니들 너무 친절하고  고기도 맛짱이구요  같이간  친구들이 너무 좋다며 좋은곳 알게 해주었다고 고맙데요~~강추에여^^^, 평점 : 5, 날짜 : 2014.09.24.
# 리뷰코드 : GC000218, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 정말 두번 다시 가고싶지않네요 소고기도 찔기고 꼴에 가격도 비싸 직원들도 너무 바빠서 뭐하나 더 달라고하기 미안하고 사장 장사 잘하고싶으면 손님 많을때 잘해라 좋은고기쓰고 정말 한우맞아 ?, 평점 : 1, 날짜 : 2013.01.27.
# 리뷰코드 : GC000219, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 다섯명이서 갔는데 테이블당 삼인분 이상씩 시켜야 반찬이던 불이던 두상을 차려주는 방침이 있나봐요. 많이 먹을 때만 가야 대접 받겠어요 ㅋ, 평점 : None, 날짜 : 2012.04.28.
# 리뷰코드 : GC000220, 가게코드 : STORE_GC0004, ID : None, 리뷰 : 시흥점 - 서비스 별로라는 글 읽고도 설마하고 아빠생신날갔다가 낭패봄. 반찬 갯수 적고.. 고기 알아서 구워 잘라서 먹어야함.. 모 달라고하면 3번이상 얘기해야함. 완전 셀프서비스. 서비스 저질 가격 너무높음, 평점 : 1, 날짜 : 2009.08.11.
# no review in crawling
# 가게코드 : STORE_GC0005, 가계명 : 도원, 주소 : 서울 금천구 범안로 1130 디지털엠파이어빌딩 101호, 지역 : (지번) 가산동 685, 종류 : 뷔페
# #### 도원
# 리뷰코드 : GC000221, 가게코드 : STORE_GC0005, ID : 8nuc8n, 리뷰 : 칸막이는 없어도 사람들 음식 풀때 마스크 쓰라고는 하는거 보면 개선된듯함. 성남에서 멀리까지 찾아갔는데 성남점 있다는걸 가서 알았네 ㅋㅋ, 평점 : 5, 날짜 : 2021.08.14.
# 리뷰코드 : GC000222, 가게코드 : STORE_GC0005, ID : benk3h, 리뷰 : 가격 대비 퀄리티 좋은 중식뷔페입니다., 평점 : 5, 날짜 : 2021.08.04.
# 리뷰코드 : GC000223, 가게코드 : STORE_GC0005, ID : 16jsnri, 리뷰 : 오늘갓다왓는데 둥네앵간한 곳보다 맛납니다 혼자 오신 분들이.많더라구요 배불러서 많이 못먹은게.아쉽 ㅜㅜ, 평점 : 5, 날짜 : 2021.06.01.
# 리뷰코드 : GC000224, 가게코드 : STORE_GC0005, ID : muldnn, 리뷰 : 맛은 있다 없다 얘기하는게 별 의미가 없는 것 같습니다. 여러가지 중식을 가성비있게 먹을 수 있어 좋긴 합니다.  하지만 플라스틱 칸막이도 없이 거리두기하지 않고 손님을 받고 있고 손님들이 마스크를 쓰지 않고 음식을 받으러 돌아다녀도 별 말이 없습니다.   저녁시간 바쁜 건 알지만 인간적으로 코로나 상황에 갈 식당은 못된다고 봅니다.  제발 제가 간 날 코..., 평점 : 1, 날짜 : 2021.04.25.
# 리뷰코드 : GC000225, 가게코드 : STORE_GC0005, ID : 1itm3vi, 리뷰 : None, 평점 : 2, 날짜 : 2021.04.24.
# 리뷰코드 : GC000226, 가게코드 : STORE_GC0005, ID : 12bdjlk, 리뷰 : 가보고싶으니 저장, 평점 : 5, 날짜 : 2021.04.22.
# 리뷰코드 : GC000227, 가게코드 : STORE_GC0005, ID : shohe8, 리뷰 : 별점 가본후 수정 예정/ 푸디랜드 독산 중식 무한리필 9,900 , 평점 : 3, 날짜 : 2021.04.22.
# 리뷰코드 : GC000228, 가게코드 : STORE_GC0005, ID : 14neucb, 리뷰 : 여기 다좋은데 일주일마다바뀌는 식단 어디 공지해주는데 없나요?, 평점 : 5, 날짜 : 2021.04.21.
# 리뷰코드 : GC000229, 가게코드 : STORE_GC0005, ID : litmd4, 리뷰 : 부자에요?, 평점 : 5, 날짜 : 2021.04.18.
# 리뷰코드 : GC000230, 가게코드 : STORE_GC0005, ID : tmj512, 리뷰 : 솔직히다른거는 다 SoSo인데 근데 중국냉면이 진짜 너무 맛있었음 그것먼 한5그릇먹은거같음 하여튼 중국냉면 때문에 재방문의사 있음., 평점 : 5, 날짜 : 2021.03.19.
# 리뷰코드 : GC000231, 가게코드 : STORE_GC0005, ID : 1foqgvr, 리뷰 : 최고의 중국집이에요 정말이지 가성비만큼은 최고에요!!!, 평점 : 5, 날짜 : 2021.02.13.
# 리뷰코드 : GC000232, 가게코드 : STORE_GC0005, ID : 7oblob, 리뷰 : 전반적으로 일반 중화요리 메뉴를 주문해서 먹는 정도의 퀄리티를 유지, 생면에는 짜장을 부어 먹는 게 일반 짜장면 한그릇 시켜먹는 것에 가장 근접함. 특히 찹쌀탕수육이 뛰어남. 가장 맛있게 먹으려면 한번에 많이 먹지 말고 조금씩 천천히 먹다가 새로 리필되는 음식들을 공략하는 것을 추천., 평점 : 5, 날짜 : 2021.02.06.
# 리뷰코드 : GC000233, 가게코드 : STORE_GC0005, ID : n1dn9l, 리뷰 : 중식뷔페, 평점 : 5, 날짜 : 2020.12.26.
# 리뷰코드 : GC000234, 가게코드 : STORE_GC0005, ID : 7mnj6e, 리뷰 : 맛은 좋고 음식 나오는 거 신경은 잘 써주시는 거는 감사한데.. 아무리 코로나 때문에 손님이 줄었다고 해도 더러운 손님은 관리 좀 해주셨으면 합니다. 마스크는 둘 째치고 음식푸고 집어먹고 손가락 빨고 그 손으로 다음 음식 푸고 계속 집어먹으면서 음식 푸는데 사장님께서 신경 안 쓰시면 누가씁니까 ㅠ 양심 나가려다 본 거 아님 손님이랑 싸웠음;, 평점 : 4, 날짜 : 2020.12.04.
# 리뷰코드 : GC000235, 가게코드 : STORE_GC0005, ID : gh3ohn, 리뷰 : 여러가지 중화요리 먹고싶어서 갔어요. 탕수육은 좀 빠삭한편이고 깐풍기도 바로 나온건 맛있어요. 짬뽕은 뜨거웠고 채소육수맛이 많이나고 건더기 많이 먹을수 있어서 괜찮았어요, 평점 : 4, 날짜 : 2020.11.20.
# 리뷰코드 : GC000236, 가게코드 : STORE_GC0005, ID : 12smutv, 리뷰 : 주인이 바꼈는지 모르겠는데 최악이었어요ㅡㅡ, 평점 : 1, 날짜 : 2020.11.06.
# 리뷰코드 : GC000237, 가게코드 : STORE_GC0005, ID : 1cr19ba, 리뷰 : None, 평점 : 5, 날짜 : 2020.10.16.
# 리뷰코드 : GC000238, 가게코드 : STORE_GC0005, ID : 127ln5n, 리뷰 : 볶음밥 퀄 최고, 평점 : 5, 날짜 : 2020.08.19.
# 리뷰코드 : GC000239, 가게코드 : STORE_GC0005, ID : fmakhc, 리뷰 : 탕수육 딱딱함. 잡채류는 별로. 짜장과 만두는 괜찮고  면이 불지 않게 조금씩 내주는 건 좋음. 그릇 셀프반납은 불편함.  서빙도 셀프인데 치우는 것까지 셀프라니 패스트푸드도 아니고 뷔페같지 않아서 만족도 떨어짐. 과식할 수 있는 사람에겐 가성비 있고 아니면 그냥 맛있는 단품 있는 중국집 가세요., 평점 : 2, 날짜 : 2020.07.16.
# 리뷰코드 : GC000240, 가게코드 : STORE_GC0005, ID : 17tb12c, 리뷰 : None, 평점 : 5, 날짜 : 2020.04.20.
# 리뷰코드 : GC000241, 가게코드 : STORE_GC0005, ID : gpcr0f, 리뷰 : 여러가지 먹고 싶으신분은 최고입니다 .. 어설픈 체인점 중국집 보다 맛은 있네요, 평점 : 5, 날짜 : 2020.04.15.
# 리뷰코드 : GC000242, 가게코드 : STORE_GC0005, ID : eau193, 리뷰 : 열자마자 마구 먹을 자신 있던가, 볶음밥 9천원 내고 드시려면 가세요., 평점 : 1, 날짜 : 2020.04.11.
# no review in crawling
# 가게코드 : STORE_GC0006, 가계명 : 쌍교숯불갈비 서울금천점, 주소 : 서울 금천구 시흥대로 435 1층, 지역 : (지번) 독산동 152-3, 종류 : 한식
# #### 쌍교숯불갈비 서울금천점
# 리뷰코드 : GC000243, 가게코드 : STORE_GC0006, ID : ndsuk7, 리뷰 : 단골이에요~ 넓게 넓게 다른 손님이랑 떨어뜨려 자리 잡아주시고 친절하고 맛있습니다. 구워서 나와서 좋아요. 아이랑 가기 좋습니다., 평점 : 5, 날짜 : 2021.08.14.
# 리뷰코드 : GC000244, 가게코드 : STORE_GC0006, ID : 1j85cf4, 리뷰 : 아이와함께하기좋아요. 냉면은비추, 평점 : 5, 날짜 : 2021.07.20.
# 리뷰코드 : GC000245, 가게코드 : STORE_GC0006, ID : uqh3f1, 리뷰 : 정말 맛있고 떡갈비가 엄청 부드러워요, 평점 : 5, 날짜 : 2021.07.16.
# 리뷰코드 : GC000246, 가게코드 : STORE_GC0006, ID : f77kv6, 리뷰 : 맛있어요 반찬도 맛나고 떡갈비랑 돼지갈비 시켰는데 다 구워서 나오고 맛있어요 진짜, 평점 : 5, 날짜 : 2021.07.11.
# 리뷰코드 : GC000247, 가게코드 : STORE_GC0006, ID : 10ibn7p, 리뷰 : 지인짜 맛난집!, 평점 : 5, 날짜 : 2021.06.28.
# 리뷰코드 : GC000248, 가게코드 : STORE_GC0006, ID : 126l72h, 리뷰 : 갈비구이>>갈비찜, 평점 : 5, 날짜 : 2021.06.28.
# 리뷰코드 : GC000249, 가게코드 : STORE_GC0006, ID : qs9353, 리뷰 : 깔끔하고 맛있어요, 평점 : 4, 날짜 : 2021.06.25.
# 리뷰코드 : GC000250, 가게코드 : STORE_GC0006, ID : ae72me, 리뷰 : 너무 맛있어요. 인터넷으로 주문해서도 먹어봤는데 역시 직접 가서 먹는 게 최고입니다., 평점 : 5, 날짜 : 2021.06.10.
# 리뷰코드 : GC000251, 가게코드 : STORE_GC0006, ID : 17orsg2, 리뷰 : 들깨수제비가 맛있어요. 저는 떡갈비보다 돼지양념갈비가 더 맛있는데 그거랑 들깨수제비 먹으면 짱이에요~~, 평점 : 5, 날짜 : 2021.05.31.
# 리뷰코드 : GC000252, 가게코드 : STORE_GC0006, ID : 1ju7v0r, 리뷰 : None, 평점 : 3, 날짜 : 2021.05.24.
# 리뷰코드 : GC000253, 가게코드 : STORE_GC0006, ID : r3f7t5, 리뷰 : 갈비찜 먹었는데 맛있고 직원들도 친절했어요, 평점 : 4, 날짜 : 2021.05.09.
# 리뷰코드 : GC000254, 가게코드 : STORE_GC0006, ID : 12p3llk, 리뷰 : 고기가 엄청 맛있고 직원 분들이 너무 친절하세요, 평점 : 5, 날짜 : 2021.01.04.
# 리뷰코드 : GC000255, 가게코드 : STORE_GC0006, ID : 1cr19ba, 리뷰 : None, 평점 : 4, 날짜 : 2020.10.16.
# 리뷰코드 : GC000256, 가게코드 : STORE_GC0006, ID : m6aa75, 리뷰 : 2020.07.26 아버지 생신 점심시간 방문  이번이 2번째 방문   첫 방문때는 떡갈비 + 돼지갈비를 먹었는데 떡갈비는 별로 돼지갈비가 더 좋음 (근데 점심행사로 떡갈비는 11,000원 행사준 정가 15.000원)  이번에는 돼지갈비로만 4인분주문, 냉면땡겨서 냉면하나 추가, 공기밥 1개추가 참고로 이곳은 들깨수제비가 맛있음 양도많고 이건 무조건 주문해..., 평점 : 3, 날짜 : 2020.07.26.
# 리뷰코드 : GC000257, 가게코드 : STORE_GC0006, ID : 9vl8i1, 리뷰 : None, 평점 : 3, 날짜 : 2020.07.26.
# 리뷰코드 : GC000258, 가게코드 : STORE_GC0006, ID : qq1acr, 리뷰 : 밑 반찬은 샐러드 포함 여섯 가지로 무난했지만, 인삼 갈비탕이라고 인삼 작은 것 하나는 들어가겠지 했는데  갈아서 넣으시는 듯한 크기를 받아서   일반 갈비탕이라면 별 3개였는데 한 개를 더 지웠습니다.  일반 갈비탕 집(11000~13000)이랑 크게 다르지 않고  뼈랑 잘 분리 안되는 뼈 하나하고 부드러운 고기 두 덩어리 나왔습니다.  당면은 굵고, 맛..., 평점 : 3, 날짜 : 2020.07.25.
# 리뷰코드 : GC000259, 가게코드 : STORE_GC0006, ID : 1945c9n, 리뷰 : 전라도에서 소문난 맛집 다운 맛 이네용~~~ 고기도 다 구워져서 나오고, 직원분들이 잘라주셔서 편하게 먹을 수 있었습니다! 밑반찬도 푸짐하고, 매운갈비, 소갈비 둘다 맛있었어요!! 강추합니다~~~~, 평점 : 5, 날짜 : 2020.06.12.
# 리뷰코드 : GC000260, 가게코드 : STORE_GC0006, ID : e43orj, 리뷰 : 고향 생각으로 지인들과 찾아갔으나 데스크 관리도 안되고 서버와 주방간에 손발도 안맞고 맛은 광주의 60-65%정도의 맛을 내는 식당 결론은 식당이 인건비를 절감하고자 했는지 적은 서버의 수로 감당이 안되는 테이블 관리를 하여 광주에서의 명성을 그야말로 여기서 다 깍아먹음... 그리고 고기는 사진 하단부분처럼이물질(주문표로 사료됨)이 있었으나 잘 제거하지 못..., 평점 : 1, 날짜 : 2020.05.09.
# 리뷰코드 : GC000261, 가게코드 : STORE_GC0006, ID : e8m2ot, 리뷰 : 일단 광주 지역에서 먹어본 적이 있어서 믿고 갔습니다. 역시 명불허전 맛있고 퀄리티 좋네요. 아!! 한가지 팁으로 중*나라 카페에서 검색하면 가끔 상품권 구할 수 있더군요 덕분에 조금 더 할인받고 기분좋게 먹었습니다. 또 이용할듯, 평점 : 5, 날짜 : 2020.04.29.
# 리뷰코드 : GC000262, 가게코드 : STORE_GC0006, ID : 13cus12, 리뷰 : 레알찐 맛집........ 안양사는데 갈막혀서 저녁이나 먹고 가자 했는데 길막혀줌에 감사! 담에 또 올란당!! , 평점 : 5, 날짜 : 2020.03.10.
# 리뷰코드 : GC000263, 가게코드 : STORE_GC0006, ID : kb4m89, 리뷰 : 밑반찬이며 고기가 더할나위없이 맛있습니다. 정갈하고 깔끔합니다. 매운 돼지갈비는 보통이예요. 그냥 돼지갈비가 맛있습니다. 구워져나오니 몸에 냄새밸일도 없고 매우 좋았습니다. 서비스도 좋고~ 5점, 평점 : 5, 날짜 : 2020.02.29.
# 리뷰코드 : GC000264, 가게코드 : STORE_GC0006, ID : ert7ek, 리뷰 : 친구랑 몇번갔는데 맛있어서 자주갈것같아요, 평점 : 5, 날짜 : 2020.02.23.
# 리뷰코드 : GC000265, 가게코드 : STORE_GC0006, ID : 13ghmts, 리뷰 : 가족들 모두 너무 만족하고 먹고 왔어요~~, 평점 : 5, 날짜 : 2019.10.23.
# 리뷰코드 : GC000266, 가게코드 : STORE_GC0006, ID : 13it978, 리뷰 : 지방 사는데 가끔 서울에 일 때문에 올라오면 일부러 찾아가서 먹는 곳. 밑반찬 정갈하고 깔끔함. 몇달만에 다시 왔더니 계절별로 밑반찬이 조금씩 달라지는거 같다(저번엔 해초쌈이 없었는데 이번엔 해초쌈이 생김). 주차도 편리하고 식당도 청결, 서빙여사님들도 매우 친절하심. 기회가 되면 담양본점도 가보고싶네요~, 평점 : 5, 날짜 : 2019.10.20.
# 리뷰코드 : GC000267, 가게코드 : STORE_GC0006, ID : beqb6k, 리뷰 : 전라도에서 갈비로 탑찍으셨다길래 기대하고 방문했는데요,맛이 없는건 아니지만 고기가 쫄깃한 식감도 없고 퍽퍽합니다. 밑반찬들은 정갈하게 맛있게 나오구요.. 가격을 쫌더 받더라도 고기를 쫌더 좋은걸 쓰시면좋을듯해요.., 평점 : 2, 날짜 : 2019.09.02.
# 리뷰코드 : GC000268, 가게코드 : STORE_GC0006, ID : 10u13ut, 리뷰 :  밑반찬 완전 다양하고 고기도 넘맛있어용 배부른데 들깨수제비가 존맛보스라길래 또먹었는데 아주 뚝딱 비워버림,,,;;;직원분들도 넘 친절하고 가게도 깨끗해서 좋았어용, 평점 : 5, 날짜 : 2019.08.08.
# 리뷰코드 : GC000269, 가게코드 : STORE_GC0006, ID : 7tldqg, 리뷰 : 밑반찬은 맛있는데 정작 갈비맛은 별로에요, 평점 : 3, 날짜 : 2019.07.20.
# no review in crawling
# 가게코드 : STORE_GC0007, 가계명 : 농장사람들, 주소 : 서울 금천구 벚꽃로 316 C&S타워 1층, 지역 : (지번) 가산동 777, 종류 : 육류,고기
# #### 농장사람들
# 리뷰코드 : GC000270, 가게코드 : STORE_GC0007, ID : 14lp7vt, 리뷰 : 넓은 공간,  친절한  서비스,  무엇보다 맛있는  소고기가 특히  좋았어요..가족  모임이라  시끌시끌했었는데  한결같이  친절했어요... 안심은  너무  부드러워  맛있었구요  채끝등심또한  너무  맛있게  먹었네요  후식  비빔냉면은  역시  매콤하면서  감칠맛  더할것없이  맛있는  식사였어요..., 평점 : 5, 날짜 : 2020.09.20.
# 리뷰코드 : GC000271, 가게코드 : STORE_GC0007, ID : 14u8ikd, 리뷰 : 넘나 맛있고 퀄히티도좋고 가성비굳!!!! 한우가 이가격에?, 평점 : 5, 날짜 : 2019.12.19.
# 리뷰코드 : GC000272, 가게코드 : STORE_GC0007, ID : 132utf4, 리뷰 : 굳굳, 평점 : 5, 날짜 : 2019.12.15.
# 리뷰코드 : GC000273, 가게코드 : STORE_GC0007, ID : 10jq375, 리뷰 : 부모님모시는 자리라 깔끔하고 맛좋은집찾다가 우연히 방문했는데 고기가 너무 맛있고!! 알바분들도 친절하셔서 기분좋게 먹고왔네요~^^!! 자주갈거같아요 ㅎㅎ, 평점 : 5, 날짜 : 2019.12.14.
# 리뷰코드 : GC000274, 가게코드 : STORE_GC0007, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.08.08.
# 리뷰코드 : GC000275, 가게코드 : STORE_GC0007, ID : None, 리뷰 : 고기맛은 보통입니다. 상차림비 5천원이 있으니... 많이 먹는 사람들한테 좋은 장소 같아요. , 평점 : 3, 날짜 : 2018.08.08.
# no review in crawling
# 가게코드 : STORE_GC0008, 가계명 : 순댕이네얼큰수제비, 주소 : 서울 금천구 시흥대로136길 1, 지역 : (지번) 독산동 160-17, 종류 : 수제비
# #### 순댕이네얼큰수제비
# 리뷰코드 : GC000276, 가게코드 : STORE_GC0008, ID : 124tggd, 리뷰 : 2021년 8월5일 방문했는데 개인적인사정에 의하여 하루쉽니다 라고붙어있음... 그래서 8월6일 다시 가볼라고 전화햇더니 안받음... 다시 확인차 전화햇더니 수신거부걸어놈.. 직원두명이 다 수신거부걸려서 전화만 걸면 통화중으로 나옴...내가 확인차 전화햇더니 전화가 걸림... 맛을떠나서 이런 인성을 가진사람들이 만드는 음식은 먹으면안됨!!!   전화받아서 ..., 평점 : 1, 날짜 : 2021.08.06.
# 리뷰코드 : GC000277, 가게코드 : STORE_GC0008, ID : 1j85cf4, 리뷰 : 줄서서먹을정도아님, 평점 : 3, 날짜 : 2021.07.05.
# 리뷰코드 : GC000278, 가게코드 : STORE_GC0008, ID : uqts70, 리뷰 : 아줌마 병원입원 갔다가 헛탕, 평점 : 2, 날짜 : 2021.06.19.
# 리뷰코드 : GC000279, 가게코드 : STORE_GC0008, ID : 12k9u82, 리뷰 : 맛은..좋은데 위생이 최악이에요 바닥에 떨어진 면을..물에 씻어서 넣는걸 보았음.., 평점 : 2, 날짜 : 2021.05.19.
# 리뷰코드 : GC000280, 가게코드 : STORE_GC0008, ID : 12980mk, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.13.
# 리뷰코드 : GC000281, 가게코드 : STORE_GC0008, ID : 1g4ncut, 리뷰 : 최고예요, 평점 : 5, 날짜 : 2021.05.07.
# 리뷰코드 : GC000282, 가게코드 : STORE_GC0008, ID : lm821e, 리뷰 : 얼큰말고 일반 바지락칼국수나 수제비에 청양고추다진거 넣어드세요. 겉절이가 예술임.  할머니 손가락 관절때문에 수술로 한동안 휴업, 그이후 일찍 퇴근하시네요.  완쾌하시고 쉬엄쉬엄 하세요. , 평점 : 5, 날짜 : 2021.05.06.
# 리뷰코드 : GC000283, 가게코드 : STORE_GC0008, ID : kid818, 리뷰 : 얼큰은 진짜...반은 남겼음. 걍 고추장 엄청 푼 맛이라 텁텁하고.. 바지락이 그나마 평타치는것 같았는데, 특별하게 와맛있다 할 정도는 아님! 조개도 뭐..자잘자잘해서 많다는게 메리트인지도 모르겠고.. 동네에 있으니까 가는데 웨이팅이 많다니 (난 없었지만) 또 갈지는 모르겠당, 평점 : 2, 날짜 : 2021.04.05.
# 리뷰코드 : GC000284, 가게코드 : STORE_GC0008, ID : 7nao21, 리뷰 : None, 평점 : 3, 날짜 : 2021.03.18.
# 리뷰코드 : GC000285, 가게코드 : STORE_GC0008, ID : vmuvgv, 리뷰 : 친절을 찾아볼 수 없음, 평점 : 1, 날짜 : 2021.02.24.
# 리뷰코드 : GC000286, 가게코드 : STORE_GC0008, ID : 1ef4rdt, 리뷰 : 너무 늦어요  시스템 개선이 필요한듯요  한번은 가는데 두번가기는 좀.., 평점 : 1, 날짜 : 2021.02.22.
# 리뷰코드 : GC000287, 가게코드 : STORE_GC0008, ID : fa8e15, 리뷰 : 맛은 인정!  근데 줄 오래 서야되고 음식 나오는데 너무 오래걸려서 거의 두시간은 잡고 먹으러가야함ㅜ 옆에 주차할 곳도 마땅치 않아서 굉장히 불편., 평점 : 3, 날짜 : 2020.12.27.
# 리뷰코드 : GC000288, 가게코드 : STORE_GC0008, ID : 8ucgi1, 리뷰 : None, 평점 : 3, 날짜 : 2020.11.25.
# 리뷰코드 : GC000289, 가게코드 : STORE_GC0008, ID : mteabq, 리뷰 : 20번 정도 방문한 동네사람입니다. 바지락이 많아 사람들이 늦게 먹어서 회전이 느리다기보다 주방에서 조리시간이 좀 느린것 같은데 이집을 좋아하는 동네사람으로서 그 느린 조리가 맛의 비결일거라 추측해봅니다. 3대천왕 방송전에 친구를 몇번 데려갔으나 웨이팅 없이 주문하고 바로 앉아 기다려도 1시간 기다린적도 있는데 아무래도 기다릴만큼의 맛이 아니라는게 다들 의..., 평점 : 5, 날짜 : 2020.06.07.
# 리뷰코드 : GC000290, 가게코드 : STORE_GC0008, ID : 13146i2, 리뷰 : 평일 1시간 주말2시간 기다려야한다는 큰 단점... 하지만 바지락을 엄청 넣어서 국물이 시원하고 맛도 인위적인 조미료의 매운맛이아닌 고추에서 나오는듯한 맵고 얼큰한맛이 좋다. 칼국수 면이랑 수제비도 수타라 쫄깃함...밑에 많은 사람들이 국물이 텁텁하다는데 실제로 그렇다. 국물이 깔끔하지않고 살짝 텁텁하긴하다. 개인적으론 텁텁함이 심하다고 생각하지 않지만 조..., 평점 : 4, 날짜 : 2020.05.19.
# 리뷰코드 : GC000291, 가게코드 : STORE_GC0008, ID : csgujd, 리뷰 : 이집은 맛보다도 바지락 껍질을 산처럼  쌓으며 먹는 퍼포먼스로 인기몰이 하는 듯 바지락을 많이 주니까 바지락 까먹는 시간이 오래걸려서 테이블 회전율이 떨어지고 다음 손님들은 줄을 오래 서게 되는데 한번쯤은 몰라도 두번은 안가게 됨, 평점 : 3, 날짜 : 2020.05.02.
# 리뷰코드 : GC000292, 가게코드 : STORE_GC0008, ID : 109442r, 리뷰 : 테이블회전율도 낮고 ㅜ  대기시간+테이블앉아서30분 해서 2시간30분넘게 기다린것같음 ㅠㅠㅠ  얼큰보다 오히려 바지락이 더 맛남 얼큰은 고추장맛남 , 평점 : 3, 날짜 : 2020.05.01.
# 리뷰코드 : GC000293, 가게코드 : STORE_GC0008, ID : ghki4k, 리뷰 : 맛이 없는건 아닌데  굳이 줄까지 서서 먹을 수준은 아님  한번정도는 먹어볼만함, 평점 : 3, 날짜 : 2020.04.03.
# 리뷰코드 : GC000294, 가게코드 : STORE_GC0008, ID : 8v9geb, 리뷰 : 별 한개도 아까움, 근처라도 절대 가지마셈. 텁텁한 국물떡볶이에 잠긴 넓다란 밀가루 반죽, 굵은 밀가루 반죽임. 바지락양은 많으나 모래 씹히고 절대 웨이팅할 맛집이 아님. 차라리 청와삼대 가산점 장터칼국수가 백배 맛있슴., 평점 : 1, 날짜 : 2020.02.26.
# 리뷰코드 : GC000295, 가게코드 : STORE_GC0008, ID : mvh6pp, 리뷰 : 최고였어요, 평점 : 5, 날짜 : 2019.10.28.
# 리뷰코드 : GC000296, 가게코드 : STORE_GC0008, ID : apa0io, 리뷰 : 웨이팅 항상 있는 것 같은데.. 따로 번호표 부여해주시는 건 아니고 얼굴 기억하시고 불러주시는 것 같아요 한 시간 정도 기다리면 된다해서 다른데 볼일 보고 왔는데 30분은 더 기다렸고 음식나오는데도 15분이상은 걸리더라구요...저는 칼제비 시켰는데 얼큰은 맵기만 해요...싱겁구요 그리고 무엇보다 수제비건 칼국수건 다 뿔어서 나왔어요.. 쫄깃함도 없고..기다..., 평점 : 1, 날짜 : 2019.10.10.
# 리뷰코드 : GC000297, 가게코드 : STORE_GC0008, ID : vmigjq, 리뷰 : None, 평점 : 2, 날짜 : 2019.08.15.
# 리뷰코드 : GC000298, 가게코드 : STORE_GC0008, ID : nflj2q, 리뷰 : 맛있어서 부모님과 자주갑니다, 평점 : 5, 날짜 : 2019.08.08.
# 리뷰코드 : GC000299, 가게코드 : STORE_GC0008, ID : uq501a, 리뷰 : 별하나도 아까움. 밑에분들이 얘기한것처럼 시스템 문제로 한두시간 기다리는거지 손님이많은건 아님. 근데 열받는건 일부로 그렇게 운영을 한다는거죠.그냥 시간 남아도는 사람들은 가보세요., 평점 : 1, 날짜 : 2019.04.20.
# 리뷰코드 : GC000300, 가게코드 : STORE_GC0008, ID : btm5qv, 리뷰 : 떡뽀끼국물에 칼국수 말은느낌  텁텁해서 안감, 평점 : 1, 날짜 : 2019.04.19.
# 리뷰코드 : GC000301, 가게코드 : STORE_GC0008, ID : v3gshk, 리뷰 : 맛은있는데 혼자가면 잘안줌, 평점 : 4, 날짜 : 2019.03.17.
# 리뷰코드 : GC000302, 가게코드 : STORE_GC0008, ID : u3pbv1, 리뷰 : 방문3번째만에 먹음.  일단 주문 먼저 하세요. 그러면 주문받고 기다리시면 됩니다. 간혹 일부 손님이 번호표 안주냐? 어떻게 누가 먼저온지 아냐? 물어보십니다. 저도 그랬고요. 근데 주문 받을실때 주문하신분의 특징을 기록하고 순서에 맞게 안내해 주셨어요. 깜짝놀랐습니다. 친철하게요. 웨이팅이 너무 길어서 불평하시고 보진 못한 손님이 먼저 앉으면 이게 뭐야~..., 평점 : 5, 날짜 : 2019.02.01.
# 리뷰코드 : GC000303, 가게코드 : STORE_GC0008, ID : 7kaa7i, 리뷰 : 여긴 절대안가요 주말에 줄서서 평일날 방문했는데 평일도 한시간반 기다려야겠더라구요 시스템 문제인것 같아요 여긴절대 안가는걸로요, 평점 : 1, 날짜 : 2018.12.22.
# 리뷰코드 : GC000304, 가게코드 : STORE_GC0008, ID : ssnvg6, 리뷰 : 식당 회전률이 거지같습니다. 다시는 오기 싫을정도. 웨이팅이 너무 깁니다. 앞 2팀만 있었을뿐인데 1시간 이상 걸리네요. 뭐 엄청 대단한 음식먹는것도 아닌데 무~~~~지 오래 걸립니다. 시간아깝고 정말 다시는 찾아가고 싶지 않아요. 1점도 아까워요~  방송 타이틀값으로 배짱장사ㅋㅋ 서비스 기대마세요. 공짜 공기밥?? 그만큼 웨이팅값으로 당연한 값입니다. 진..., 평점 : 1, 날짜 : 2018.11.29.
# 리뷰코드 : GC000305, 가게코드 : STORE_GC0008, ID : a53hdo, 리뷰 : None, 평점 : 3, 날짜 : 2018.09.22.
# 리뷰코드 : GC000306, 가게코드 : STORE_GC0008, ID : beetb0, 리뷰 : None, 평점 : 4, 날짜 : 2018.07.21.
# 리뷰코드 : GC000307, 가게코드 : STORE_GC0008, ID : ldk523, 리뷰 : 더럽게 오래 걸리고 바지락도 오래되서 껍질붙어 있는거  걍 매운걸로 밀어붙이는데 예전 5천원이면 메리트 있지만 지금은 전혀 아 글고 혼자가면 잘안줌ㅋ, 평점 : 1, 날짜 : 2018.02.09.
# 리뷰코드 : GC000308, 가게코드 : STORE_GC0008, ID : 7kp6ed, 리뷰 : None, 평점 : 4, 날짜 : 2017.05.23.
# 리뷰코드 : GC000309, 가게코드 : STORE_GC0008, ID : 10j07kd, 리뷰 : 평일인데도  한시간 기다리다 먹었다.얼큰칼제비 면발은 보통 바지락이  싱싱하고  양이  많아 국물도  시원하다.좀 매운편 , 평점 : 3, 날짜 : 2017.03.20.
# 리뷰코드 : GC000310, 가게코드 : STORE_GC0008, ID : 104ba8h, 리뷰 : 칼제비 /칼국수 얼큰보다 바지락이 더 먹을만한거 같다., 평점 : 2, 날짜 : 2016.10.12.
# 리뷰코드 : GC000311, 가게코드 : STORE_GC0008, ID : bkmq24, 리뷰 : 백종원. 얼큰 칼국수. , 평점 : 2, 날짜 : 2016.10.03.
# 리뷰코드 : GC000312, 가게코드 : STORE_GC0008, ID : None, 리뷰 : None, 평점 : 5, 날짜 : 2018.12.30.
# 리뷰코드 : GC000313, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 줄을 쓰는건 늦게 만들어서... 절대 한시간 기다릴 집 아님 쓸데없이 추천좀 하지 마시더, 평점 : 1, 날짜 : 2018.09.29.
# 리뷰코드 : GC000314, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 너무비싸요 김치도 너무짜요, 평점 : 1, 날짜 : 2018.09.04.
# 리뷰코드 : GC000315, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 5대5, 평점 : 3, 날짜 : 2018.07.27.
# 리뷰코드 : GC000316, 가게코드 : STORE_GC0008, ID : None, 리뷰 : None, 평점 : 5, 날짜 : 2018.05.03.
# 리뷰코드 : GC000317, 가게코드 : STORE_GC0008, ID : None, 리뷰 : None, 평점 : 5, 날짜 : 2018.02.11.
# 리뷰코드 : GC000318, 가게코드 : STORE_GC0008, ID : None, 리뷰 : None, 평점 : 5, 날짜 : 2017.09.07.
# 리뷰코드 : GC000319, 가게코드 : STORE_GC0008, ID : None, 리뷰 : None, 평점 : 3, 날짜 : 2017.04.02.
# 리뷰코드 : GC000320, 가게코드 : STORE_GC0008, ID : None, 리뷰 : None, 평점 : 5, 날짜 : 2016.10.20.
# 리뷰코드 : GC000321, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 3대천왕 얼큰칼제비 @, 평점 : 4, 날짜 : 2016.09.25.
# 리뷰코드 : GC000322, 가게코드 : STORE_GC0008, ID : None, 리뷰 : None, 평점 : 5, 날짜 : 2016.05.09.
# 리뷰코드 : GC000323, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 일욜일엔 하지도않구 ㅜㅜ 평일에도 일찍 닫아서... 토욜밖에없는데 ! 점심때가면 웨이팅 기본 한시간 ㅜㅜㅜㅜㅜ 근데 넘 맛있어서 계속 가게되요 ㅎㅎ, 평점 : 5, 날짜 : 2016.04.23.
# 리뷰코드 : GC000324, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 정말 쵝오 바지락 끝판왕, 평점 : 5, 날짜 : 2016.03.29.
# 리뷰코드 : GC000325, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 저렴한가격의 푸짐한양 맛최고 얼큰 칼제비 바지락이 너무 푸짐해서 바지락만 고르는데 10분걸릴정도 한가지 유일한 단점은 웨이팅이 길다는거 자리에 앉기도 힘들지만 앉아서도 15-20분기다려야 한다는게 힘듬, 평점 : None, 날짜 : 2015.05.28.
# 리뷰코드 : GC000326, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 아침일찍오픈하자마자오니 손님이 너무많이오네여 바지락 먹다 지쳤어여~~, 평점 : None, 날짜 : 2015.05.07.
# 리뷰코드 : GC000327, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 기다리는건   무조건 한시간이상인데  먹고나면 절대 후회 안해요ㅋ, 평점 : None, 날짜 : 2014.06.10.
# 리뷰코드 : GC000328, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 20130929.2주째 물먹었다 문 닫았는지 운영하는걸 못봤다, 평점 : None, 날짜 : 2013.09.29.
# 리뷰코드 : GC000329, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 방문하기~~, 평점 : None, 날짜 : 2013.08.24.
# 리뷰코드 : GC000330, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 바지락 정말 많은 맛집!! 1시간 대기라는게 함정이지만 푸짐하다. 재료가 떨어지면 문 닫는곳~~^^, 평점 : None, 날짜 : 2013.08.15.
# 리뷰코드 : GC000331, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 자리가협소 미리가서줄서세요, 평점 : None, 날짜 : 2013.08.08.
# 리뷰코드 : GC000332, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 바지락이 듬뿍! 얼큰한 국물~, 평점 : None, 날짜 : 2013.08.07.
# 리뷰코드 : GC000333, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 여긴 줄서서먹어야하는곳~~ 미리전화하면 포장도됩니당~~, 평점 : None, 날짜 : 2013.04.20.
# 리뷰코드 : GC000334, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 얼큰칼제비 굿~~!!, 평점 : None, 날짜 : 2013.04.17.
# 리뷰코드 : GC000335, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 영업시간 저녁에는 안하네요 헛걸음 했습니다. , 평점 : 1, 날짜 : 2018.03.23.
# 리뷰코드 : GC000336, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 오늘 먹고왔어요사람 진짜 많네요 오픈시간에 갔는데도 ㅎㅎ사업 번창하세요 맛있어요~^^, 평점 : 5, 날짜 : 2016.09.27.
# 리뷰코드 : GC000337, 가게코드 : STORE_GC0008, ID : None, 리뷰 : 얼큰하고 개운한 맛과 모래 안씹히는 신선한 바지락의 어마어마한 양 거기에 겉절이까지 강추!, 평점 : 5, 날짜 : 2013.09.06.
# no review in crawling
# 가게코드 : STORE_GC0009, 가계명 : 김사부샤브샤브, 주소 : 서울 금천구 가산로 132, 지역 : (지번) 가산동 145-24, 종류 : 샤브샤브
# #### 김사부샤브샤브
# 리뷰코드 : GC000338, 가게코드 : STORE_GC0009, ID : cv14b8, 리뷰 : 훈둔 맛나요 꿔바로우  ㅠㅠ 크기는커요 볶음밥  쌀알이 뭉쳐있어요, 평점 : 2, 날짜 : 2021.08.14.
# 리뷰코드 : GC000339, 가게코드 : STORE_GC0009, ID : nvn8qn, 리뷰 : 꿔바로우 JMT 볶음면도 맛있음, 기대 안 했는데 이국적으로 매콤함 코로나 위생도 잘 지키심, 평점 : 4, 날짜 : 2021.08.06.
# 리뷰코드 : GC000340, 가게코드 : STORE_GC0009, ID : 1682m90, 리뷰 : 오랫동안 방문하고 싶은데 그냥그랬어요. 제가 묻고 싶은 게 있었지만 직원이 한국어 못 알아들어서 상황이 안 좋았어요. 설명하지 못하고 제가 추가 인분을 주문하고 싶었지만 결국 나갔어요. , 평점 : 2, 날짜 : 2021.07.20.
# 리뷰코드 : GC000341, 가게코드 : STORE_GC0009, ID : kmqmrt, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.30.
# 리뷰코드 : GC000342, 가게코드 : STORE_GC0009, ID : f15gk7, 리뷰 : 다른건 그냥 평타정도 근데 꿔바로우 진짜 여태껏 먹은것 중에 제일 맛있어서 이마 빡빡침 , 평점 : 4, 날짜 : 2021.05.29.
# 리뷰코드 : GC000343, 가게코드 : STORE_GC0009, ID : 18bqja1, 리뷰 : 너무 맛있는 음식 종업원분들과 약간 소통이 안되는 것 말고는 좋았어요!, 평점 : 4, 날짜 : 2021.02.14.
# 리뷰코드 : GC000344, 가게코드 : STORE_GC0009, ID : mteabq, 리뷰 : 벨이 의미가 없을 정도로 누르고 기다리고 누르고 기다리고 3번 반복하는데 기분 좀 별로더라구요.(벨눌러도 안오심ㅋㅋ) 손님에 비해 직원수가 좀 적어보였고. 10분넘게 기다리다 손흔들어 불러서 주문 겨우하고 마라상궈 재료 담는 바구니 끈적끈적.. 에고.. 나가고싶지만 일단 먹어보자 ㅋ 꿔바로우 마라샹궈 먹을만 했어요. 정말 중국사람들이 좋아하는 맛인지 중국인..., 평점 : 2, 날짜 : 2021.02.11.
# 리뷰코드 : GC000345, 가게코드 : STORE_GC0009, ID : 113r6bc, 리뷰 : 꿔바로우항 마라샹궈 진짜 최고 조합, 평점 : 5, 날짜 : 2021.01.28.
# 리뷰코드 : GC000346, 가게코드 : STORE_GC0009, ID : mausq1, 리뷰 : 짱맛있아요  담에도 가야겠어요. 중국인 입맛에 맞아요, 평점 : 5, 날짜 : 2020.12.27.
# 리뷰코드 : GC000347, 가게코드 : STORE_GC0009, ID : tvs86r, 리뷰 : 마라탕 1단계+꿔바로우 미친 조합; 꿔바로우 존맛탱ㅠㅠ, 평점 : 5, 날짜 : 2020.12.23.
# 리뷰코드 : GC000348, 가게코드 : STORE_GC0009, ID : e4iomp, 리뷰 : 마라샹궈 1단계에 꿔바로우 그리고 칭따오는 행복으로 가는 지름길입니다, 평점 : 5, 날짜 : 2020.12.12.
# 리뷰코드 : GC000349, 가게코드 : STORE_GC0009, ID : 1404e00, 리뷰 : None, 평점 : 5, 날짜 : 2020.11.29.
# 리뷰코드 : GC000350, 가게코드 : STORE_GC0009, ID : mva17m, 리뷰 : 꿔바로우 쥰맛탱 인정, 평점 : 4, 날짜 : 2020.11.22.
# ...
# 리뷰코드 : GC001188, 가게코드 : STORE_GC0037, ID : fch5di, 리뷰 : 차돌짬뽕...여기 진심 맛집입니다 ㄷㄷㄷ, 평점 : 5, 날짜 : 2020.08.13.
# 리뷰코드 : GC001189, 가게코드 : STORE_GC0037, ID : vs1ivj, 리뷰 : 맛, 서비스 별로. 특히 서비스가 너무 별로. 혼자라고 하니 태도가 확달라짐., 평점 : 1, 날짜 : 2020.07.07.
# 리뷰코드 : GC001190, 가게코드 : STORE_GC0037, ID : ghd8jt, 리뷰 : 차돌짬뽕은 짬뽕이 아니라 거의 국밥같은 느낌이에요. 육수가 걸쭉할 정도로 진하게 우러났습니다. 개인적으론 해물짬뽕이 정말 맛있었어요., 평점 : 4, 날짜 : 2020.06.30.
# 리뷰코드 : GC001191, 가게코드 : STORE_GC0037, ID : mr5ucd, 리뷰 : None, 평점 : 4, 날짜 : 2020.05.31.
# 리뷰코드 : GC001192, 가게코드 : STORE_GC0037, ID : 13146i2, 리뷰 : 긴말 필요없고 짬뽕 매니아라면 꼭 먹어봐야할 식당중 한곳이라 생각함, 평점 : 5, 날짜 : 2020.05.19.
# 리뷰코드 : GC001193, 가게코드 : STORE_GC0037, ID : 17je9nu, 리뷰 : 차돌짬뽕 진짜 맛있어요.. 어느 정도 믿음이 있는 집이냐면요, 몇주전에 이사오고나서 주변탐방하는데, 웬 남자분이 저랑 같이 한참을 걸어갔거든요? 그렇게 한참을 걸어서 들어가신 곳이 여기였어요. 이렇게 멀어도 걸어오게 만드는 맛집이구나 싶어서 얼른 따라들어가서 포장해왔는데 진짜 존맛탱. 제 동생 여기 짬뽕맛보고선 해장하러 서울오고싶어 할 정도로 맛있어요(부산..., 평점 : 5, 날짜 : 2020.04.27.
# 리뷰코드 : GC001194, 가게코드 : STORE_GC0037, ID : 17e4mjf, 리뷰 : 차돌짬뽕 미칩니다 진짜 개 맛있어요ㅠㅠ 집 앞이라 일주일에 네번은 갑니다  이거 먹으면 홍콩반점 짬뽕 절대 못먹음ㅋㅋㅋㅋ, 평점 : 5, 날짜 : 2020.03.31.
# 리뷰코드 : GC001195, 가게코드 : STORE_GC0037, ID : 17e43k9, 리뷰 : 매콤! 한 해물짬뽕이 매일 먹어도 질리지가 않네요 면은탱글탱글하고, 찐한 국물맛이 정말맛있어요 매운거 싫어하시는분들은 미리말씀해주시면 맵기도조절해준다네요! 너무맛집으로 소문나면 웨이팅이 있을까봐걱정네요ㅠ 짬뽕하면 생각나는 혼자만 알고싶은맛집입니다, 평점 : 5, 날짜 : 2020.03.31.
# 리뷰코드 : GC001196, 가게코드 : STORE_GC0037, ID : gehppu, 리뷰 : 진짜 맛있어요, 평점 : 5, 날짜 : 2020.03.18.
# 리뷰코드 : GC001197, 가게코드 : STORE_GC0037, ID : 15phbcc, 리뷰 : 근방 짬뽕중 원탑, 평점 : 5, 날짜 : 2020.01.26.
# 리뷰코드 : GC001198, 가게코드 : STORE_GC0037, ID : 13rc0g3, 리뷰 : 맛이 변하지 않고 늘 얼큰하고 국물이 매우 깊어서 얼큰한거 땡길때면 찾아가는 곳!! 면도 직접 만든 거라 그런지 국물과 면이 굉장히 잘어울림!! 굿굿!!!, 평점 : 5, 날짜 : 2020.01.07.
# 리뷰코드 : GC001199, 가게코드 : STORE_GC0037, ID : 158jke6, 리뷰 : 최근 먹은 짬뽕중 최고였습니다. 메뉴를 다양하게 시키면 오래걸린다고 써있었는데 실제로 오래걸리긴 합니다 ㅜ 근처가면 또 방문할 생각이예요!, 평점 : 5, 날짜 : 2020.01.02.
# 리뷰코드 : GC001200, 가게코드 : STORE_GC0037, ID : ba9vaf, 리뷰 : 여기서 짬뽕 먹고는 일반 중국집에서 못 먹겠어요 ㅠㅠ 깊은맛 국물맛 짱이고 건더기도 엄청 푸짐히 주세요~♡♡♡ 미리 끓여놓는 짬뽕이랑은 비교할 수 없다는.. 주문하면 조리하는거라 시간은 좀 걸릴 수 있어도 훨 맛있어요!!!, 평점 : 5, 날짜 : 2020.01.02.
# 리뷰코드 : GC001201, 가게코드 : STORE_GC0037, ID : 14tgsu3, 리뷰 : 이근방에서 제일 맛있는 짬뽕집이라고 생각해요. 양도 푸짐하고 가성비 좋고. 주변에 오면 한번 들를만합니다., 평점 : 4, 날짜 : 2019.12.19.
# 리뷰코드 : GC001202, 가게코드 : STORE_GC0037, ID : qli2o8, 리뷰 : 맛대가리업던데.. 다알바인가..홍콩반점이나음.. 국물도밍하고 먹어보몬암, 평점 : 1, 날짜 : 2019.11.01.
# 리뷰코드 : GC001203, 가게코드 : STORE_GC0037, ID : f11jjo, 리뷰 : 일반 중국집 짬뽕과 다른맛 아줌마가 TV싫어해서 안킴 켜달라면 짜증냄에 3점, 평점 : 3, 날짜 : 2019.08.06.
# 리뷰코드 : GC001204, 가게코드 : STORE_GC0037, ID : s9pha3, 리뷰 : 확실한 불맛 넉넉한 건더기. 꼭 밥말아드세요. 면에는 깊은 국물맛이 충분히 묻어있지가 않아서 좀 아쉬운데, 밥은 다 빨아들여서 맛있네요. 그리고 밥시키면 엄청많이주십니다. , 평점 : 4, 날짜 : 2019.08.05.
# 리뷰코드 : GC001205, 가게코드 : STORE_GC0037, ID : o95di2, 리뷰 : 다음에 또 오고 싶은맛이네요, 평점 : 5, 날짜 : 2018.11.29.
# 리뷰코드 : GC001206, 가게코드 : STORE_GC0037, ID : bkmq24, 리뷰 : 짬뽕 먹어본 중 최고인듯.  가깝다면 매일 오고싶음.  돼지짬뽕 5.5, 평점 : 5, 날짜 : 2018.04.11.
# 리뷰코드 : GC001207, 가게코드 : STORE_GC0037, ID : gk3uv0, 리뷰 : 저도 짬뽕중에 최고라고 생각함. 특히 차돌짬뽕 너무 좋아요 ^^, 평점 : 5, 날짜 : 2018.04.10.
# 리뷰코드 : GC001208, 가게코드 : STORE_GC0037, ID : None, 리뷰 : 짬뽕을 이틀 연속 먹기는 처음이네요 ^^ 첫날에는 차돌 둘쨋날은 돼지ㅎ 진짜 맛나요 ^^ , 평점 : 5, 날짜 : 2018.11.11.
# 리뷰코드 : GC001209, 가게코드 : STORE_GC0037, ID : None, 리뷰 : 돼지짬뽕밥. 차돌짬뽕밥 최고!! 난 안양살지만 짬뽕먹으러 간다, 평점 : 5, 날짜 : 2018.10.12.
# 리뷰코드 : GC001210, 가게코드 : STORE_GC0037, ID : None, 리뷰 : 혼자가면 눈치주고 기본 물도 안줌 혼자가는 사람은 그냥 가지 마세요 서빙하는 아줌마가 눈치 오지게 주고 싫어하는 티 엄청 냄 맛이고 뭐고 다시는 안감, 평점 : 1, 날짜 : 2018.10.14.
# no review in crawling
# 가게코드 : STORE_GC0038, 가계명 : 슈케익하우스, 주소 : 서울 금천구 시흥대로63길 3, 지역 : (지번) 시흥동 121, 종류 : 음식점
# #### 슈케익하우스
# 리뷰코드 : GC001211, 가게코드 : STORE_GC0038, ID : 1hvak9n, 리뷰 : 조카생일이라서 생일 케이크 예약하러갔습니다. 주문할때 부터 제가 예약한날 케이크예약이 많다고 달력을 확인하더라구요 제가원하는케이크에 대해  얘기하는데  일반케이크 아니고 주문케이크라 돈 추가 된다는얘기만 하시더라구요 레터링도 몇자가 들어가고  얼마가 추가되는지도 말안해줘서 제가 레터링 못 넣으냐 물어보니 그제서야 10자이상 2천원이라 하더군요 제가말한거에 ..., 평점 : 2, 날짜 : 2021.03.28.
# 리뷰코드 : GC001212, 가게코드 : STORE_GC0038, ID : ms2qv4, 리뷰 : 밤에 늦게 갔는데 친절하게 맞아주시고 급하게 딸기케익주문했는데 완전 딸기가 난리가 나요~~!!! 이동네 주민은아닌데 지나는길에 들렸는데 너무 좋은기분을 들게 해주셨어요~~^-^ 1주년축하드려용, 평점 : 5, 날짜 : 2021.03.13.
# 리뷰코드 : GC001213, 가게코드 : STORE_GC0038, ID : 1d1ua3b, 리뷰 : Best, 평점 : 5, 날짜 : 2020.10.24.
# no review in crawling
# 가게코드 : STORE_GC0039, 가계명 : 니하우, 주소 : 서울 금천구 벚꽃로38길 32-43, 지역 : (지번) 가산동 83-1, 종류 : 양꼬치
# #### 니하우
# 리뷰코드 : GC001214, 가게코드 : STORE_GC0039, ID : 9e3ja6, 리뷰 : 맛있는데.. 사람이너무많아서.. 주문이 밀려요.., 평점 : 3, 날짜 : 2021.07.01.
# 리뷰코드 : GC001215, 가게코드 : STORE_GC0039, ID : 126kre5, 리뷰 : None, 평점 : 3, 날짜 : 2021.06.30.
# 리뷰코드 : GC001216, 가게코드 : STORE_GC0039, ID : 14cum87, 리뷰 : 시간 넘쳐나는 분 가세요 양꼬치에 숯 나오는데 40분 걸리는 양꼬치집은 처음 봅니다 진짜 어이가 없어서 너무 오래 기다린 거 같다고 하니까 순서대로 나오는 거라고 하네요 순서 40분 기다리실 분 가세요 참고로 옆테이블은 저희 다 먹을 때까지 안나왔어요  무슨 장작 패서 숯 만드는 줄 알았네 어이가 없어 아니 쓰다보니가 화나네 30분 기다리고 밑반찬 받아서 ..., 평점 : 1, 날짜 : 2021.05.21.
# 리뷰코드 : GC001217, 가게코드 : STORE_GC0039, ID : mp5qra, 리뷰 : 육즙도 많고 가격도 적당하고 가게 외관 내부 모두 깔끔하고 멋있다. 넓어서 모임하거나 적당히 거리두고 먹기도 좋음!, 평점 : 5, 날짜 : 2020.12.18.
# 리뷰코드 : GC001218, 가게코드 : STORE_GC0039, ID : qtdph6, 리뷰 : 가게가 정말 깨끗하고 양꼬치 초보자도 거부감없이 먹을 만큼 잡내가 없어요 , 평점 : 5, 날짜 : 2020.10.23.
# 리뷰코드 : GC001219, 가게코드 : STORE_GC0039, ID : sjqr6h, 리뷰 : 넘버 원 양꼬치집 양꼬치도 요리도 너무맛있고, 자극적이지 않아 계속 들어가요 ˓◞˂̵, 평점 : 5, 날짜 : 2020.10.09.
# 리뷰코드 : GC001220, 가게코드 : STORE_GC0039, ID : 7o7hq7, 리뷰 : 더할나위 없었다..., 평점 : 5, 날짜 : 2020.02.29.
# 리뷰코드 : GC001221, 가게코드 : STORE_GC0039, ID : d9f73l, 리뷰 : None, 평점 : 5, 날짜 : 2020.01.21.
# 리뷰코드 : GC001222, 가게코드 : STORE_GC0039, ID : v6idjt, 리뷰 : 맛있다, 평점 : 5, 날짜 : 2020.01.02.
# 리뷰코드 : GC001223, 가게코드 : STORE_GC0039, ID : ae05i4, 리뷰 : 구석에 있지만 가게 깨끗하구요 조용하고  ☆양꼬치 넘 마싯습니다☆ 서비스로 나온 마파두부도 맛있었구요 옥면우육면도 정말 맛있어서 두 번 먹었어요. 소주 땡기는 맛..., 평점 : 5, 날짜 : 2019.09.25.
# 리뷰코드 : GC001224, 가게코드 : STORE_GC0039, ID : 11ppmbt, 리뷰 : 양꼬치 풍미가 다른 곳 보다 더 좋은 느낌? 뭔진 모르겠는데 더 맛있었어요! 가게도 깨끗하고 넓고 게다가 물 맛집 맥주 맛집, 평점 : 5, 날짜 : 2019.07.29.
# 리뷰코드 : GC001225, 가게코드 : STORE_GC0039, ID : 10os6pc, 리뷰 : 양꼬치집 많지만 비린맛없구 고기상태도 좋았던거 같음 양고기 첨먹는 남친도 반한곳, 평점 : 4, 날짜 : 2019.07.14.
# 리뷰코드 : GC001226, 가게코드 : STORE_GC0039, ID : 11h3tk6, 리뷰 : 양고기 입문자도 여기서 시작하면 양고기 좋아할것 같아요 매우 맛있게 잘먹었어요!, 평점 : 4, 날짜 : 2019.07.14.
# 리뷰코드 : GC001227, 가게코드 : STORE_GC0039, ID : qfn4ci, 리뷰 : None, 평점 : 4, 날짜 : 2019.01.18.
# 리뷰코드 : GC001228, 가게코드 : STORE_GC0039, ID : 7ljjeg, 리뷰 : 맛 괜춘 가게도 넓고 깨끗한듯, 평점 : 5, 날짜 : 2018.09.19.
# 리뷰코드 : GC001229, 가게코드 : STORE_GC0039, ID : fntgif, 리뷰 : 이동네에서 다같이 회식하기엔 제일 좋은 장소입니다. 위치가 다소 찾기 힘들수도 있으나 깔끔하고 사장님도 친절하시네요. , 평점 : 5, 날짜 : 2018.02.28.
# 리뷰코드 : GC001230, 가게코드 : STORE_GC0039, ID : 10d6b2g, 리뷰 : 양꼬치/양갈비 맛은 괜찮은데 양념이 강한 느낌 금방타기 때문에 불조절이 좀 번거롭다. 가지튀김은 다른 중국집처럼 조림스탈이 아니라 문자그대로 가지안에 소를 넣어 튀긴 형태. 많이 먹긴 부담스럽지만 여럿이 가면 먹어보길 추천, 평점 : 3, 날짜 : 2017.12.25.
# 리뷰코드 : GC001231, 가게코드 : STORE_GC0039, ID : None, 리뷰 : None, 평점 : 2, 날짜 : 2017.07.02.
# 리뷰코드 : GC001232, 가게코드 : STORE_GC0039, ID : None, 리뷰 : 마라탕 강추, 평점 : 4, 날짜 : 2017.07.01.
# 리뷰코드 : GC001233, 가게코드 : STORE_GC0039, ID : None, 리뷰 : None, 평점 : 3, 날짜 : 2016.11.20.
# 리뷰코드 : GC001234, 가게코드 : STORE_GC0039, ID : None, 리뷰 : None, 평점 : 3, 날짜 : 2016.07.09.
# 리뷰코드 : GC001235, 가게코드 : STORE_GC0039, ID : None, 리뷰 : 퇴근 후에 동료들하고 한잔하기 좋은곳이네요...ㅋㅋ 분위기도 좋구요.., 평점 : 5, 날짜 : 2016.09.08.
# 리뷰코드 : GC001236, 가게코드 : STORE_GC0039, ID : None, 리뷰 : 잡내도 안나고 양고기가 넘나 맛있어요, 평점 : 5, 날짜 : 2016.08.30.
# 리뷰코드 : GC001237, 가게코드 : STORE_GC0039, ID : None, 리뷰 : 재방문 의사 100   친절하고  맛있어요  ㅎㅎ  퇴근하고  딱입니다~~, 평점 : 5, 날짜 : 2016.08.29.
# no review in crawling
# 가게코드 : STORE_GC0040, 가계명 : 스튜디오레이크, 주소 : 서울 금천구 디지털로 210 지하 1층, 지역 : (지번) 가산동 140-26, 종류 : 카페
# #### 스튜디오레이크
# 리뷰코드 : GC001238, 가게코드 : STORE_GC0040, ID : 15ejn78, 리뷰 : 조아욤 자주 가요 와인 많이 시키면 사장님이 서비스도 자주 줘서 조아욤, 평점 : 5, 날짜 : 2021.05.31.
# 리뷰코드 : GC001239, 가게코드 : STORE_GC0040, ID : r6q0o1, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.21.
# 리뷰코드 : GC001240, 가게코드 : STORE_GC0040, ID : eolfu3, 리뷰 : 치킨 맛있고 분위기 좋아요! 다음에는 와인 마시러 또 가게요, 평점 : 5, 날짜 : 2021.04.17.
# 리뷰코드 : GC001241, 가게코드 : STORE_GC0040, ID : bf1m77, 리뷰 : 분위기맛집 템프라닐로가 있어서 좋았다, 평점 : 5, 날짜 : 2020.10.08.
# 리뷰코드 : GC001242, 가게코드 : STORE_GC0040, ID : u6uq98, 리뷰 : 분위기에 취한ㄷr...☆ 와인을 잘 안먹는 사람도 가면 반할 분위기에요., 평점 : 5, 날짜 : 2020.06.26.
# no review in crawling
# 가게코드 : STORE_GC0041, 가계명 : 노브랜드버거 가산디지털단지점, 주소 : 서울 금천구 벚꽃로 286 삼성리더스타워 1층 109호, 지역 : (지번) 가산동 60-15, 종류 : 패스트푸드
# #### 노브랜드버거 가산디지털단지점
# 리뷰코드 : GC001243, 가게코드 : STORE_GC0041, ID : 7kvkpk, 리뷰 : 버거하고 감튀 둘다 무난하게 맛있음, 평점 : 5, 날짜 : 2021.08.12.
# 리뷰코드 : GC001244, 가게코드 : STORE_GC0041, ID : 15ti57b, 리뷰 : 여기 버거 맛있습니다. 다른거 말고 기본인, 불고기버거 드세요. 그게 가장 맛있습니다. 이제 전, 여기서 불고기버거 4개 먹고, 옆집 커피 맛집인 맥도날드 갑니다., 평점 : 4, 날짜 : 2021.07.27.
# 리뷰코드 : GC001245, 가게코드 : STORE_GC0041, ID : o30mi4, 리뷰 : 매장이 너무 지저분..., 평점 : 2, 날짜 : 2021.05.14.
# 리뷰코드 : GC001246, 가게코드 : STORE_GC0041, ID : 7lo5s7, 리뷰 : 호기심에 한 번 가봤는데 다시 안갈 듯. 가성비 안나오고 매장 내 환기가 안되서 기름냄새 쩐다..., 평점 : 2, 날짜 : 2021.05.13.
# 리뷰코드 : GC001247, 가게코드 : STORE_GC0041, ID : r8ac8e, 리뷰 : 딱 그 가격에서 기대할 수 있는 정도의 퀄리티와 양입니다. 음식은 나쁘지 않았는데.... 오늘만 유독 심했던건지는 몰라도 매장 안에 기름 탄냄새가 엄청많이 나더라구요, 평점 : 3, 날짜 : 2021.04.06.
# 리뷰코드 : GC001248, 가게코드 : STORE_GC0041, ID : qnn895, 리뷰 : 노브랜드라고해서 가성비 생각하면 실패봅니다. 의외로 가산에는 맛집이 많아서 그런가 특색을 못느꼈습니다.  버거가 원래 짜고 달고 느끼하고겠지만 여긴 유독 짜다고 생각이 들더라고요.., 평점 : 2, 날짜 : 2021.02.26.
# 리뷰코드 : GC001249, 가게코드 : STORE_GC0041, ID : 17vb4ta, 리뷰 : 깔끔하고 친절합니다, 평점 : 5, 날짜 : 2020.09.03.
# 리뷰코드 : GC001250, 가게코드 : STORE_GC0041, ID : mv6ato, 리뷰 : 뒤틀린 황천의 손가락 파이 , 평점 : 1, 날짜 : 2020.08.29.
# 리뷰코드 : GC001251, 가게코드 : STORE_GC0041, ID : 7kmnub, 리뷰 : None, 평점 : 5, 날짜 : 2020.08.23.
# 리뷰코드 : GC001252, 가게코드 : STORE_GC0041, ID : nu8ut1, 리뷰 : 미쳤음 대존맛탱. 양파 풍성히 들고 토마토도 들고 소스 풍성히 들고 패티 두툼 육즙 맛있는데 단품이 2,900₩임 더 싼 것도 있음 1,900₩, 평점 : 5, 날짜 : 2020.07.12.
# 리뷰코드 : GC001253, 가게코드 : STORE_GC0041, ID : n1adub, 리뷰 : 먹고 배탈 나서 다니지도 못하고 집가서 앓아누웠어요, 평점 : 1, 날짜 : 2020.05.05.
# 리뷰코드 : GC001254, 가게코드 : STORE_GC0041, ID : 11hee27, 리뷰 : None, 평점 : 4, 날짜 : 2020.05.03.
# no review in crawling
# 가게코드 : STORE_GC0042, 가계명 : 우리소양평해장국 본점, 주소 : 서울 금천구 범안로 1244, 지역 : (지번) 독산동 1035-1, 종류 : 해장국
# #### 우리소양평해장국 본점
# 리뷰코드 : GC001255, 가게코드 : STORE_GC0042, ID : 1iq4808, 리뷰 : 양선지가 진짜 맛잇어요, 평점 : 5, 날짜 : 2021.05.15.
# 리뷰코드 : GC001256, 가게코드 : STORE_GC0042, ID : e4m52f, 리뷰 : 정말 맛집입니다. 코로나로 밤 10시에 영업이 끝나니 참고하세요 ㅎㅎ, 평점 : 5, 날짜 : 2021.04.17.
# 리뷰코드 : GC001257, 가게코드 : STORE_GC0042, ID : v0e2u8, 리뷰 : 양선지 괜찮네~, 평점 : 3, 날짜 : 2020.12.13.
# 리뷰코드 : GC001258, 가게코드 : STORE_GC0042, ID : 1ar91or, 리뷰 : 양선지해장국 맛있어서 3일연속가는중, 평점 : 5, 날짜 : 2020.10.21.
# 리뷰코드 : GC001259, 가게코드 : STORE_GC0042, ID : csgujd, 리뷰 : 술먹은 다음날 해장하기 좋은 메뉴들이 많음, 평점 : 3, 날짜 : 2020.05.26.
# 리뷰코드 : GC001260, 가게코드 : STORE_GC0042, ID : 168mc68, 리뷰 : 한우모듬전골 맛있게 잘 먹고왔어요!, 평점 : 5, 날짜 : 2020.04.04.
# 리뷰코드 : GC001261, 가게코드 : STORE_GC0042, ID : kid818, 리뷰 : 백년묵은 소로 만드는듯한 소등뼈감자탕 고기로 집지어도 될정도로 튼튼해요^0^b 싫어하는사람이있다면 암살용으로 먹이기좋아요, 평점 : 1, 날짜 : 2019.08.28.
# 리뷰코드 : GC001262, 가게코드 : STORE_GC0042, ID : uut0t7, 리뷰 : 맛없습니다 소뼈라고는 하는데 맛도없고 퍽퍽하구요 중자소뼈감자탕에 감자반개들어갔네여... 국물도 별로구요 전 다신여기 안오기로 했습니다, 평점 : 2, 날짜 : 2019.08.28.
# 리뷰코드 : GC001263, 가게코드 : STORE_GC0042, ID : eqqu2p, 리뷰 : 맛있고 푸짐하고 친절합니다.  겉절이 김치가 진짜 맛있어요., 평점 : 5, 날짜 : 2018.05.15.
# 리뷰코드 : GC001264, 가게코드 : STORE_GC0042, ID : None, 리뷰 : 가성비대비 서울안에 이만한 해장국집 찾기 힘든 곳, 평점 : 3, 날짜 : 2018.05.03.
# 리뷰코드 : GC001265, 가게코드 : STORE_GC0042, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.02.04.
# 리뷰코드 : GC001266, 가게코드 : STORE_GC0042, ID : None, 리뷰 : 일부러 찾아갈 맛은 아닙니다. 평범하나 친절해서 별하나 더 추가 합니다, 평점 : 3, 날짜 : 2017.12.11.
# 리뷰코드 : GC001267, 가게코드 : STORE_GC0042, ID : None, 리뷰 : 워낙 양평해장국을 좋아해서 여기저기 돌아다니며 즐겨먹는데 여기만큼 가격싸고 맛있고 양도 만족 할 만한데는 못 가봤음 ㅋ 가성비 최고입니다. , 평점 : 5, 날짜 : 2017.06.10.
# 리뷰코드 : GC001268, 가게코드 : STORE_GC0042, ID : None, 리뷰 : 소머리수육&소머리해장국, 평점 : 5, 날짜 : 2016.10.09.
# no review in crawling
# 가게코드 : STORE_GC0043, 가계명 : 동산미, 주소 : 서울 금천구 가산디지털2로 138-1, 지역 : (지번) 가산동 458-31, 종류 : 육류,고기
# #### 동산미
# 리뷰코드 : GC001269, 가게코드 : STORE_GC0043, ID : 13n9n4j, 리뷰 : 돼지고기 냄새나고 삼겹살 일인분양이 진짜 적습니다 평범한사람 4명이 배채우려면 6인분은 시켜야되요, 평점 : 1, 날짜 : 2021.04.30.
# 리뷰코드 : GC001270, 가게코드 : STORE_GC0043, ID : 196q0m0, 리뷰 : 서비스 정말 최악입니다. 새우만 따로 주문 된다길래 새우 따로 주문했더니 못알아듣고 안주시고, 다시 달라 하니깐 원래 말씀하신 마리수 보다 2마리 덜 주시더군요. 여기까진 뭐 실수할 수 있겠다 싶었는데 마지막에 볶음밥 주문했는데 하도 안나오길래 주문 들어갔냐고 여쭤보니 주문 안하지 않았냐고, 주문할때 무슨볶음밥 먹을지 물어보셨으면서 책임을 저희한태 덮어 씌..., 평점 : 1, 날짜 : 2021.04.01.
# 리뷰코드 : GC001271, 가게코드 : STORE_GC0043, ID : glt7ll, 리뷰 : 갑오징어 & 삼겹살 조합 너무 괜찮았고요~ 반찬으로 나오는 콩나물파채무침 대박; 총 3접시를 먹음;;;; -_-;;;;; 마무리 볶음밥은 필수~~  < 연탄초벌삼겹살 동산미 > 2020/07/16 (목) 2인 동산미스페셜2 ￦29,000 ( 갑오징어 + 삼겹살 ) 삼겹살 1인분 추가 ￦12,000 동산미칡냉면 ￦5,000 ( 후식볶음밥 서비스 ) 총합계 ￦..., 평점 : 5, 날짜 : 2020.07.21.
# 리뷰코드 : GC001272, 가게코드 : STORE_GC0043, ID : None, 리뷰 : 해물철판볶음밥 점심으로 딱. 가끔씩!, 평점 : 3, 날짜 : 2016.04.11.
# 리뷰코드 : GC001273, 가게코드 : STORE_GC0043, ID : None, 리뷰 : 맛있어욜~, 평점 : None, 날짜 : 2013.09.05.
# 리뷰코드 : GC001274, 가게코드 : STORE_GC0043, ID : None, 리뷰 : 최고의 맛집 꼭 함께가요, 평점 : 5, 날짜 : 2011.11.29.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-3c885a308bbd> in search(place, local)
#     228
# --> 229                 crawling(place, local, place_lists)
#     230
#
# <ipython-input-1-3c885a308bbd> in crawling(place, local, place_lists)
#     301                 idx += 1
# --> 302             driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 5페이지가 넘는 경우 다음 버튼 누르기
#     303
#
# AttributeError: 'NoneType' object has no attribute 'send_keys'
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-1-3c885a308bbd> in <module>
#     439 #### 메인 ####
#     440 if __name__ == "__main__":
# --> 441     main()
#
# <ipython-input-1-3c885a308bbd> in main()
#     175
#     176         local = read_local_code(place)
# --> 177         search(place, local)
#     178         create_csv_file(place)
#     179
#
# <ipython-input-1-3c885a308bbd> in search(place, local)
#     238
#     239         finally:
# --> 240             search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')
#     241             search_area.clear()
#     242
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     429         """
#     430         warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# --> 431         return self.find_element(by=By.XPATH, value=xpath)
#     432
#     433     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1092         return self.execute(Command.FIND_ELEMENT, {
#    1093             'using': by,
# -> 1094             'value': value})['value']
#    1095
#    1096     def find_elements(self, by=By.ID, value=None):
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response['value'] = self._unwrap_value(
#     349                 response.get('value', None))
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     238                 alert_text = value['alert'].get('text')
#     239             raise exception_class(message, screen, stacktrace, alert_text)
# --> 240         raise exception_class(message, screen, stacktrace)
#     241
#     242     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=92.0.4515.131)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00EB3733+2504499]
# 	Ordinal0 [0x00E4C401+2081793]
# 	Ordinal0 [0x00D52628+1058344]
# 	Ordinal0 [0x00D3BF86+966534]
# 	Ordinal0 [0x00D97B59+1342297]
# 	Ordinal0 [0x00DA4392+1393554]
# 	Ordinal0 [0x00D95D4B+1334603]
# 	Ordinal0 [0x00D722B4+1188532]
# 	Ordinal0 [0x00D73149+1192265]
# 	GetHandleVerifier [0x0102FB8C+1512252]
# 	GetHandleVerifier [0x010DB0DF+2214031]
# 	GetHandleVerifier [0x00F34BC3+484211]
# 	GetHandleVerifier [0x00F33E69+480793]
# 	Ordinal0 [0x00E5218D+2105741]
# 	Ordinal0 [0x00E566E8+2123496]
# 	Ordinal0 [0x00E56827+2123815]
# 	Ordinal0 [0x00E5FB73+2161523]
# 	BaseThreadInitThunk [0x7643FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C67A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C67A4E+238]

# %%
rating_df
# Out:
#      review_code     ItemID UserID review Rating    Timestamp
# 0       GC000001        호세가   None   None   None  2021.06.14.
# 1       GC000002        호세가   None   None   None  2021.06.04.
# 2       GC000003        호세가   None   None   None  2021.06.02.
# 3       GC000004        호세가   None   None   None  2021.05.18.
# 4       GC000005        호세가   None   None   None  2021.05.15.
# ...          ...        ...    ...    ...    ...          ...
# 3229    GC003230  용호동낙지 가산점   None   None   None  2021.01.08.
# 3230    GC003231  용호동낙지 가산점   None   None   None  2020.01.31.
# 3231    GC003232  용호동낙지 가산점   None   None   None  2018.12.16.
# 3232    GC003233  용호동낙지 가산점   None   None   None  2018.08.29.
# 3233    GC003234  용호동낙지 가산점   None   None   None  2016.12.27.
#
# [3234 rows x 6 columns]
