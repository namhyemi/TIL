# %%
# 2021.08.12
# kakaoMap_crawling_2.ipynb 수정버전
# 수정사항 : 지역구 맛집 검색 및 CSV 저장 자동화 수정, 데이터 변수 종류 및 오류 수정(리뷰 코드, 가게 코드 추가, 비어있는 값은 None값으로 통일)
# 추가사항 : 데이터 저장 방식 변경(클래스 추가)

# 문제점 : DB 연결

# %%
import os

from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup

import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')

##########################################################################
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')


driver = webdriver.Chrome('./webdriver/chromedriver')

rating_df = pd.DataFrame()
restaurant_df = pd.DataFrame()


##### 가게 정보를 담는 클레스
class STORE_Info:
    place_code = ''
    place_name = ''
    place_address = ''
    place_local  = ''
    place_category  = ''
    
    # 생성자
    def __init__(self, place_code = None, place_name = None, place_address = None, place_local = None, place_category = None):
        self.place_code = place_code
        self.place_name =  place_name
        self.place_address = place_address
        self.place_local  = place_local
        self.place_category  = place_category
        
    # 데이터 확인
    def data_check(self):
        print('가게코드 : %s, 가계명 : %s, 주소 : %s, 지역 : %s, 종류 : %s' %(self.place_code, self.place_name, self.place_address, 
                                                                 self.place_local, self.place_category))
        
        
##### 리뷰 정보를 담는 클레스
class REVIEW_Info:
    review_code = ''
    place_code = ''
    comment = ''
    rating = ''
    user_id  = ''
    timestamp  = ''

    
    # 생성자
    def __init__(self, review_code=None, place_code =None ,comment = None, rating = None, user_id = None, timestamp = None):
        self.review_code = review_code
        self.place_code = place_code
        self.comment =  comment
        self.rating = rating
        self.user_id  = user_id
        self.timestamp  = timestamp 

    # 데이터 확인
    def data_check(self):
        print('리뷰코드 : %s, 가게코드 : %s, ID : %s, 리뷰 : %s, 평점 : %s, 날짜 : %s' %(self.review_code, self.place_code, 
                                                                           self.user_id,self.comment, self.rating, self.timestamp))

        
##### 메인 코드 #####
def main():
    global driver, load_wb, review_num, local, number_local, number_store

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

     #### 검색할 목록
#     place_infos = ['종로구 맛집', '중구 맛집', ' 용산구 맛집', '성동구 맛집', '광진구 맛집', '동대문구 맛집', '중랑구 맛집', '성북구 맛집', '강북구 맛집']
#     place_infos = ['도봉구 맛집', '노원구 맛집', '은평구 맛집', '서대문구 맛집', '마포구 맛집', '양천구 맛집', '강서구 맛집','구로구 맛집']
    place_infos = ['금천구 맛집', '영등포구 맛집', '동작구 맛집', '관악구 맛집', '서초구 맛집', '강남구 맛집', '송파구 맛집','강동구 맛집']
    
    for i, place in enumerate(place_infos):
        print("##### {0} : {1}".format(i,place))
        number_local = 0
        number_store = 0
        
        local = read_local_code(place)
        search(place, local)
        create_csv_file(place)

    driver.quit()
    print("finish")


#### 가게 정보 찾기
def search(place, local):
    """
    검색한 페이지 음식점 정보 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    """
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER) # 더보기
    
    xPath = '//*[@id="info.search.page.no1"]'
    driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER) # 첫번째 페이지로 이동
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem') # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, local, place_lists)

    # 전체 페이지
    while True:
        try:
#            2~ 5페이지 읽기
            for i in range(2, 6):
                # 페이지 넘기기
                xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
                driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
                sleep(1)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                place_lists = soup.select('.placelist > .PlaceItem') # 장소 목록 list
                
                crawling(place, local, place_lists)
                
                # 다음 페이지 넘기기
                if i==5:
                    driver.find_element_by_xpath('//*[@id="info.search.page.next"]').send_keys(Keys.ENTER)

        except ElementNotInteractableException:
            print('end page')
            break
            
        finally:
            search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')
            search_area.clear()


#### 가게 정보 크롤링 하기
def crawling(place, local, place_lists):
    """
    페이지 목록을 받아서 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    :param place_lists : 페이지 내에 있는 음식점 목록
    """
    
    global restaurant_df, number_store

    while_flag = False
    for i, place in enumerate(place_lists):
        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address
        place_local = place.select('.info_item > .addr > .lot_number')[0].text
        place_category = place.select('.head_item > .subcategory')[0].text
        place_detail = place.select('.info_item > .contact> .moreview')[0].get('href') # place detail
        
        number_store += 1
        place_code = str('STORE_') + local + str(number_store).zfill(4) # 가게 코드 (ex. STORE_GC0001)
        
        store_Info = STORE_Info(place_code, place_name, place_address, place_local, place_category)
        store_Info.data_check()
        
        #### DataFrame 저장 ####
        row = {'place_code': place_code, "ItemID":place_name, "address": place_address, "local" : place_local, "category": place_category}
        row = pd.DataFrame(row, index=[1])
        restaurant_df = restaurant_df.append(row, ignore_index=True)
        
        #### 데이터 베이스 저장 #####

        
        
        
        driver.execute_script('window.open("about:blank", "_blank");')
        driver.switch_to.window(driver.window_handles[-1])
        driver.get(place_detail) # 상세정보 탭으로 변환
        sleep(1)
        
        print('####', place_name)
        sleep(1)
        # 첫 페이지
        extract_review(place_name, place_code , local) # 리뷰 추출

        # 2-5 페이지
        idx = 3
        try:
            page_num = len(driver.find_elements_by_class_name('link_page')) # 페이지 수 찾기
            for i in range(page_num-1):
                # css selector를 이용해 페이지 버튼 누르기
                driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name, place_code, local)
                idx += 1
            driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 5페이지가 넘는 경우 다음 버튼 누르기
            
            sleep(1)
            extract_review(place_name, place_code, local) # 리뷰 추출
            
            # 그 이후 페이지
            while True:
                idx = 4
                page_num = len(driver.find_elements_by_class_name('link_page')) #페이지 수 찾기
                for i in range(page_num-1):
                    driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                    sleep(1)
                    extract_review(place_name, place_code, local)
                    idx += 1
                driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 10페이지 이상으로 넘어가기 위한 다음 버튼 클릭
                sleep(1)
                extract_review(place_name, place_code, local) # 리뷰 추출            
            
        except (NoSuchElementException, ElementNotInteractableException):
            print("no review in crawling")

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환


#### 리뷰 크롤링 하기
def extract_review(place_name, place_code, local):
    """
    리뷰 크롤링 하는 함수
    :param place_place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    """
    
    global driver, rating_df, number_local

    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')

    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        for i, review in enumerate(review_lists):
            comment = review.select('.txt_comment > span') # 리뷰
            rating = review.select('.grade_star > em') # 별점
            user_id = review.select('.append_item > a[data-userid]') # user-id 정보 html 파싱
#             user_name = review.select('.append_item > a[data-username]') # user-name 정보 html 파싱
            timestamp = review.select(' div > span.time_write') #시간정보
            number_local += 1
                  

            #### 클래스 ####
            review_info = REVIEW_Info()
            
            review_info.review_code = local + str(number_local).zfill(6) # 리뷰 코드 (ex. GC000001)
            review_info.place_code = place_code
            
            #### 클래스에 정보 담기 ####
            if len(comment) != 0: # 리뷰
                if comment[0].text:
                    review_info.comment = comment[0].text 
                else:
                    review_info.comment = None
            else:
                review_info.comment = None
            
            if len(rating) != 0: # 별점
                review_info.rating = rating[0].text.replace('점', '')
            else:
                review_info.rating = None

            if(len(user_id) != 0): # 유저id
                if(user_id[0].get('data-userid')):
                    review_info.user_id = user_id[0].get('data-userid')
                else:
                    review_info.user_id = None
            else:
                review_info.user_id = None

            if len(timestamp) != 0: # 시간
                review_info.timestamp = timestamp[0].text
            else:
                review_info.timestamp = None
                
            review_info.data_check()
            
            #### DataFrame 에 정보 담기 ####
            try:
                row = {"review_code" : review_info.review_code, "place_code": place_code, "ItemID": place_name, 
                       "UserID":review_info.user_id, "review" : review_info.comment,
                       "Rating":review_info.rating, "Timestamp":review_info.timestamp}
                row = pd.DataFrame(row, index=[i])
                rating_df = rating_df.append(row, ignore_index=True)
            
            except:
                row = {"review_code" : review_info.review_code, "place_code": place_code, "ItemID":place_name, 
                       "UserID": None, "review" : None, "Rating":None, "Timestamp":review_info.timestamp}
                row = pd.DataFrame(row, index=[i])
                rating_df = rating_df.append(row, ignore_index=True)
                
    else:
        print('no review in extract')
        ret = False

    return ret



#### CSV 파일로 저장 ####
def create_csv_file(place):
    global rating_df, restaurant_df

    rating_df.to_csv('%s_rating_df.csv' %place)
    rating_df.to_csv('%s_rating_df_ko.csv' %place, sep=',', na_rep='NaN', encoding='utf-8-sig')
        
    restaurant_df.to_csv('%s_restaurant_df.csv'  %place)
    restaurant_df.to_csv('%s_restaurant_df_ko.csv'  %place, sep=',', na_rep='NaN', encoding='utf-8-sig')
    
    

#### 지역구 코드 뽑아오기 ####
def read_local_code(place):
    
    local_place = place.split(' ')[0]

    local_code = pd.read_csv('local_code.csv', encoding='utf-8', index_col = 'local')
    return local_code.at[local_place, 'local_code']

#### 메인 ####
if __name__ == "__main__":
    main()
# Out:
# ##### 0 : 금천구 맛집
# 가게코드 : STORE_GC0001, 가계명 : 광고만두라, 주소 : 서울 금천구 시흥대로 97 BB53호, 지역 : (지번) 시흥동 984, 종류 : 한식
# #### 광고만두라
# 리뷰코드 : GC000001, 가게코드 : STORE_GC0001, ID : tghmif, 리뷰 : 드뎌열은듯? 전화가네 , 평점 : 4, 날짜 : 2021.08.12.
# 리뷰코드 : GC000002, 가게코드 : STORE_GC0001, ID : 1m4d6dq, 리뷰 : ㅜㅜ 방문했는데 아직 안열었네요ㅠㅠ 맛보고싶었는데ㅜ, 평점 : 4, 날짜 : 2021.07.22.
# 리뷰코드 : GC000003, 가게코드 : STORE_GC0001, ID : ssnvg6, 리뷰 : 주변 상인들 말로는 6월달부터 영업하신다고 전달받았는데 아직까지도 영업하지 않으심.. 5월 중순부터 3번은 찾아가본 듯 한데 언제쯤 먹어볼 수 있을지…, 평점 : 3, 날짜 : 2021.06.16.
# 리뷰코드 : GC000004, 가게코드 : STORE_GC0001, ID : 8uv76b, 리뷰 : 못먹어봐서 ㅠ 6월10일 어제 갔는데 개인 사정으로 당분간 쉰다고 적혀 있었어요 ㅠ 언제까지 쉬는지는 잘 모름 안적혀 있었음., 평점 : 3, 날짜 : 2021.06.11.
# 리뷰코드 : GC000005, 가게코드 : STORE_GC0001, ID : n1gc3v, 리뷰 : 만두로는 최고, 평점 : 5, 날짜 : 2021.05.19.
# 가게코드 : STORE_GC0002, 가계명 : 가산물갈비&백년불고기, 주소 : 서울 금천구 가산디지털1로 128 STXV타워 1층 110호, 지역 : (지번) 가산동 371-37, 종류 : 불고기,두루치기
# #### 가산물갈비&백년불고기
# 리뷰코드 : GC000006, 가게코드 : STORE_GC0002, ID : 1kbkdss, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.15.
# 리뷰코드 : GC000007, 가게코드 : STORE_GC0002, ID : kl3tq0, 리뷰 : 회식 장소로는 갸우뚱. 하지만 동성 친구끼리 가성비 있게 먹을 장소로 제격입니다. 양 많고 맛 좋고 서비스 괜찮아요., 평점 : 5, 날짜 : 2021.05.23.
# 리뷰코드 : GC000008, 가게코드 : STORE_GC0002, ID : tl6oe5, 리뷰 : 여기가 맛있어요? 회식장소로 좋아요? 아 내돈 내산은 안좋다는거죠 갔을때 먹고, 아 여긴 두번다시 안올맛이다. 싶어요 한약재로 만들었다고 하는데,그게 진짜 사족의맛 이에요., 평점 : 1, 날짜 : 2021.05.13.
# 리뷰코드 : GC000009, 가게코드 : STORE_GC0002, ID : 9hhb1j, 리뷰 : 회식장소로 좋구요 오징어튀김이 별미예요 엄청 바삭해요 , 평점 : 5, 날짜 : 2021.04.23.
# 리뷰코드 : GC000010, 가게코드 : STORE_GC0002, ID : td5904, 리뷰 : 맛있음, 평점 : 5, 날짜 : 2021.03.27.
# 가게코드 : STORE_GC0003, 가계명 : 동흥관, 주소 : 서울 금천구 시흥대로63길 20, 지역 : (지번) 시흥동 115-10, 종류 : 중화요리
# #### 동흥관
# 리뷰코드 : GC000011, 가게코드 : STORE_GC0003, ID : mup5gm, 리뷰 :  , 평점 : 5, 날짜 : 2021.08.11.
# 리뷰코드 : GC000012, 가게코드 : STORE_GC0003, ID : n3320u, 리뷰 : 가격도 그렇게 비싼것도 아니고 맛도 괜찮았어요, 평점 : 3, 날짜 : 2021.07.07.
# 리뷰코드 : GC000013, 가게코드 : STORE_GC0003, ID : 1604arb, 리뷰 : 일부러 갈곳은 절대아님! 지나가다 배고파 갈곳없을때나 가볼까 하는집. 친절. 위생꽝이네요. 좀친절하고 위생과 맛에신경쓰면 괜찮은 기본은 있는 집인데!, 평점 : 1, 날짜 : 2021.07.06.
# 리뷰코드 : GC000014, 가게코드 : STORE_GC0003, ID : 16ghll5, 리뷰 : 고등학교때부터 쭉 다녀왔지만 옛날의 친절함이 다 사라졌다. 주문을 해도 들은둥 마는둥... 뭘 좀 더 갖다달라고 하면 3번을 말해야 갖다준다. 심지어 옆테이블에게 갖다준다 ㅋㅋㅋㅋ 직원들은 벽에 기대어 핸드폰이나 하고 이런게 중국인 종특인가싶다. 다시는 가지 않을것 같다., 평점 : 1, 날짜 : 2021.07.05.
# 리뷰코드 : GC000015, 가게코드 : STORE_GC0003, ID : lnn9im, 리뷰 : 개인적으로는 너무 맛잇고 프라이빗 하게 만나기 너무 좋은데 직원들분이 그렇게 친절 하진 않아서 5 점 만점을 못 드리겠는 …? , 평점 : 4, 날짜 : 2021.06.23.
# 가게코드 : STORE_GC0004, 가계명 : 강강술래 시흥점, 주소 : 서울 금천구 시흥대로 193 금천ICT타워 2층, 지역 : (지번) 시흥동 991, 종류 : 육류,고기
# #### 강강술래 시흥점
# 리뷰코드 : GC000016, 가게코드 : STORE_GC0004, ID : 109p7k6, 리뷰 : None, 평점 : 4, 날짜 : 2021.06.14.
# 리뷰코드 : GC000017, 가게코드 : STORE_GC0004, ID : 18t6cjp, 리뷰 : 이전 이후 더 깔끔해지고 맛도 더 신경쓰시는 것 같습니다., 평점 : 4, 날짜 : 2021.05.30.
# 리뷰코드 : GC000018, 가게코드 : STORE_GC0004, ID : 19h1cpf, 리뷰 : 별 1점도 아까움. 고기 최악. 직원은 더 최악. 한우 질기고 맛없음. 직원 주문 받던 분이 빤히 쳐다보더니 위아래 흘겨봄. 다 먹지도 않았는데 불판 치워버림. 마감시간인줄. 비싼 돈 주고 먹다 체할뻔. 2번 다시는 안 옴. 손절. 그냥 줘도 안 먹음. 1성급이 5성급인 척 하는 느낌. 간만에 밥 먹고 기분 더럽., 평점 : 1, 날짜 : 2021.03.31.
# 리뷰코드 : GC000019, 가게코드 : STORE_GC0004, ID : obt6ck, 리뷰 : 돈 많이나올거 각오하고 가는 패밀리 고기 레스토랑, 평점 : 5, 날짜 : 2021.02.16.
# 리뷰코드 : GC000020, 가게코드 : STORE_GC0004, ID : bfk42a, 리뷰 : None, 평점 : 4, 날짜 : 2020.12.20.
# 가게코드 : STORE_GC0005, 가계명 : 도원, 주소 : 서울 금천구 범안로 1130 디지털엠파이어빌딩 101호, 지역 : (지번) 가산동 685, 종류 : 뷔페
# #### 도원
# 리뷰코드 : GC000021, 가게코드 : STORE_GC0005, ID : benk3h, 리뷰 : 가격 대비 퀄리티 좋은 중식뷔페입니다., 평점 : 5, 날짜 : 2021.08.04.
# 리뷰코드 : GC000022, 가게코드 : STORE_GC0005, ID : 16jsnri, 리뷰 : 오늘갓다왓는데 둥네앵간한 곳보다 맛납니다 혼자 오신 분들이.많더라구요 배불러서 많이 못먹은게.아쉽 ㅜㅜ, 평점 : 5, 날짜 : 2021.06.01.
# 리뷰코드 : GC000023, 가게코드 : STORE_GC0005, ID : muldnn, 리뷰 : 맛은 있다 없다 얘기하는게 별 의미가 없는 것 같습니다. 여러가지 중식을 가성비있게 먹을 수 있어 좋긴 합니다.  하지만 플라스틱 칸막이도 없이 거리두기하지 않고 손님을 받고 있고 손님들이 마스크를 쓰지 않고 음식을 받으러 돌아다녀도 별 말이 없습니다.   저녁시간 바쁜 건 알지만 인간적으로 코로나 상황에 갈 식당은 못된다고 봅니다.  제발 제가 간 날 코..., 평점 : 1, 날짜 : 2021.04.25.
# 리뷰코드 : GC000024, 가게코드 : STORE_GC0005, ID : 1itm3vi, 리뷰 : None, 평점 : 2, 날짜 : 2021.04.24.
# 리뷰코드 : GC000025, 가게코드 : STORE_GC0005, ID : 12bdjlk, 리뷰 : 가보고싶으니 저장, 평점 : 5, 날짜 : 2021.04.22.
# 가게코드 : STORE_GC0006, 가계명 : 쌍교숯불갈비 서울금천점, 주소 : 서울 금천구 시흥대로 435 1층, 지역 : (지번) 독산동 152-3, 종류 : 한식
# #### 쌍교숯불갈비 서울금천점
# 리뷰코드 : GC000026, 가게코드 : STORE_GC0006, ID : 1j85cf4, 리뷰 : 아이와함께하기좋아요. 냉면은비추, 평점 : 5, 날짜 : 2021.07.20.
# 리뷰코드 : GC000027, 가게코드 : STORE_GC0006, ID : uqh3f1, 리뷰 : 정말 맛있고 떡갈비가 엄청 부드러워요, 평점 : 5, 날짜 : 2021.07.16.
# 리뷰코드 : GC000028, 가게코드 : STORE_GC0006, ID : f77kv6, 리뷰 : 맛있어요 반찬도 맛나고 떡갈비랑 돼지갈비 시켰는데 다 구워서 나오고 맛있어요 진짜, 평점 : 5, 날짜 : 2021.07.11.
# 리뷰코드 : GC000029, 가게코드 : STORE_GC0006, ID : 10ibn7p, 리뷰 : 지인짜 맛난집!, 평점 : 5, 날짜 : 2021.06.28.
# 리뷰코드 : GC000030, 가게코드 : STORE_GC0006, ID : 126l72h, 리뷰 : 갈비구이>>갈비찜, 평점 : 5, 날짜 : 2021.06.28.
# 가게코드 : STORE_GC0007, 가계명 : 농장사람들, 주소 : 서울 금천구 벚꽃로 316 C&S타워 1층, 지역 : (지번) 가산동 777, 종류 : 육류,고기
# #### 농장사람들
# 리뷰코드 : GC000031, 가게코드 : STORE_GC0007, ID : 14lp7vt, 리뷰 : 넓은 공간,  친절한  서비스,  무엇보다 맛있는  소고기가 특히  좋았어요..가족  모임이라  시끌시끌했었는데  한결같이  친절했어요... 안심은  너무  부드러워  맛있었구요  채끝등심또한  너무  맛있게  먹었네요  후식  비빔냉면은  역시  매콤하면서  감칠맛  더할것없이  맛있는  식사였어요..., 평점 : 5, 날짜 : 2020.09.20.
# 리뷰코드 : GC000032, 가게코드 : STORE_GC0007, ID : 14u8ikd, 리뷰 : 넘나 맛있고 퀄히티도좋고 가성비굳!!!! 한우가 이가격에?, 평점 : 5, 날짜 : 2019.12.19.
# 리뷰코드 : GC000033, 가게코드 : STORE_GC0007, ID : 132utf4, 리뷰 : 굳굳, 평점 : 5, 날짜 : 2019.12.15.
# 리뷰코드 : GC000034, 가게코드 : STORE_GC0007, ID : 10jq375, 리뷰 : 부모님모시는 자리라 깔끔하고 맛좋은집찾다가 우연히 방문했는데 고기가 너무 맛있고!! 알바분들도 친절하셔서 기분좋게 먹고왔네요~^^!! 자주갈거같아요 ㅎㅎ, 평점 : 5, 날짜 : 2019.12.14.
# 리뷰코드 : GC000035, 가게코드 : STORE_GC0007, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.08.08.
# 가게코드 : STORE_GC0008, 가계명 : 순댕이네얼큰수제비, 주소 : 서울 금천구 시흥대로136길 1, 지역 : (지번) 독산동 160-17, 종류 : 수제비
# #### 순댕이네얼큰수제비
# 리뷰코드 : GC000036, 가게코드 : STORE_GC0008, ID : 124tggd, 리뷰 : 2021년 8월5일 방문했는데 개인적인사정에 의하여 하루쉽니다 라고붙어있음... 그래서 8월6일 다시 가볼라고 전화햇더니 안받음... 다시 확인차 전화햇더니 수신거부걸어놈.. 직원두명이 다 수신거부걸려서 전화만 걸면 통화중으로 나옴...내가 확인차 전화햇더니 전화가 걸림... 맛을떠나서 이런 인성을 가진사람들이 만드는 음식은 먹으면안됨!!!   전화받아서 ..., 평점 : 1, 날짜 : 2021.08.06.
# 리뷰코드 : GC000037, 가게코드 : STORE_GC0008, ID : 1j85cf4, 리뷰 : 줄서서먹을정도아님, 평점 : 3, 날짜 : 2021.07.05.
# 리뷰코드 : GC000038, 가게코드 : STORE_GC0008, ID : uqts70, 리뷰 : 아줌마 병원입원 갔다가 헛탕, 평점 : 2, 날짜 : 2021.06.19.
# 리뷰코드 : GC000039, 가게코드 : STORE_GC0008, ID : 12k9u82, 리뷰 : 맛은..좋은데 위생이 최악이에요 바닥에 떨어진 면을..물에 씻어서 넣는걸 보았음.., 평점 : 2, 날짜 : 2021.05.19.
# 리뷰코드 : GC000040, 가게코드 : STORE_GC0008, ID : 12980mk, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.13.
# 가게코드 : STORE_GC0009, 가계명 : 김사부샤브샤브, 주소 : 서울 금천구 가산로 132, 지역 : (지번) 가산동 145-24, 종류 : 샤브샤브
# #### 김사부샤브샤브
# 리뷰코드 : GC000041, 가게코드 : STORE_GC0009, ID : nvn8qn, 리뷰 : 꿔바로우 JMT 볶음면도 맛있음, 기대 안 했는데 이국적으로 매콤함 코로나 위생도 잘 지키심, 평점 : 4, 날짜 : 2021.08.06.
# 리뷰코드 : GC000042, 가게코드 : STORE_GC0009, ID : 1682m90, 리뷰 : 오랫동안 방문하고 싶은데 그냥그랬어요. 제가 묻고 싶은 게 있었지만 직원이 한국어 못 알아들어서 상황이 안 좋았어요. 설명하지 못하고 제가 추가 인분을 주문하고 싶었지만 결국 나갔어요. , 평점 : 2, 날짜 : 2021.07.20.
# 리뷰코드 : GC000043, 가게코드 : STORE_GC0009, ID : kmqmrt, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.30.
# 리뷰코드 : GC000044, 가게코드 : STORE_GC0009, ID : f15gk7, 리뷰 : 다른건 그냥 평타정도 근데 꿔바로우 진짜 여태껏 먹은것 중에 제일 맛있어서 이마 빡빡침 , 평점 : 4, 날짜 : 2021.05.29.
# 리뷰코드 : GC000045, 가게코드 : STORE_GC0009, ID : 18bqja1, 리뷰 : 너무 맛있는 음식 종업원분들과 약간 소통이 안되는 것 말고는 좋았어요!, 평점 : 4, 날짜 : 2021.02.14.
# 가게코드 : STORE_GC0010, 가계명 : 왕게수산, 주소 : 서울 금천구 시흥대로 182, 지역 : (지번) 시흥동 903-5, 종류 : 게,대게
# #### 왕게수산
# 리뷰코드 : GC000046, 가게코드 : STORE_GC0010, ID : 7mviov, 리뷰 : 직원들은 완전 좋은데 카운터는 개싹아지 ♬♬♬♩♩임.. 두번다시 안갈거임.. 갈때마다 현찰주는데.. 돈아까움..다른곳 뚤어야지, 평점 : 1, 날짜 : 2021.03.28.
# 리뷰코드 : GC000047, 가게코드 : STORE_GC0010, ID : 131k246, 리뷰 : 그냥 저냥, 평점 : 3, 날짜 : 2021.02.11.
# 리뷰코드 : GC000048, 가게코드 : STORE_GC0010, ID : cdmj9q, 리뷰 : 서비스의 질 이라든지 맛 이라든지, 종업원 분들의 손님접대 태도라든지 보통 입니다. 사랑받는 식당 되길 바랍니다~^^, 평점 : 3, 날짜 : 2020.10.04.
# 리뷰코드 : GC000049, 가게코드 : STORE_GC0010, ID : 102qqnp, 리뷰 : 어머니 생신때 킹크랩 키로당 노량진보다 너무비싸게삼 동네라 급해샀지 시간만 있었음 그냥노량진 가는게 훨쌈.., 평점 : 1, 날짜 : 2020.10.03.
# 리뷰코드 : GC000050, 가게코드 : STORE_GC0010, ID : 10g4lqj, 리뷰 : 가격대비 아쉬움, 평점 : 2, 날짜 : 2020.08.20.
# 가게코드 : STORE_GC0011, 가계명 : 채영진의명품생고기무한리필 독산점, 주소 : 서울 금천구 독산로 176, 지역 : (지번) 독산동 378-436, 종류 : 고기뷔페
# #### 채영진의명품생고기무한리필 독산점
# 리뷰코드 : GC000051, 가게코드 : STORE_GC0011, ID : 13fc3je, 리뷰 : 사장님 유도리도 없고 말투도 싸가지 없으시네요 더러워서 안먹습니다^^, 평점 : 1, 날짜 : 2021.08.08.
# 리뷰코드 : GC000052, 가게코드 : STORE_GC0011, ID : 1aq8ku9, 리뷰 : None, 평점 : 5, 날짜 : 2021.06.08.
# 리뷰코드 : GC000053, 가게코드 : STORE_GC0011, ID : 1802ss4, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.02.
# 리뷰코드 : GC000054, 가게코드 : STORE_GC0011, ID : 14v3g46, 리뷰 : 직원이 불친절해요, 평점 : 1, 날짜 : 2021.04.30.
# 리뷰코드 : GC000055, 가게코드 : STORE_GC0011, ID : 1clemtd, 리뷰 : 리뷰 보아하니 한동안 못 갔는데 많이 개차반 되었나보네요.. 예전엔 두꺼워서 좋았는데 마지막으로 갔을때 작고 얇아지고.. 처음 갔을때부터 직원 두세분 앉아서 노가리 털고 있고 불친절하던거 그냥 고기가 맛있어서 넘어갔는데 두 세번째 갔을때도 바뀐건지 여전히 노가리 털고 고기 달라하면 귀찮은 식으로 반응 하고 체인점이라 역시 글러쳐먹었네요. 지인보고 가라했다가..., 평점 : 1, 날짜 : 2021.04.25.
# 가게코드 : STORE_GC0012, 가계명 : 개성손만두요리전문점 가산디지털점, 주소 : 서울 금천구 가산로9길 22, 지역 : (지번) 가산동 143-18, 종류 : 한식
# #### 개성손만두요리전문점 가산디지털점
# 리뷰코드 : GC000056, 가게코드 : STORE_GC0012, ID : 17532nq, 리뷰 : 양도 많고 맛도 있는 집, 평점 : 5, 날짜 : 2021.07.26.
# 리뷰코드 : GC000057, 가게코드 : STORE_GC0012, ID : uqh3f1, 리뷰 : 맛있어요, 평점 : 5, 날짜 : 2021.07.16.
# 리뷰코드 : GC000058, 가게코드 : STORE_GC0012, ID : 1634v98, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.12.
# 리뷰코드 : GC000059, 가게코드 : STORE_GC0012, ID : 13dfchl, 리뷰 : 국물 깔끔하고 시원해서 좋음 사장님은 매우 불친절 내용물(채소)은 줄거면 주고 말거면 말지 매우 조금나옴, 평점 : 3, 날짜 : 2021.06.09.
# 리뷰코드 : GC000060, 가게코드 : STORE_GC0012, ID : e4gbh1, 리뷰 : 만두 좋아하는데 전골 1인분 주문할 수 있는 곳은 처음이네요. 만두가 네 알 들어가고 김치는 여기서 담그신답니다. 저녁에는 2천원에 볶음밥도 추가 가능한데 기본으로 나오는 칼국수까지 먹고 나니 배불러서 안 했어요. 가격은 매장에서 드시면 8천원, 포장하면 7천원. 매장 앞에 5대 가량 주차 가능합니다., 평점 : 5, 날짜 : 2021.05.27.
# 가게코드 : STORE_GC0013, 가계명 : 두껍삼 가산직영점, 주소 : 서울 금천구 벚꽃로38길 43, 지역 : (지번) 가산동 87-225, 종류 : 삼겹살
# #### 두껍삼 가산직영점
# 리뷰코드 : GC000061, 가게코드 : STORE_GC0013, ID : 1634v98, 리뷰 : None, 평점 : 3, 날짜 : 2021.07.12.
# 리뷰코드 : GC000062, 가게코드 : STORE_GC0013, ID : f5n90h, 리뷰 : 믿고 먹는 두껍삼 후식으로 온국수 필수 회식 장소 추천, 평점 : 5, 날짜 : 2021.05.09.
# 리뷰코드 : GC000063, 가게코드 : STORE_GC0013, ID : 13fgd4s, 리뷰 : 최고에여, 평점 : 5, 날짜 : 2021.03.04.
# 리뷰코드 : GC000064, 가게코드 : STORE_GC0013, ID : csgujd, 리뷰 : 다소 비싸긴해도 서비스와 맛은 괜찮은편임, 평점 : 3, 날짜 : 2020.07.28.
# 리뷰코드 : GC000065, 가게코드 : STORE_GC0013, ID : dfg4be, 리뷰 : 편하게 먹는 건 좋지만 고기질이 아쉽습니다., 평점 : 3, 날짜 : 2020.05.13.
# 가게코드 : STORE_GC0014, 가계명 : 문정곱창, 주소 : 서울 금천구 디지털로12길 37 1층, 지역 : (지번) 가산동 143-20, 종류 : 곱창,막창
# #### 문정곱창
# 리뷰코드 : GC000066, 가게코드 : STORE_GC0014, ID : rjmus4, 리뷰 : None, 평점 : 5, 날짜 : 2021.08.08.
# 리뷰코드 : GC000067, 가게코드 : STORE_GC0014, ID : 19ap743, 리뷰 : 볶음밥 맛이 신기하다.. 그래서 주는 소스 넣고 볶아서 먹을만 했다. 근데평점이 왜이렇게 높은지 모르겠다 , 평점 : 1, 날짜 : 2021.06.24.
# 리뷰코드 : GC000068, 가게코드 : STORE_GC0014, ID : uk1fm6, 리뷰 : 존맛탱입ㄴ다 곱창이 찐이에요, 평점 : 5, 날짜 : 2021.06.10.
# 리뷰코드 : GC000069, 가게코드 : STORE_GC0014, ID : r6q0o1, 리뷰 : None, 평점 : 4, 날짜 : 2021.05.21.
# 리뷰코드 : GC000070, 가게코드 : STORE_GC0014, ID : 126l72h, 리뷰 : 양념장이 맛있네요.. 멀리서 와서 갈 곳은 아니고 누가 사주면 갈 정도.., 평점 : 4, 날짜 : 2021.04.25.
# 가게코드 : STORE_GC0015, 가계명 : 춘천옥, 주소 : 서울 금천구 디지털로12길 19, 지역 : (지번) 가산동 140-38, 종류 : 족발,보쌈
# #### 춘천옥
# 리뷰코드 : GC000071, 가게코드 : STORE_GC0015, ID : ae72me, 리뷰 : 깔끔하고 맛있어요., 평점 : 5, 날짜 : 2021.08.12.
# 리뷰코드 : GC000072, 가게코드 : STORE_GC0015, ID : 1634v98, 리뷰 : None, 평점 : 3, 날짜 : 2021.07.12.
# 리뷰코드 : GC000073, 가게코드 : STORE_GC0015, ID : qs9i8p, 리뷰 : 이 코로나 시국에 주방안에 두사람 (남1, 여1) 계속 마스크도 안하고 조리 하시더라고요. 먹는내내 자꾸 눈앞에 보여서 먹다가 나왔습니다., 평점 : 1, 날짜 : 2021.07.06.
# 리뷰코드 : GC000074, 가게코드 : STORE_GC0015, ID : 17gmpu1, 리뷰 : 후회, 평점 : 1, 날짜 : 2021.01.15.
# 리뷰코드 : GC000075, 가게코드 : STORE_GC0015, ID : lneiso, 리뷰 : 와서 먹어보면 알수있지만...비추, 평점 : 1, 날짜 : 2021.01.15.
# 가게코드 : STORE_GC0016, 가계명 : 은행골 시흥분점, 주소 : 서울 금천구 시흥대로 198 지하1층, 지역 : (지번) 시흥동 890-10, 종류 : 초밥,롤
# #### 은행골 시흥분점
# 리뷰코드 : GC000076, 가게코드 : STORE_GC0016, ID : 14e5f0l, 리뷰 : 먹어본 초밥집 중에 가성비는 둘째치고 맛으로 손 꼽히는 초밥집입니다 매달 2-3번 정도 가는데 진짜 왠만하면 평타 이상 무조건 치고 가끔 특정 초밥이 비정상적으로 맛있는 경우가 있어요 뜬금없이 광어초밥?이 미친 맛을 낸다던가ㅋㅋ, 평점 : 5, 날짜 : 2021.08.02.
# 리뷰코드 : GC000077, 가게코드 : STORE_GC0016, ID : 16il1dq, 리뷰 : 핵존맛탱 회도 두툼하고 맛도 좋았어요 그리고 무지 친절하심, 평점 : 5, 날짜 : 2021.06.28.
# 리뷰코드 : GC000078, 가게코드 : STORE_GC0016, ID : 1je2d52, 리뷰 : 맛있고 친절했음. 서비스 초밥은 말씀안드려도 항상 주셨었음., 평점 : 5, 날짜 : 2021.05.13.
# 리뷰코드 : GC000079, 가게코드 : STORE_GC0016, ID : v3894s, 리뷰 : 맛있긴한데 서비스정신 개구림ㅋㅋㅋ, 평점 : 1, 날짜 : 2021.05.07.
# 리뷰코드 : GC000080, 가게코드 : STORE_GC0016, ID : jti6dn, 리뷰 : 서빙진짜 개열받음 서비스초밥 달라니까 던질듯툭놓고감  아진짜 오래갔었는데 진짜 실망이다 그간 손님뒷담 겁나까는것도 듣고 대수롭지 않게 생각했는데 그때부터 알아봤어야함., 평점 : 1, 날짜 : 2021.04.14.
# 가게코드 : STORE_GC0017, 가계명 : 호세가, 주소 : 서울 금천구 남부순환로108길 19 1층, 지역 : (지번) 가산동 145-13, 종류 : 멕시칸,브라질
# #### 호세가
# 리뷰코드 : GC000081, 가게코드 : STORE_GC0017, ID : 133utn8, 리뷰 : 넘모 맛있어요!, 평점 : 5, 날짜 : 2021.06.14.
# 리뷰코드 : GC000082, 가게코드 : STORE_GC0017, ID : bejo8o, 리뷰 : 맛있어요 , 평점 : 3, 날짜 : 2021.06.04.
# 리뷰코드 : GC000083, 가게코드 : STORE_GC0017, ID : objtma, 리뷰 : 5번째 방문!! 멕시코 음식 땡길때 마다 갑니다.  시켜본 메뉴중 실패한게 없어요. 다 어느정도 맛있습니다. 친구들 데리고 저 계속 갈테니까 오래 장사 해주세요~  , 평점 : 5, 날짜 : 2021.06.02.
# 리뷰코드 : GC000084, 가게코드 : STORE_GC0017, ID : ggphir, 리뷰 : 호세가 부리또볼 쉬림프를 엄청 좋아해서 종종 가요. 다른 평처럼 불친절 한 건 한번도 못느꼈어요 오히려 늘 친절한 편이셨던 것 같아요. 오늘은 엔칠라다를 처음으로 포장했어요. 맛은 좋은데 열어보니 나초는 없는데 나초향이 엄청 나서 보니 나초가 소스에 쩔어있어요.. ㅠㅜ, 평점 : 4, 날짜 : 2021.05.18.
# 리뷰코드 : GC000085, 가게코드 : STORE_GC0017, ID : pof6og, 리뷰 : 앞에 손님들이 웨이팅 한다고 기다리래요. 네 기다릴 의향있었어요. 근데 비가 정말 철철 오는 날이었는데, 밖에서 기다리래요; ? 밖 어디요...?  그래서 계산대 앞에 창가쪽의자있길래 거기앉아도 되겠냐구 여쭤봤는데 안된다고 밖에 있으래요. 그래서 웨이팅 시간 여쭤봤는데 그것도 알려줄수 없고 자신들도 모른다네요. ㅋ..그럼 밖에서 철철맞으면서 우산쓰고 기약없..., 평점 : 1, 날짜 : 2021.05.15.
# 가게코드 : STORE_GC0018, 가계명 : 북촌삼대갈비 가산본점, 주소 : 서울 금천구 가산로 149 1층, 지역 : (지번) 가산동 140-8, 종류 : 갈비
# #### 북촌삼대갈비 가산본점
# 리뷰코드 : GC000086, 가게코드 : STORE_GC0018, ID : 1514khp, 리뷰 : 생갈비 존맛집. 생갈비 먹다가 양념고기 못먹음ㅋㅋㅋ, 평점 : 5, 날짜 : 2021.02.28.
# 리뷰코드 : GC000087, 가게코드 : STORE_GC0018, ID : 13dfchl, 리뷰 : 솔직히 요 근방에서 가성비는 최고에요 맛도 괜찮아서 자주 가는편, 평점 : 5, 날짜 : 2020.10.25.
# 리뷰코드 : GC000088, 가게코드 : STORE_GC0018, ID : 1cr19ba, 리뷰 : None, 평점 : 2, 날짜 : 2020.10.16.
# 리뷰코드 : GC000089, 가게코드 : STORE_GC0018, ID : ai9c5m, 리뷰 : 다른거는 모르겠으나 통삼겹은 고기에 기름이 너무 많았어요... 처음에 세덩이 주셨는데 한덩이 빼곤 기름덩어리라서 잘라서 먹었네요. 닭갈비는 살짝 매콤해요. 직원분은 좀 불친절했습니다., 평점 : 2, 날짜 : 2020.10.05.
# 리뷰코드 : GC000090, 가게코드 : STORE_GC0018, ID : 14gm3ht, 리뷰 : 직원  불친절., , , 평점 : 1, 날짜 : 2020.08.07.
# 가게코드 : STORE_GC0019, 가계명 : 만두라, 주소 : 서울 금천구 시흥대로 97 BB53호, 지역 : (지번) 시흥동 984, 종류 : 한식
# #### 만두라
# 리뷰코드 : GC000091, 가게코드 : STORE_GC0019, ID : tghmif, 리뷰 : 드뎌열은듯? 전화가네 , 평점 : 4, 날짜 : 2021.08.12.
# 리뷰코드 : GC000092, 가게코드 : STORE_GC0019, ID : 1m4d6dq, 리뷰 : ㅜㅜ 방문했는데 아직 안열었네요ㅠㅠ 맛보고싶었는데ㅜ, 평점 : 4, 날짜 : 2021.07.22.
# 리뷰코드 : GC000093, 가게코드 : STORE_GC0019, ID : ssnvg6, 리뷰 : 주변 상인들 말로는 6월달부터 영업하신다고 전달받았는데 아직까지도 영업하지 않으심.. 5월 중순부터 3번은 찾아가본 듯 한데 언제쯤 먹어볼 수 있을지…, 평점 : 3, 날짜 : 2021.06.16.
# 리뷰코드 : GC000094, 가게코드 : STORE_GC0019, ID : 8uv76b, 리뷰 : 못먹어봐서 ㅠ 6월10일 어제 갔는데 개인 사정으로 당분간 쉰다고 적혀 있었어요 ㅠ 언제까지 쉬는지는 잘 모름 안적혀 있었음., 평점 : 3, 날짜 : 2021.06.11.
# 리뷰코드 : GC000095, 가게코드 : STORE_GC0019, ID : n1gc3v, 리뷰 : 만두로는 최고, 평점 : 5, 날짜 : 2021.05.19.
# 가게코드 : STORE_GC0020, 가계명 : 우리집 순대국, 주소 : 서울 금천구 금하로 650, 지역 : (지번) 시흥동 885-6, 종류 : 순대
# #### 우리집 순대국
# 리뷰코드 : GC000096, 가게코드 : STORE_GC0020, ID : 1438o8q, 리뷰 : 개인적으로 순대국맛은 좋았어요. 다만, 식당이 오래되서인지 약간 지저분..., 평점 : 4, 날짜 : 2021.07.19.
# 리뷰코드 : GC000097, 가게코드 : STORE_GC0020, ID : 1568oos, 리뷰 : 개판.  특히 젊은 아들 완전 싸가지  손님하고 막싸움. , 평점 : 1, 날짜 : 2021.07.11.
# 리뷰코드 : GC000098, 가게코드 : STORE_GC0020, ID : dnt018, 리뷰 : 윤호찌보고 갔는데 후회함 , 평점 : 2, 날짜 : 2021.05.30.
# 리뷰코드 : GC000099, 가게코드 : STORE_GC0020, ID : ldk523, 리뷰 : 김치부터 쌈장까지 재활함.... 남의 침뭍어 있는 밑반찬 먹고싶은 가보삼!, 평점 : 1, 날짜 : 2020.08.02.
# 리뷰코드 : GC000100, 가게코드 : STORE_GC0020, ID : 15q54kq, 리뷰 : ㄴ, 평점 : 4, 날짜 : 2020.04.25.
# 가게코드 : STORE_GC0021, 가계명 : 탐나종합어시장 가산점, 주소 : 서울 금천구 가산로 156 1층, 지역 : (지번) 가산동 141-14, 종류 : 회
# #### 탐나종합어시장 가산점
# 리뷰코드 : GC000101, 가게코드 : STORE_GC0021, ID : 1634v98, 리뷰 : None, 평점 : 4, 날짜 : 2021.07.12.
# 리뷰코드 : GC000102, 가게코드 : STORE_GC0021, ID : 11sunb7, 리뷰 : 신설동점도 먹어봤는데 여기가 최고에요 진짜 숭어 무슨일 너무 맛있어요 ㅠㅠㅠㅠㅠㅠ 최고최고 오독오독하니 식감 대박이에요 소라무침도 진짜 너무 맛집 ^_^ 내부가 넓은 편은 아니라 코시국엔 포장 추천해여 , 평점 : 5, 날짜 : 2021.01.23.
# 리뷰코드 : GC000103, 가게코드 : STORE_GC0021, ID : kf56oi, 리뷰 : 회가 두꺼워서 식감이 좋네요. 진짜 맛있어요, 평점 : 5, 날짜 : 2020.09.12.
# 리뷰코드 : GC000104, 가게코드 : STORE_GC0021, ID : rs12u8, 리뷰 : 뭐야~ 리뷰 작업들어왔나?? 가산에서 그나마 저렴하게 먹을 수 있는 유일한 횟집. 사람들 많아서 회전율이 좋아 고기 신선함. 여기 괜찮음. 여기서 먹으려면 5시에 퇴근해서 가야함., 평점 : 5, 날짜 : 2020.09.04.
# 리뷰코드 : GC000105, 가게코드 : STORE_GC0021, ID : e8cekq, 리뷰 : None, 평점 : 5, 날짜 : 2020.07.06.
# 가게코드 : STORE_GC0022, 가계명 : 진영면옥, 주소 : 서울 금천구 가산로 22-5, 지역 : (지번) 독산동 162-10, 종류 : 냉면
# #### 진영면옥
# 리뷰코드 : GC000106, 가게코드 : STORE_GC0022, ID : 172hens, 리뷰 : 11시 오픈 시간전 도착해서 기다리다가 입장. 아주 담백하고 개운한 냉면맛 이네요. 면발도 얇고 부드러워서 제대로 된 평냉이더군요. 가게앞에 1~2대 정도만 주차 가능해서 주차는 좀 불편할거 같아요!, 평점 : 5, 날짜 : 2021.08.09.
# 리뷰코드 : GC000107, 가게코드 : STORE_GC0022, ID : 1gihh8c, 리뷰 : 단골입니다., 평점 : 5, 날짜 : 2021.07.29.
# 리뷰코드 : GC000108, 가게코드 : STORE_GC0022, ID : le701i, 리뷰 : 기존의 냉면보다 간이 깔끔합니다. 육수도 소고기향이 가득하고 냉면에 식초 겨자는 안넣는걸 추천합니다.(안넣고 먹어보고 넣고 먹어봄) 면도 안질겨 가위질고 비추입니다. 수육은 입에서 녹습니다. 수육에 소주만 먹어도 될듯. 별저 5점 안준건 다른거 안먹어봐서 그렇습니다.   , 평점 : 4, 날짜 : 2021.07.28.
# 리뷰코드 : GC000109, 가게코드 : STORE_GC0022, ID : 10icp5i, 리뷰 : 성시경맛집. 한식기능장 따신 사장님.평양안가도됨, 평점 : 4, 날짜 : 2021.07.26.
# 리뷰코드 : GC000110, 가게코드 : STORE_GC0022, ID : uqts70, 리뷰 : 3시 5시 브레이크 타임 못먹고 나옴맛 모름, 평점 : 3, 날짜 : 2021.06.19.
# 가게코드 : STORE_GC0023, 가계명 : 스시쥬베이, 주소 : 서울 금천구 가산로 147, 지역 : (지번) 가산동 140-9, 종류 : 일식
# #### 스시쥬베이
# 리뷰코드 : GC000111, 가게코드 : STORE_GC0023, ID : 9e3ja6, 리뷰 : 런치초밥 너무 신선하고 맛있었어요!!!, 평점 : 5, 날짜 : 2021.07.01.
# 리뷰코드 : GC000112, 가게코드 : STORE_GC0023, ID : None, 리뷰 : 회덮밥+특선 초밥 넘 맛나요 비법이 모예요, 평점 : 5, 날짜 : 2021.05.29.
# 리뷰코드 : GC000113, 가게코드 : STORE_GC0023, ID : u6uq98, 리뷰 : 점심 때에 방문했고 맛은 괜찮았어요. 다만 사람이 많았는데 환기를 할수있는 창문이 있음에도 환기를 안하고, 주방장분이 마스크를 안쓰고 계시고, 출입명부가 잘 관리가 안되어서 불안했어요. 코로나 시국에는 안갈것 같네요., 평점 : 4, 날짜 : 2021.05.12.
# 리뷰코드 : GC000114, 가게코드 : STORE_GC0023, ID : mteabq, 리뷰 : 점심때 갔는데. 식전죽. 오.... 맛있더라구요. 스시. 좋았습니다! 동네 손님 오면 이집 가려구요. 식사하는데 불편함이 1도 없었네요. 우동은 좀 짰는데요. 뭔가 한국식이 아닌 진짜 일본의 느낌이 나서 좋았어요. 국물이 짠데 뭔가 깊은맛나면서 개운해요. 아울렛에서 가까우니 쇼핑 후 가볍게 식사하실 곳으로 매우 추천합니다 ㅋㅋ, 평점 : 5, 날짜 : 2021.02.11.
# 리뷰코드 : GC000115, 가게코드 : STORE_GC0023, ID : 15ktmqb, 리뷰 : None, 평점 : 5, 날짜 : 2021.01.11.
# 가게코드 : STORE_GC0024, 가계명 : 황제짬뽕양꼬치, 주소 : 서울 금천구 디지털로9길 32 B동 1층 107호, 지역 : (지번) 가산동 60-5, 종류 : 중화요리
# #### 황제짬뽕양꼬치
# 리뷰코드 : GC000116, 가게코드 : STORE_GC0024, ID : 13kfnpv, 리뷰 : None, 평점 : 4, 날짜 : 2021.06.11.
# 리뷰코드 : GC000117, 가게코드 : STORE_GC0024, ID : 1eoj3ao, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.27.
# 리뷰코드 : GC000118, 가게코드 : STORE_GC0024, ID : 9sqe77, 리뷰 : 황제짬뽕 진짜루맛있음 ..ㅠㅠ 지금까지 양꼬치만 먹었다가 짬뽕시켜봤는데 깜짝놀램 , 평점 : 5, 날짜 : 2021.01.15.
# 리뷰코드 : GC000119, 가게코드 : STORE_GC0024, ID : n3i24d, 리뷰 : 짬뽕이랑 양꼬치 궁합 좋아요, 평점 : 5, 날짜 : 2021.01.06.
# 리뷰코드 : GC000120, 가게코드 : STORE_GC0024, ID : m74m27, 리뷰 : 가성비갑, 평점 : 4, 날짜 : 2020.10.09.
# 가게코드 : STORE_GC0025, 가계명 : 아웃백스테이크하우스 가산점, 주소 : 서울 금천구 디지털로10길 9 현대시티아울렛 가산점 7층, 지역 : (지번) 가산동 60-8, 종류 : 패밀리레스토랑
# #### 아웃백스테이크하우스 가산점
# 리뷰코드 : GC000121, 가게코드 : STORE_GC0025, ID : tbhhlt, 리뷰 : 메뉴 강요가 너무 심해요 ㅠㅠ3번정도 괜찮다고 했는데....ㅜ다른 지점도 이러는지는 모르겠는데 이 지점은 다시는 안갈듯...., 평점 : 1, 날짜 : 2021.08.01.
# 리뷰코드 : GC000122, 가게코드 : STORE_GC0025, ID : 8qqdkk, 리뷰 : 직원분들 너무 친절하시고 서비스도 너무 좋습니다 맛있게 기분좋게 먹고 갑니다 ^^, 평점 : 5, 날짜 : 2021.03.03.
# 리뷰코드 : GC000123, 가게코드 : STORE_GC0025, ID : laoaff, 리뷰 : 친절하고.   친절하고.  친절하다. , 평점 : 5, 날짜 : 2021.02.06.
# 리뷰코드 : GC000124, 가게코드 : STORE_GC0025, ID : m51d47, 리뷰 : 엄청 친절하심 ㅎㅎㅎ 감사합니다 잘먹을게요, 평점 : 5, 날짜 : 2021.02.04.
# 리뷰코드 : GC000125, 가게코드 : STORE_GC0025, ID : vhlvlj, 리뷰 : 그냥.. 그랬어요, 평점 : 3, 날짜 : 2020.10.16.
# 가게코드 : STORE_GC0026, 가계명 : 스미다, 주소 : 서울 금천구 벚꽃로 298 대륭포스트6차 b143호, 지역 : (지번) 가산동 50-3, 종류 : 카페
# #### 스미다
# 리뷰코드 : GC000126, 가게코드 : STORE_GC0026, ID : 1k89fdu, 리뷰 : 맛있네요, 평점 : 5, 날짜 : 2021.06.02.
# 리뷰코드 : GC000127, 가게코드 : STORE_GC0026, ID : so9ifu, 리뷰 : None, 평점 : 5, 날짜 : 2021.03.07.
# 리뷰코드 : GC000128, 가게코드 : STORE_GC0026, ID : 12kqhf8, 리뷰 : 맛이좋네요~!! 담에또올게요, 평점 : 4, 날짜 : 2020.12.24.
# 리뷰코드 : GC000129, 가게코드 : STORE_GC0026, ID : ae72me, 리뷰 : 가기 전에 평가에서 감시 당하는 느낌을 받았다고 그래서 걱정했는데 1시간만 있어서 그런지 감시 당하는 느낌은 받지 못했지만 시간에 관대하지 못한 건 사실인 것 같아요. 주문을 마치자마자 시간 제한이 있다고 고지하더라구요. 애초에 약속 전 한시간만 앉아있을 생각으로 간거였는데도 시간 제한을 이렇게 직접적으로 얘기한 곳은 처음이라 당황스러웠어요. 음.. 전 아..., 평점 : 3, 날짜 : 2020.10.25.
# 리뷰코드 : GC000130, 가게코드 : STORE_GC0026, ID : g7ieh4, 리뷰 : 주말에 문 연 곳 찾아갔는데 너무 좋았어요. 분위기 있고 디저트 종류도 다양하고 음료도 맛있고 보드게임도 있어서 잘 놀고 왔습니다. 분위기는 조용한 편이였고 조금 좁았지만 또 가고 싶어요~, 평점 : 5, 날짜 : 2020.10.17.
# 가게코드 : STORE_GC0027, 가계명 : 동대문털보네, 주소 : 서울 금천구 디지털로9길 99, 지역 : (지번) 가산동 60-11, 종류 : 육류,고기
# #### 동대문털보네
# 리뷰코드 : GC000131, 가게코드 : STORE_GC0027, ID : 1634v98, 리뷰 : None, 평점 : 4, 날짜 : 2021.07.18.
# 리뷰코드 : GC000132, 가게코드 : STORE_GC0027, ID : d1nhb8, 리뷰 : 초벌구이해줌. 대박. 맛있음. 다음에 또 오고 싶음., 평점 : 5, 날짜 : 2021.04.27.
# 리뷰코드 : GC000133, 가게코드 : STORE_GC0027, ID : 1g2quqo, 리뷰 : 대존맛 사장님이신지 직원분들 인상은 좀 불친절하실것처럼 보이는데 엄청 친절하심 무엇보다... 고기 질이 미쳤음 너무 맛잇음, 평점 : 5, 날짜 : 2021.04.19.
# 리뷰코드 : GC000134, 가게코드 : STORE_GC0027, ID : eg9c4a, 리뷰 : 고기 완전 맛있음 굳굳 금요일 저녁은 웨이팅 잇음 , 평점 : 5, 날짜 : 2021.04.04.
# 리뷰코드 : GC000135, 가게코드 : STORE_GC0027, ID : oaief9, 리뷰 : 진짜맛있어서짜증남 끝., 평점 : 5, 날짜 : 2021.03.06.
# 가게코드 : STORE_GC0028, 가계명 : 동남집 2호점, 주소 : 서울 금천구 가산디지털1로 149, 지역 : (지번) 가산동 371-59, 종류 : 육류,고기
# #### 동남집 2호점
# 리뷰코드 : GC000136, 가게코드 : STORE_GC0028, ID : 17rv1l8, 리뷰 : 21년 7월 3주차에 방문 혼자 기억하려고 쓰는 주관적인 방문기 평균 3.5점  평균 1점 최악 2점 비추천 3점 추천 4점 강력 추천 5점 업계 최고  세부항목 도가니탕(14000원) 맛 4점  양 3.5점  가격 2.5점  서비스 4점(무료 국수) 사람들이 많은데 직원들이 당황하지 않고 적절히 안내하고 생각보다는 분위기가 깔끔하다. 국수가 있어서 든든하..., 평점 : 3, 날짜 : 2021.07.14.
# 리뷰코드 : GC000137, 가게코드 : STORE_GC0028, ID : k6kco7, 리뷰 : 밥도 주고 사리 면도 줘요. 다 먹으면 배불러요. 깔끔하게 먹기 좋아요, 평점 : 3, 날짜 : 2021.06.21.
# 리뷰코드 : GC000138, 가게코드 : STORE_GC0028, ID : klai6e, 리뷰 : 양지곰탕 7000원 ->8000원 오름. 특곰탕 9000 -> 10000, 평점 : 4, 날짜 : 2020.01.31.
# 리뷰코드 : GC000139, 가게코드 : STORE_GC0028, ID : u8lamg, 리뷰 : 포장에 특화가 되어있음, 평점 : 3, 날짜 : 2019.11.27.
# 리뷰코드 : GC000140, 가게코드 : STORE_GC0028, ID : 91a28p, 리뷰 : 사장있는 날이랑 종업원만 있는날이 다름. 사장있는 날은 매우 만족. 종업원만 있는날은 4명이 갔는데 2명씩 따로 앉으라고 강요함. 불러도 대답만 하고 안옴.  여기는 종업원들이 문제인듯  , 평점 : 1, 날짜 : 2018.08.29.
# 가게코드 : STORE_GC0029, 가계명 : 지리산 삼계탕, 주소 : 서울 금천구 가산로 88, 지역 : (지번) 독산동 148-32, 종류 : 삼계탕
# #### 지리산 삼계탕
# 리뷰코드 : GC000141, 가게코드 : STORE_GC0029, ID : 19gd2ak, 리뷰 : None, 평점 : 5, 날짜 : 2021.04.03.
# 리뷰코드 : GC000142, 가게코드 : STORE_GC0029, ID : h5c4n9, 리뷰 : 삼계탕이 맛집이라고 하긴 그렇고 김치가 맛집이었음, 평점 : 4, 날짜 : 2021.01.17.
# 리뷰코드 : GC000143, 가게코드 : STORE_GC0029, ID : 1fgj6ed, 리뷰 : 녹두삼계탕 먹었는데 녹두를 일부는 곱게 갈고 일부는 통으로 넣어서 약간 녹두색이 도는 삼계탕 국물은 꼬습하고 사이사이에 씹히는 녹두의 부드러운 식감이 밋밋해질수 있는 식감과 국물맛을 더 고소하게 바꾼듯 합니다. 닭은 다른데보다 작은사이즈 인데 닭의 뱃속은 엄청 눌러담으셔서 모자리지 않았어요(여자양 기준) 남자들은 국물에 밥 추가로 말아먹으면 될듯요~ 그리고..., 평점 : 5, 날짜 : 2021.01.13.
# 리뷰코드 : GC000144, 가게코드 : STORE_GC0029, ID : c4okq5, 리뷰 : 맛이 아주 그냥 짱입니다. 완전맛있어요.반찬 김치도 맛있어요!, 평점 : 5, 날짜 : 2018.11.30.
# 리뷰코드 : GC000145, 가게코드 : STORE_GC0029, ID : None, 리뷰 : 녹두삼계탕이 메인같지만 녹두를 시러라하는 난 오리지날 그냥 삼계탕~ 맛있따! 맛있어!, 평점 : None, 날짜 : 2013.08.09.
# 가게코드 : STORE_GC0030, 가계명 : 떡볶이랑걸레만두랑, 주소 : 서울 금천구 시흥대로58길 13, 지역 : (지번) 시흥동 885-10, 종류 : 떡볶이
# #### 떡볶이랑걸레만두랑
# 리뷰코드 : GC000146, 가게코드 : STORE_GC0030, ID : 11h2lo2, 리뷰 : 그렇게 맛나지도 않는데 드릅게 비쌈  비싸면 양이라도 많이주지 가격 또 올랐음 ㅜㅜ 으 , 평점 : 1, 날짜 : 2021.07.28.
# 리뷰코드 : GC000147, 가게코드 : STORE_GC0030, ID : 7ltqr9, 리뷰 : 30년전부터 대명시장 짜투리 골목에서 비닐쳐서 할머님 3~4분께서 낮은 의자놓고 장사하던 시절부터 다녔었죠. 입구쪽 할머님 며느님이 전부 물려받으신걸로 기억해요. 예전의 맛과 추억을  원하는건 아니지만 시흥을 떠나 살면서 가끔 시흥 갈때면 매번 포장해서 가지고 갔습니다. 아직도 현금 장사하시더군요. 뻥 조금 붙여서 시흥에서 현금은 제일 많은 가게라고 웃으면..., 평점 : 1, 날짜 : 2021.06.19.
# 리뷰코드 : GC000148, 가게코드 : STORE_GC0030, ID : fjp9mk, 리뷰 : 고추가루 묵은내 너무 나서 감점  맛은 괜찮았음, 평점 : 3, 날짜 : 2021.06.08.
# 리뷰코드 : GC000149, 가게코드 : STORE_GC0030, ID : 162i3as, 리뷰 : 꼬꼬맹이 시절부터 자주 왔는데 지금은 맛이 변해도 너무 변했다. 만두는 바삭함을 잃어서 흐물흐물하고 크기도 작아졌고 떡볶이는 떡 종류도 바뀌었고 국물맛도 변해서 만두랑 조합도 별로.. 심지어 떡에 심지가 씹힘. 3년전에 갔을땐 그나마 괜찮았는데 지금은 예전 그맛을 조금도 찾아볼 수 없어서 실망. 이럴거면 가격이라도 내리지ㅠㅠ, 평점 : 1, 날짜 : 2021.04.26.
# 리뷰코드 : GC000150, 가게코드 : STORE_GC0030, ID : 1igp34a, 리뷰 : 할머니들 시절부터 30년을 넘게 다니고 있지만  맛 ,양,가격, 친절도 모든것이 변했네요 저는 항상 현금만 내다가 시장보느라 다 써서 30년만에 처음으로 카드를 냈는데 거부 당했네요 신한카드 안된다고 해서 삼성페이 줬더니 어떻게 하는지 모른답니다 핸드폰을 카드 단말기에 가져다 대는것이 어려운거였군요  계좌입금 하니 사장이 좋아라 하네요 저 말고도 많은 손님..., 평점 : 1, 날짜 : 2021.04.13.
# 가게코드 : STORE_GC0031, 가계명 : 말뚝곱창 5호점, 주소 : 서울 금천구 벚꽃로38길 21 2층, 지역 : (지번) 가산동 44-1, 종류 : 곱창,막창
# #### 말뚝곱창 5호점
# 리뷰코드 : GC000151, 가게코드 : STORE_GC0031, ID : 16afmo3, 리뷰 : 쏘쏘, 평점 : 3, 날짜 : 2021.07.03.
# 리뷰코드 : GC000152, 가게코드 : STORE_GC0031, ID : mvi5nt, 리뷰 : 맛있어유!! 곱창도 신선하고 맛있게 잘 먹었어요~_~ 사모님?이 친절하셔서 기억에 남아효, 평점 : 4, 날짜 : 2021.06.07.
# 리뷰코드 : GC000153, 가게코드 : STORE_GC0031, ID : n2gbvo, 리뷰 : None, 평점 : 4, 날짜 : 2020.11.29.
# 리뷰코드 : GC000154, 가게코드 : STORE_GC0031, ID : l1dn2h, 리뷰 : 앞접시 달라니까 줄수없다는데 다른 테이블이 앞접시 달라하면 주고 사람 차별하나  곱창시키면 기본 30분은 있어야 나오고  계란후라이 하는 곳에는 계란후라이 담을 접시도 안놔주고  일단 계란후라이하는 후라이팬 자체도 너무 더러움  가장 중요한 것은 제일 맛있는게 곱창시키면 같이 나오는 떡임.. 그 이외 모든 음식의 맛이 최악 수준임.. 육회도 이렇게 맛없는 ..., 평점 : 1, 날짜 : 2020.01.23.
# 리뷰코드 : GC000155, 가게코드 : STORE_GC0031, ID : vhoglp, 리뷰 : 질겨요, 평점 : 1, 날짜 : 2019.12.20.
# 가게코드 : STORE_GC0032, 가계명 : 맥도날드 서울시흥DT점, 주소 : 서울 금천구 시흥대로 184, 지역 : (지번) 시흥동 903-4, 종류 : 패스트푸드
# #### 맥도날드 서울시흥DT점
# 리뷰코드 : GC000156, 가게코드 : STORE_GC0032, ID : djl7en, 리뷰 : 직원들 친절해요~ㅎ 할머니가 메뉴판 사용 못하시고 계시면 진~짜 바뿔때 아니면 직원이 나와서 해주고 외국사람이 와도 영어로 고객관리 잘함~ 집이 신림동인데 일주일에 세번 이상은 감~   ^^;, 평점 : 5, 날짜 : 2021.08.13.
# 리뷰코드 : GC000157, 가게코드 : STORE_GC0032, ID : 1im0023, 리뷰 : 빨리 나오고 맛있어요 ㅎㅎ, 평점 : 5, 날짜 : 2021.04.17.
# 리뷰코드 : GC000158, 가게코드 : STORE_GC0032, ID : h6dcfo, 리뷰 : 간만에 햄버거 땡겨서 왔는데 고기는 차갑고 빵은 질기고.. 먹어본중에 최악, 평점 : 1, 날짜 : 2021.02.21.
# 리뷰코드 : GC000159, 가게코드 : STORE_GC0032, ID : v0e2u8, 리뷰 : 먹어본 체인 중 가장 맛 없다 패티가 젤 아쉬움,  질겨서 턱 아픔, 평점 : 2, 날짜 : 2021.01.25.
# 리뷰코드 : GC000160, 가게코드 : STORE_GC0032, ID : beptmi, 리뷰 : 맘에 들어요~, 평점 : 5, 날짜 : 2021.01.15.
# 가게코드 : STORE_GC0033, 가계명 : 애슐리퀸즈 가산재능점, 주소 : 서울 금천구 가산디지털1로 186 제이플라츠 2층, 지역 : (지번) 가산동 459-11, 종류 : 패밀리레스토랑
# #### 애슐리퀸즈 가산재능점
# 리뷰코드 : GC000161, 가게코드 : STORE_GC0033, ID : 1dj6blu, 리뷰 : 민트초코 특집이라 갔는데 회전율 빠르고 무난했어요! 전반적으로 조금 달았는데 아마 애슐리 자체의 레시피라 어쩔 수 없는 듯ㅋㅋ 사람도 많았고 직원분들 친절하셨습니다, 평점 : 3, 날짜 : 2021.07.03.
# 리뷰코드 : GC000162, 가게코드 : STORE_GC0033, ID : 1138o8s, 리뷰 : 진짜…ㅜ 너무 맛없어요… 7만원돈이ㅠㅠ, 평점 : 1, 날짜 : 2021.06.20.
# 리뷰코드 : GC000163, 가게코드 : STORE_GC0033, ID : 8u4nvb, 리뷰 : 도대체 가산엔 제대로된 식당이 있긴한거야?, 평점 : 1, 날짜 : 2021.04.23.
# 리뷰코드 : GC000164, 가게코드 : STORE_GC0033, ID : qqber9, 리뷰 : 평범해요, 평점 : 3, 날짜 : 2021.03.23.
# 리뷰코드 : GC000165, 가게코드 : STORE_GC0033, ID : 1h99q70, 리뷰 : None, 평점 : 2, 날짜 : 2021.03.08.
# 가게코드 : STORE_GC0034, 가계명 : 우마왕, 주소 : 서울 금천구 범안로17길 9 한아마인드아파트 1층, 지역 : (지번) 독산동 1142, 종류 : 육류,고기
# #### 우마왕
# 리뷰코드 : GC000166, 가게코드 : STORE_GC0034, ID : up32f1, 리뷰 : 존맛탱구리, 평점 : 5, 날짜 : 2020.07.28.
# 리뷰코드 : GC000167, 가게코드 : STORE_GC0034, ID : 7nmg28, 리뷰 : 부드러운 고기, 평점 : 5, 날짜 : 2020.07.23.
# 리뷰코드 : GC000168, 가게코드 : STORE_GC0034, ID : h87ckk, 리뷰 : 최고에요, 평점 : 5, 날짜 : 2020.04.28.
# 리뷰코드 : GC000169, 가게코드 : STORE_GC0034, ID : l14jon, 리뷰 : Worth it, 평점 : 5, 날짜 : 2020.03.19.
# 리뷰코드 : GC000170, 가게코드 : STORE_GC0034, ID : r67rm8, 리뷰 : None, 평점 : 5, 날짜 : 2019.03.11.
# 가게코드 : STORE_GC0035, 가계명 : 풍년갈비, 주소 : 서울 금천구 디지털로12길 33, 지역 : (지번) 가산동 143-28, 종류 : 갈비
# #### 풍년갈비
# 리뷰코드 : GC000171, 가게코드 : STORE_GC0035, ID : 1e3r59n, 리뷰 : 갈비탕은  맛있어요  그러나 갈비탕에 배추김치와  깍두기가 나오는데  두가지 김치가너무 많이 없네요. , 평점 : 3, 날짜 : 2020.12.24.
# 리뷰코드 : GC000172, 가게코드 : STORE_GC0035, ID : flg9vs, 리뷰 : 잔 재주 안 부리고 기본에 충실한 집. 고기 굽는게 귀찮기는 하지만 추천합니다., 평점 : 5, 날짜 : 2020.01.27.
# 리뷰코드 : GC000173, 가게코드 : STORE_GC0035, ID : 14tgsu3, 리뷰 : 그냥 오래된집...특별히 맛집은 아니에요, 평점 : 2, 날짜 : 2019.12.19.
# 리뷰코드 : GC000174, 가게코드 : STORE_GC0035, ID : n047h9, 리뷰 : 그냥 오래되기만한집, 평점 : 1, 날짜 : 2018.05.07.
# 리뷰코드 : GC000175, 가게코드 : STORE_GC0035, ID : 7kfa5v, 리뷰 : None, 평점 : 2, 날짜 : 2016.04.21.
# 가게코드 : STORE_GC0036, 가계명 : 여신족발, 주소 : 서울 금천구 벚꽃로38길 21, 지역 : (지번) 가산동 44-1, 종류 : 족발,보쌈
# #### 여신족발
# 리뷰코드 : GC000176, 가게코드 : STORE_GC0036, ID : dhkl0u, 리뷰 : 조미료 족발., 평점 : 2, 날짜 : 2021.08.12.
# 리뷰코드 : GC000177, 가게코드 : STORE_GC0036, ID : fjp9mk, 리뷰 : 가디 에서 술약속 장소로 추천드립니다, 평점 : 5, 날짜 : 2021.04.18.
# 리뷰코드 : GC000178, 가게코드 : STORE_GC0036, ID : mukr45, 리뷰 : 맛있고 좋아요!, 평점 : 5, 날짜 : 2021.02.07.
# 리뷰코드 : GC000179, 가게코드 : STORE_GC0036, ID : 1eqvp4n, 리뷰 : 말할 시간에 하나 더 먹고 싶은 맛이며 이렇게 느끼하지 않은 족발 처음 먹어봄 또한 다른 집은 막국수를 팔지만 이곳은 비빔국수를 판다. 비빔국수 맛있음 다만 비빔국수가 조금 더 자극적이어도 나쁘지 않을 듯^^, 평점 : 5, 날짜 : 2021.01.10.
# 리뷰코드 : GC000180, 가게코드 : STORE_GC0036, ID : 16gr9op, 리뷰 : 가보세요., 평점 : 5, 날짜 : 2021.01.04.
# 가게코드 : STORE_GC0037, 가계명 : 이화룡불짬뽕, 주소 : 서울 금천구 시흥대로122길 15 1층, 지역 : (지번) 독산동 285-23, 종류 : 중화요리
# #### 이화룡불짬뽕
# 리뷰코드 : GC000181, 가게코드 : STORE_GC0037, ID : ghki4k, 리뷰 : 단언컨데 이집의 차돌짬뽕은 금천구 최고의 짬뽕임, 평점 : 5, 날짜 : 2021.07.25.
# 리뷰코드 : GC000182, 가게코드 : STORE_GC0037, ID : 19h1cpf, 리뷰 : 짬뽕 1타 이화룡 불짬뽕. 많이 안 맵고 얼큰하니 정말 맛있음. 가격도 훌륭. 사장님도 친절하심. 한 번도 안 먹을 수는 있어도 한 번만 먹을 수는 없는 곳. 여기서 짬뽕 먹으면 다른곳 짬뽕은 눈에도 안 들어옴., 평점 : 5, 날짜 : 2021.06.30.
# 리뷰코드 : GC000183, 가게코드 : STORE_GC0037, ID : 165sn65, 리뷰 : 국물이 찐~~~~해요 . 가벼운 조미료 듬뿍 들어간 싸구려 국물이 아닌 찐국물 ! 근데 면이 너무 얇아서 면은 별로고 밥이랑 같이 먹는데 더 맛날듯 , 평점 : 5, 날짜 : 2021.05.23.
# 리뷰코드 : GC000184, 가게코드 : STORE_GC0037, ID : 1jimfdk, 리뷰 : 금천구 원탑 짬뽕집은 이곳입니다. 꼭드셔보세요   특히 차돌짬뽕은 크으으으 ~~~ 진짜 죽여줍니다., 평점 : 5, 날짜 : 2021.05.13.
# 리뷰코드 : GC000185, 가게코드 : STORE_GC0037, ID : u71ucl, 리뷰 : 엄청 불친절하네요 음식은 엄청짜구요, 평점 : 1, 날짜 : 2021.04.01.
# 가게코드 : STORE_GC0038, 가계명 : 슈케익하우스, 주소 : 서울 금천구 시흥대로63길 3, 지역 : (지번) 시흥동 121, 종류 : 음식점
# #### 슈케익하우스
# 리뷰코드 : GC000186, 가게코드 : STORE_GC0038, ID : 1hvak9n, 리뷰 : 조카생일이라서 생일 케이크 예약하러갔습니다. 주문할때 부터 제가 예약한날 케이크예약이 많다고 달력을 확인하더라구요 제가원하는케이크에 대해  얘기하는데  일반케이크 아니고 주문케이크라 돈 추가 된다는얘기만 하시더라구요 레터링도 몇자가 들어가고  얼마가 추가되는지도 말안해줘서 제가 레터링 못 넣으냐 물어보니 그제서야 10자이상 2천원이라 하더군요 제가말한거에 ..., 평점 : 2, 날짜 : 2021.03.28.
# 리뷰코드 : GC000187, 가게코드 : STORE_GC0038, ID : ms2qv4, 리뷰 : 밤에 늦게 갔는데 친절하게 맞아주시고 급하게 딸기케익주문했는데 완전 딸기가 난리가 나요~~!!! 이동네 주민은아닌데 지나는길에 들렸는데 너무 좋은기분을 들게 해주셨어요~~^-^ 1주년축하드려용, 평점 : 5, 날짜 : 2021.03.13.
# 리뷰코드 : GC000188, 가게코드 : STORE_GC0038, ID : 1d1ua3b, 리뷰 : Best, 평점 : 5, 날짜 : 2020.10.24.
# 가게코드 : STORE_GC0039, 가계명 : 니하우, 주소 : 서울 금천구 벚꽃로38길 32-43, 지역 : (지번) 가산동 83-1, 종류 : 양꼬치
# #### 니하우
# 리뷰코드 : GC000189, 가게코드 : STORE_GC0039, ID : 9e3ja6, 리뷰 : 맛있는데.. 사람이너무많아서.. 주문이 밀려요.., 평점 : 3, 날짜 : 2021.07.01.
# 리뷰코드 : GC000190, 가게코드 : STORE_GC0039, ID : 126kre5, 리뷰 : None, 평점 : 3, 날짜 : 2021.06.30.
# 리뷰코드 : GC000191, 가게코드 : STORE_GC0039, ID : 14cum87, 리뷰 : 시간 넘쳐나는 분 가세요 양꼬치에 숯 나오는데 40분 걸리는 양꼬치집은 처음 봅니다 진짜 어이가 없어서 너무 오래 기다린 거 같다고 하니까 순서대로 나오는 거라고 하네요 순서 40분 기다리실 분 가세요 참고로 옆테이블은 저희 다 먹을 때까지 안나왔어요  무슨 장작 패서 숯 만드는 줄 알았네 어이가 없어 아니 쓰다보니가 화나네 30분 기다리고 밑반찬 받아서 ..., 평점 : 1, 날짜 : 2021.05.21.
# 리뷰코드 : GC000192, 가게코드 : STORE_GC0039, ID : mp5qra, 리뷰 : 육즙도 많고 가격도 적당하고 가게 외관 내부 모두 깔끔하고 멋있다. 넓어서 모임하거나 적당히 거리두고 먹기도 좋음!, 평점 : 5, 날짜 : 2020.12.18.
# 리뷰코드 : GC000193, 가게코드 : STORE_GC0039, ID : qtdph6, 리뷰 : 가게가 정말 깨끗하고 양꼬치 초보자도 거부감없이 먹을 만큼 잡내가 없어요 , 평점 : 5, 날짜 : 2020.10.23.
# 가게코드 : STORE_GC0040, 가계명 : 스튜디오레이크, 주소 : 서울 금천구 디지털로 210 지하 1층, 지역 : (지번) 가산동 140-26, 종류 : 카페
# #### 스튜디오레이크
# 리뷰코드 : GC000194, 가게코드 : STORE_GC0040, ID : 15ejn78, 리뷰 : 조아욤 자주 가요 와인 많이 시키면 사장님이 서비스도 자주 줘서 조아욤, 평점 : 5, 날짜 : 2021.05.31.
# 리뷰코드 : GC000195, 가게코드 : STORE_GC0040, ID : r6q0o1, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.21.
# 리뷰코드 : GC000196, 가게코드 : STORE_GC0040, ID : eolfu3, 리뷰 : 치킨 맛있고 분위기 좋아요! 다음에는 와인 마시러 또 가게요, 평점 : 5, 날짜 : 2021.04.17.
# 리뷰코드 : GC000197, 가게코드 : STORE_GC0040, ID : bf1m77, 리뷰 : 분위기맛집 템프라닐로가 있어서 좋았다, 평점 : 5, 날짜 : 2020.10.08.
# 리뷰코드 : GC000198, 가게코드 : STORE_GC0040, ID : u6uq98, 리뷰 : 분위기에 취한ㄷr...☆ 와인을 잘 안먹는 사람도 가면 반할 분위기에요., 평점 : 5, 날짜 : 2020.06.26.
# 가게코드 : STORE_GC0041, 가계명 : 노브랜드버거 가산디지털단지점, 주소 : 서울 금천구 벚꽃로 286 삼성리더스타워 1층 109호, 지역 : (지번) 가산동 60-15, 종류 : 패스트푸드
# #### 노브랜드버거 가산디지털단지점
# 리뷰코드 : GC000199, 가게코드 : STORE_GC0041, ID : 7kvkpk, 리뷰 : 버거하고 감튀 둘다 무난하게 맛있음, 평점 : 5, 날짜 : 2021.08.12.
# 리뷰코드 : GC000200, 가게코드 : STORE_GC0041, ID : 15ti57b, 리뷰 : 여기 버거 맛있습니다. 다른거 말고 기본인, 불고기버거 드세요. 그게 가장 맛있습니다. 이제 전, 여기서 불고기버거 4개 먹고, 옆집 커피 맛집인 맥도날드 갑니다., 평점 : 4, 날짜 : 2021.07.27.
# 리뷰코드 : GC000201, 가게코드 : STORE_GC0041, ID : o30mi4, 리뷰 : 매장이 너무 지저분..., 평점 : 2, 날짜 : 2021.05.14.
# 리뷰코드 : GC000202, 가게코드 : STORE_GC0041, ID : 7lo5s7, 리뷰 : 호기심에 한 번 가봤는데 다시 안갈 듯. 가성비 안나오고 매장 내 환기가 안되서 기름냄새 쩐다..., 평점 : 2, 날짜 : 2021.05.13.
# 리뷰코드 : GC000203, 가게코드 : STORE_GC0041, ID : r8ac8e, 리뷰 : 딱 그 가격에서 기대할 수 있는 정도의 퀄리티와 양입니다. 음식은 나쁘지 않았는데.... 오늘만 유독 심했던건지는 몰라도 매장 안에 기름 탄냄새가 엄청많이 나더라구요, 평점 : 3, 날짜 : 2021.04.06.
# 가게코드 : STORE_GC0042, 가계명 : 동산미, 주소 : 서울 금천구 가산디지털2로 138-1, 지역 : (지번) 가산동 458-31, 종류 : 육류,고기
# #### 동산미
# 리뷰코드 : GC000204, 가게코드 : STORE_GC0042, ID : 13n9n4j, 리뷰 : 돼지고기 냄새나고 삼겹살 일인분양이 진짜 적습니다 평범한사람 4명이 배채우려면 6인분은 시켜야되요, 평점 : 1, 날짜 : 2021.04.30.
# 리뷰코드 : GC000205, 가게코드 : STORE_GC0042, ID : 196q0m0, 리뷰 : 서비스 정말 최악입니다. 새우만 따로 주문 된다길래 새우 따로 주문했더니 못알아듣고 안주시고, 다시 달라 하니깐 원래 말씀하신 마리수 보다 2마리 덜 주시더군요. 여기까진 뭐 실수할 수 있겠다 싶었는데 마지막에 볶음밥 주문했는데 하도 안나오길래 주문 들어갔냐고 여쭤보니 주문 안하지 않았냐고, 주문할때 무슨볶음밥 먹을지 물어보셨으면서 책임을 저희한태 덮어 씌..., 평점 : 1, 날짜 : 2021.04.01.
# 리뷰코드 : GC000206, 가게코드 : STORE_GC0042, ID : glt7ll, 리뷰 : 갑오징어 & 삼겹살 조합 너무 괜찮았고요~ 반찬으로 나오는 콩나물파채무침 대박; 총 3접시를 먹음;;;; -_-;;;;; 마무리 볶음밥은 필수~~  < 연탄초벌삼겹살 동산미 > 2020/07/16 (목) 2인 동산미스페셜2 ￦29,000 ( 갑오징어 + 삼겹살 ) 삼겹살 1인분 추가 ￦12,000 동산미칡냉면 ￦5,000 ( 후식볶음밥 서비스 ) 총합계 ￦..., 평점 : 5, 날짜 : 2020.07.21.
# 리뷰코드 : GC000207, 가게코드 : STORE_GC0042, ID : None, 리뷰 : 해물철판볶음밥 점심으로 딱. 가끔씩!, 평점 : 3, 날짜 : 2016.04.11.
# 리뷰코드 : GC000208, 가게코드 : STORE_GC0042, ID : None, 리뷰 : 맛있어욜~, 평점 : None, 날짜 : 2013.09.05.
# 가게코드 : STORE_GC0043, 가계명 : 우리소양평해장국 본점, 주소 : 서울 금천구 범안로 1244, 지역 : (지번) 독산동 1035-1, 종류 : 해장국
# #### 우리소양평해장국 본점
# 리뷰코드 : GC000209, 가게코드 : STORE_GC0043, ID : 1iq4808, 리뷰 : 양선지가 진짜 맛잇어요, 평점 : 5, 날짜 : 2021.05.15.
# 리뷰코드 : GC000210, 가게코드 : STORE_GC0043, ID : e4m52f, 리뷰 : 정말 맛집입니다. 코로나로 밤 10시에 영업이 끝나니 참고하세요 ㅎㅎ, 평점 : 5, 날짜 : 2021.04.17.
# 리뷰코드 : GC000211, 가게코드 : STORE_GC0043, ID : v0e2u8, 리뷰 : 양선지 괜찮네~, 평점 : 3, 날짜 : 2020.12.13.
# 리뷰코드 : GC000212, 가게코드 : STORE_GC0043, ID : 1ar91or, 리뷰 : 양선지해장국 맛있어서 3일연속가는중, 평점 : 5, 날짜 : 2020.10.21.
# 리뷰코드 : GC000213, 가게코드 : STORE_GC0043, ID : csgujd, 리뷰 : 술먹은 다음날 해장하기 좋은 메뉴들이 많음, 평점 : 3, 날짜 : 2020.05.26.
# 가게코드 : STORE_GC0044, 가계명 : 흥부전놀부전, 주소 : 서울 금천구 남부순환로108길 28, 지역 : (지번) 가산동 142-34, 종류 : 한정식
# #### 흥부전놀부전
# 리뷰코드 : GC000214, 가게코드 : STORE_GC0044, ID : k4s3ks, 리뷰 : None, 평점 : 5, 날짜 : 2021.06.12.
# 리뷰코드 : GC000215, 가게코드 : STORE_GC0044, ID : 7ll1d2, 리뷰 : 육전은 생각보다 별로였지만, 해물파전이랑 감자전 먹다보면 나도모르게 감동의 눈물 흘리고있음, 평점 : 4, 날짜 : 2021.05.31.
# 리뷰코드 : GC000216, 가게코드 : STORE_GC0044, ID : 1879e1b, 리뷰 : None, 평점 : 1, 날짜 : 2021.04.21.
# 리뷰코드 : GC000217, 가게코드 : STORE_GC0044, ID : mv4tfv, 리뷰 : 맛있어요, 평점 : 5, 날짜 : 2020.09.07.
# 리뷰코드 : GC000218, 가게코드 : STORE_GC0044, ID : 101ofin, 리뷰 : None, 평점 : 2, 날짜 : 2019.05.20.
# 가게코드 : STORE_GC0045, 가계명 : 딥, 주소 : 서울 금천구 범안로 1249 1층, 지역 : (지번) 독산동 1026-15, 종류 : 호프,요리주점
# #### 딥
# 리뷰코드 : GC000219, 가게코드 : STORE_GC0045, ID : o4nfs1, 리뷰 : None, 평점 : 5, 날짜 : 2021.04.28.
# 리뷰코드 : GC000220, 가게코드 : STORE_GC0045, ID : 14mmm78, 리뷰 : None, 평점 : 5, 날짜 : 2021.04.09.
# 리뷰코드 : GC000221, 가게코드 : STORE_GC0045, ID : mud9g1, 리뷰 : 맛이있고요 가격대가 있지만 맛있습니다, 평점 : 5, 날짜 : 2021.04.08.
# 리뷰코드 : GC000222, 가게코드 : STORE_GC0045, ID : 14ndk0c, 리뷰 : 분위기도 좋고 음식도 맛있습니다. 다만 상황에 따라 조금 시끄럽긴 합니다., 평점 : 5, 날짜 : 2020.10.18.
# 리뷰코드 : GC000223, 가게코드 : STORE_GC0045, ID : h2j73d, 리뷰 : 분위기도 좋고. 직원분들도 친절했어요 스키야키도 엄청 맛있었습니다 :), 평점 : 5, 날짜 : 2019.06.14.
# 가게코드 : STORE_GC0046, 가계명 : 파티엘하우스, 주소 : 서울 금천구 디지털로 173 엘리시아 빌딩 3층, 지역 : (지번) 가산동 60-69, 종류 : 뷔페
# #### 파티엘하우스
# no review in extract
# 가게코드 : STORE_GC0047, 가계명 : 스타벅스 금천독산점, 주소 : 서울 금천구 두산로 70 남서울현대지식산업센터 T로비층 108호, 지역 : (지번) 독산동 291-1, 종류 : 커피전문점
# #### 스타벅스 금천독산점
# 리뷰코드 : GC000224, 가게코드 : STORE_GC0047, ID : 10hi1fo, 리뷰 : 직원분들도 친절하시고 그리 넓지는 않지만 사람들도 그다지 많지 않아서 출장 중 잠시 들러 급한업무 잘보았네요., 평점 : 5, 날짜 : 2021.06.24.
# 리뷰코드 : GC000225, 가게코드 : STORE_GC0047, ID : 7u3i33, 리뷰 : 큰길이 아닌 곳에 있어서 그런지 사람이 적은 편이라 좋았습니다. 마스크 안 끼고 진상부리는 할아버지 대응하느라 고생하시는 모습이 안타까웠어요. 주문부터 음료 받을때까지 직원분들 전부 밝게 인사해주시고 친절하셨는데ㅜㅜ  다음에 독산가면 금천독산점으로 갈 것 같아요!, 평점 : 5, 날짜 : 2021.06.10.
# 리뷰코드 : GC000226, 가게코드 : STORE_GC0047, ID : bhngv1, 리뷰 : 매장은 좀 소규모라서 편안한 분위기인지는 모르겠지만 서비스가 정말 만족스럽네요. 게다가 역근처여서 접근성이 좋고, 매장도 깔끔합니다., 평점 : 5, 날짜 : 2021.06.03.
# 리뷰코드 : GC000227, 가게코드 : STORE_GC0047, ID : 13iubnh, 리뷰 : 친절하고 빠르고 좋아요, 평점 : 5, 날짜 : 2021.03.11.
# 리뷰코드 : GC000228, 가게코드 : STORE_GC0047, ID : n09dr7, 리뷰 : 직원분들 친절스 ..., 평점 : 5, 날짜 : 2021.03.11.
# 가게코드 : STORE_GC0048, 가계명 : 논빼미돼지볶음, 주소 : 서울 금천구 시흥대로 185, 지역 : (지번) 시흥동 991-14, 종류 : 불고기,두루치기
# #### 논빼미돼지볶음
# 리뷰코드 : GC000229, 가게코드 : STORE_GC0048, ID : 1dmvsk4, 리뷰 : 찐 맛있어요~^^ 다음에 또 먹으러 가겠습니다.!, 평점 : 5, 날짜 : 2021.06.21.
# 리뷰코드 : GC000230, 가게코드 : STORE_GC0048, ID : 1ktaa40, 리뷰 : 맛있어요~담에 또갈듯, 평점 : 5, 날짜 : 2021.06.20.
# 리뷰코드 : GC000231, 가게코드 : STORE_GC0048, ID : 974768, 리뷰 : 좀 달다..., 평점 : 2, 날짜 : 2021.06.11.
# 리뷰코드 : GC000232, 가게코드 : STORE_GC0048, ID : fkaj5m, 리뷰 : 가격대비 맛도 괜찮고 양도 괜찮아요, 평점 : 4, 날짜 : 2020.11.02.
# 리뷰코드 : GC000233, 가게코드 : STORE_GC0048, ID : 1470tsd, 리뷰 : 정말 맛집 , 평점 : 5, 날짜 : 2020.05.01.
# 가게코드 : STORE_GC0049, 가계명 : 탐나종합어시장 시흥사거리점, 주소 : 서울 금천구 금하로 636, 지역 : (지번) 시흥동 884-1, 종류 : 회
# #### 탐나종합어시장 시흥사거리점
# 리뷰코드 : GC000234, 가게코드 : STORE_GC0049, ID : 1irbouf, 리뷰 : 그제 광어 33000짜리 포장 했는데 진짜 양이 절반으로 줄었다 집에와서 보니 속은기분 이었다  배짱장사 누구에게도 추천하고 싶지않다 별 하나도 아깝다 포장시 써비스도 전혀없다 두번다시 거래 않한다, 평점 : 1, 날짜 : 2021.06.27.
# 리뷰코드 : GC000235, 가게코드 : STORE_GC0049, ID : ldk523, 리뷰 : 진짜 별로다 상차림별도 매운탕도 별도... 문제는 맛도 별로..., 평점 : 1, 날짜 : 2020.10.15.
# 리뷰코드 : GC000236, 가게코드 : STORE_GC0049, ID : 7kdtnp, 리뷰 : 엄청나게 별로 베짱 영업함, 평점 : 1, 날짜 : 2020.07.10.
# 리뷰코드 : GC000237, 가게코드 : STORE_GC0049, ID : 13n3fg9, 리뷰 : 회전율이 좋아 신선하고 서울서 먹는 회치고는 가성비가 좋다, 평점 : 4, 날짜 : 2020.05.10.
# 리뷰코드 : GC000238, 가게코드 : STORE_GC0049, ID : bfim3m, 리뷰 : None, 평점 : 3, 날짜 : 2017.08.29.
# 가게코드 : STORE_GC0050, 가계명 : 동남집, 주소 : 서울 금천구 디지털로9길 99 스타밸리 1층 105,106호, 지역 : (지번) 가산동 60-11, 종류 : 갈비
# #### 동남집
# 리뷰코드 : GC000239, 가게코드 : STORE_GC0050, ID : dfv2ia, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.01.
# 리뷰코드 : GC000240, 가게코드 : STORE_GC0050, ID : kb4m89, 리뷰 : 갈비탕 먹었습니다. 고기가 좀 질기네요. 갈비대에 붙어있는것이. 그래서 맛있다는 생각은 안들고 갈비탕이네 라는 생각으로 먹었습니다., 평점 : 3, 날짜 : 2021.03.09.
# 리뷰코드 : GC000241, 가게코드 : STORE_GC0050, ID : qkva4f, 리뷰 : 국물이 깔끔하고 양도 많아 든든하다 고기도 많이 들어있고 면 사리와 공깃밥도 더 먹을 수 있어 배가 많이 부른 맛집. 깍두기와 김치도 잘 어울린다., 평점 : 5, 날짜 : 2020.02.03.
# 리뷰코드 : GC000242, 가게코드 : STORE_GC0050, ID : qgbdmp, 리뷰 : 맑지만 깊이있고 은근 맛난 국물. 양지곰탕에 보들보들한 고기가 한가득. 덜 익어서 더 맛있는 깍두기도 맛나고. (배추 김치는 아쉽..) 소면 사리까지 공짜로 주문해서 먹으면 담날 아침까지 배가 든든함. 조만간 재방문 예정., 평점 : 5, 날짜 : 2019.02.26.
# 리뷰코드 : GC000243, 가게코드 : STORE_GC0050, ID : lfb4jd, 리뷰 : 갈비탕만큼 비빔사리 맛도 끝내줘요, 평점 : 5, 날짜 : 2019.02.25.
# 가게코드 : STORE_GC0051, 가계명 : 가산통통, 주소 : 서울 금천구 가산디지털1로 168 우림라이온스밸리 A-2019호, 지역 : (지번) 가산동 371-28, 종류 : 육류,고기
# #### 가산통통
# 리뷰코드 : GC000244, 가게코드 : STORE_GC0051, ID : k6kco7, 리뷰 : 고기 질이 좋아요, 평점 : 5, 날짜 : 2021.06.21.
# 리뷰코드 : GC000245, 가게코드 : STORE_GC0051, ID : 1hv2omn, 리뷰 : 맛있게 잘먹고 갑니다, 평점 : 4, 날짜 : 2021.06.12.
# 리뷰코드 : GC000246, 가게코드 : STORE_GC0051, ID : bijcl2, 리뷰 : 너무좋아요, 평점 : 5, 날짜 : 2021.05.04.
# 리뷰코드 : GC000247, 가게코드 : STORE_GC0051, ID : 10f3q7e, 리뷰 : 고기 맛집! 친절하셔서 즐겁게 저녁 먹었습니다ㅎㅎ, 평점 : 5, 날짜 : 2021.04.21.
# 리뷰코드 : GC000248, 가게코드 : STORE_GC0051, ID : 1457pim, 리뷰 : 저녁에 와서 그런가 불친절하신 직원분 불친절한 가격대비 고기량 불친절한 반찬수.. 다시는 안올고깃집.., 평점 : 1, 날짜 : 2021.03.21.
# 가게코드 : STORE_GC0052, 가계명 : 복숭아꽃살구꽃, 주소 : 서울 금천구 벚꽃로38길 32-53, 지역 : (지번) 가산동 83-26, 종류 : 호프,요리주점
# #### 복숭아꽃살구꽃
# 리뷰코드 : GC000249, 가게코드 : STORE_GC0052, ID : gskfa0, 리뷰 : 개오졋다 기본안주.... 안경 쓰신 알바생분 너무 친절쓰...갬덩스...안주 ㅈㅁㅌ..., 평점 : 5, 날짜 : 2021.06.24.
# 리뷰코드 : GC000250, 가게코드 : STORE_GC0052, ID : ar37fs, 리뷰 : 분위기 좋아요 종업원분들 모두친절하시고요, 평점 : 5, 날짜 : 2021.06.17.
# 리뷰코드 : GC000251, 가게코드 : STORE_GC0052, ID : 1088jgk, 리뷰 : 11월 13일 영업합니다., 평점 : 5, 날짜 : 2020.11.14.
# 리뷰코드 : GC000252, 가게코드 : STORE_GC0052, ID : qpr2a4, 리뷰 : 도대체 언제 문열어요?, 평점 : 1, 날짜 : 2020.07.06.
# 리뷰코드 : GC000253, 가게코드 : STORE_GC0052, ID : csgujd, 리뷰 : 가정집을 개조한 비교적 젊은 분위기의 2차 하기 좋은곳, 평점 : 3, 날짜 : 2020.05.19.
# 가게코드 : STORE_GC0053, 가계명 : 도넛인사이드도넛, 주소 : 서울 금천구 시흥대로141길 81 1층, 지역 : (지번) 독산동 144-6, 종류 : 도넛
# #### 도넛인사이드도넛
# 리뷰코드 : GC000254, 가게코드 : STORE_GC0053, ID : 123d6ng, 리뷰 : 맛있는 도넛, 맛있는 커피! 그리고 실내도 좋습니다., 평점 : 5, 날짜 : 2021.07.21.
# 리뷰코드 : GC000255, 가게코드 : STORE_GC0053, ID : 9ej4fg, 리뷰 : 맛있어서 몇번 사먹었어요~ 5개 다 사서 저녁에 먹으려보니 초코도넛이 그새 상했네요ㅜㅜ 다른건 괜찮았고요. 실온에 두고 드실 분은 꼭 냉장보관하세요!, 평점 : 4, 날짜 : 2021.07.04.
# 리뷰코드 : GC000256, 가게코드 : STORE_GC0053, ID : r4roa0, 리뷰 : 도넛 진짜 맛있어용... 말차 도넛최애... 바깥 작은 테라스에서 강아지랑 함께 쉴수있어서 좋아요...!, 평점 : 5, 날짜 : 2021.05.02.
# 리뷰코드 : GC000257, 가게코드 : STORE_GC0053, ID : me0lbp, 리뷰 : 또 먹으러 가고싶은..., 평점 : 5, 날짜 : 2021.02.19.
# 가게코드 : STORE_GC0054, 가계명 : 금대한우도매식당, 주소 : 서울 금천구 범안로21길 19, 지역 : (지번) 독산동 293-4, 종류 : 육류,고기
# #### 금대한우도매식당
# 리뷰코드 : GC000258, 가게코드 : STORE_GC0054, ID : nebvh2, 리뷰 : 친절하든대??ㅋㅋㅋ 밑에있는 사람들이 손님이라고 갑질한건 아이고?ㅋㅋ 갈비탕 먹었는대 양은  다른곳에 비해 많긴함 괜춘함, 평점 : 5, 날짜 : 2020.12.27.
# 리뷰코드 : GC000259, 가게코드 : STORE_GC0054, ID : 13uq4og, 리뷰 : 맛잇어염 친절하시던데, 평점 : 4, 날짜 : 2020.10.25.
# 리뷰코드 : GC000260, 가게코드 : STORE_GC0054, ID : t90j8r, 리뷰 : 맛을 떠나서 직원들이 손님을 무시함. 셀프바가 있어서 반찬리필하러 갔더니 거기 반찬없다고 필요한거 있음 부르라고 오히려 뭐라고함.  민망해서 혼났음. 운영안할거면 셀프바를 없애던가 하지 . 오히려 미안해야 할 사람은 가게 인데 손님을 무시함. 원래 손님이 많앗던 곳인데 직원들 서비스 마인드가 개판이라 손님이 없어진 전형적인 케이스임., 평점 : 1, 날짜 : 2020.08.04.
# 리뷰코드 : GC000261, 가게코드 : STORE_GC0054, ID : sk2v21, 리뷰 : 정육코너에서 골라서 먹을수 있어요. 친절함., 평점 : 5, 날짜 : 2020.07.29.
# 리뷰코드 : GC000262, 가게코드 : STORE_GC0054, ID : gv5bck, 리뷰 : 맛집 인정   서빙친절. 맛최고 갈비탕 정말 맛나게 잘먹었네요. 광고 아님  비빔 물냉 맛있음 만족 오랫만에 맛집찾아 기분짱임 정말 가족이와서 맛나게먹음, 평점 : 5, 날짜 : 2019.12.14.
# 가게코드 : STORE_GC0055, 가계명 : 로, 주소 : 서울 금천구 디지털로9길 47 한신IT타워 2차 1층 103호, 지역 : (지번) 가산동 60-18, 종류 : 육류,고기
# #### 로
# 리뷰코드 : GC000263, 가게코드 : STORE_GC0055, ID : utm8cl, 리뷰 : 불친절하다는 얘기듣고 가서  그래 밥만 기대하자 하고 갔는데 사장님 친절하게 고기 잘 구워주셔서 안도했스브니다..?  고기가 일단 미쳤어요 식어도 맛있는건 삼겹살 마지막에 된장밥이랑 먹는데 어우 식어도 맛있음  국내에서 먹은 이베리코중에 최상입니다 숙성고기라 토욜엔 물량이 없을수있어서 전화하고 가봐야합니다  2인 삼겹살 2인분에 항정1인분추가 하고 된장밥도..., 평점 : 5, 날짜 : 2021.07.31.
# 리뷰코드 : GC000264, 가게코드 : STORE_GC0055, ID : l7bkk0, 리뷰 : 직원분들이 항상 좀 불친절합니다. 여자친구랑 자주 가긴하는데 가산에 먹을만한데가 없어서 가는것도 있지만. 풍체가 좀 있으신 직원분 말고는 다 불친절해요..고기에대한 설명도 안해주고,뭔가 화가 나신듯합니다.. 고기도 다 안먹었는데 불빼시고.. 안빼면 안되냐고하면 안된다고 빼야한다고 그러심.. 고기올려두는 돌?그릇은 좀 고기올리면 빼시면 좋겠음..전에 직원분이..., 평점 : 2, 날짜 : 2020.12.10.
# 리뷰코드 : GC000265, 가게코드 : STORE_GC0055, ID : 1d49q93, 리뷰 : -개념없는 남 종업원 2명과 여종업원 1명- 오늘 점심때 일입니다. 방문한 시간 자리는 비워져 있었으나 치워지지 않은 상태였고 남종업원1이 와서 자리 치우고 안내 주겠다고 했고, 잠시뒤 남종업원2가 다시 와서 자리 치우고 안내하겠다고 또 말해서 불길한 예감이 들었으나 기달렸죠.  남종업원 2명은 각자 서빙하고 치울 생각은 없어 보였으나 바쁘니까 그럴수 있다..., 평점 : 1, 날짜 : 2020.10.27.
# 리뷰코드 : GC000266, 가게코드 : STORE_GC0055, ID : bf1m77, 리뷰 : 고기맛이 진짜 최고 ㅠㅠㅠㅠ, 평점 : 5, 날짜 : 2020.10.08.
# 리뷰코드 : GC000267, 가게코드 : STORE_GC0055, ID : ljt7g6, 리뷰 : 비싸긴한데 맛있다., 평점 : 4, 날짜 : 2020.08.08.
# 가게코드 : STORE_GC0056, 가계명 : 삼대족발 금천점, 주소 : 서울 금천구 시흥대로 196, 지역 : (지번) 시흥동 890-14, 종류 : 족발,보쌈
# #### 삼대족발 금천점
# 리뷰코드 : GC000268, 가게코드 : STORE_GC0056, ID : 147sqhh, 리뷰 : 그냥 동네 족발맛, 평점 : 2, 날짜 : 2021.05.16.
# 리뷰코드 : GC000269, 가게코드 : STORE_GC0056, ID : muv9m5, 리뷰 : 굳이 찾아가서 먹을 필요 없는 맛. 보통 배달 족발맛.. 식은 상태로 나와서 약간 냄새나고 그냥 그래요. 막국수는 새콤하니 괜찮지만 건포도 빼달라고 하세요. 암튼 별로.., 평점 : 1, 날짜 : 2019.09.11.
# 리뷰코드 : GC000270, 가게코드 : STORE_GC0056, ID : 10g62nc, 리뷰 : 맛있게 잘먹었습니다. 족발 먹고 싶을땐 항상 맨먼저 생각납니다. 자주 가는데 서비스가 없는게 조금 아쉽지만  그래도 족발이 맛있고 양도 충분해서 나름 만족 합니다. 또 먹으러 가겠습니다., 평점 : 5, 날짜 : 2019.07.23.
# 리뷰코드 : GC000271, 가게코드 : STORE_GC0056, ID : 10f2ptm, 리뷰 : 장점 ㅡ 100% 국내산 족발, 퍼석하지않은 부드러운 식감과 아침저녁으로 새로 삶아져 나오는 신선한 맛. 개인적으로 삶을때 마지막에 쫄여져서 나오는 족발의 짭조름한 맛이 최고~ ^-^b 자주 다녀서 단골로 사장님하고 친해지면 팍팍 쏟아지는 서비스!  단점 ㅡ 막국수 서비스 없음, 장수막걸리밖에 막걸리 안들어옴, 과일소주없음(이슬톡톡은 있음), 쿨피스 없음(..., 평점 : 5, 날짜 : 2019.05.24.
# 리뷰코드 : GC000272, 가게코드 : STORE_GC0056, ID : k86jml, 리뷰 : 매장도 깨끗하고 족발도 맛있는 집이에요, 평점 : 5, 날짜 : 2018.08.21.
# 가게코드 : STORE_GC0057, 가계명 : 인생양대창, 주소 : 서울 금천구 시흥대로52길 42 1층, 지역 : (지번) 시흥동 888-5, 종류 : 곱창,막창
# #### 인생양대창
# 리뷰코드 : GC000273, 가게코드 : STORE_GC0057, ID : e4mkcq, 리뷰 : 정말 맛있네요 금천구에서 갑입니다, 평점 : 5, 날짜 : 2021.07.30.
# 리뷰코드 : GC000274, 가게코드 : STORE_GC0057, ID : 15j66ua, 리뷰 : 인생 곱창집 발견^,.^, 평점 : 5, 날짜 : 2020.11.21.
# 가게코드 : STORE_GC0058, 가계명 : 스시히또 가산점, 주소 : 서울 금천구 벚꽃로 286 삼성리더스타워 지하1층 114호, 지역 : (지번) 가산동 60-15, 종류 : 초밥,롤
# #### 스시히또 가산점
# 리뷰코드 : GC000275, 가게코드 : STORE_GC0058, ID : rl2kts, 리뷰 : 사시미는 괜찮았습니다만 샤리가 너무 뻑뻑하고 맛이 없네요. 이렇게 진밥같은 샤리는 처음 먹어봅니다.  그리고 아무리 사시미가 나온다지만 4만원 오마카세에 스시 8조각 나오는거 실화입니까. 테이블 자리였는데 서버 분은 스시가 뭐가 뭔지 하나도 모른채 서빙하기 바쁘고.. 다시 갈 것 같진 않네요., 평점 : 1, 날짜 : 2021.07.27.
# 리뷰코드 : GC000276, 가게코드 : STORE_GC0058, ID : m28j64, 리뷰 : 여기 맞죠?, 평점 : 1, 날짜 : 2021.07.03.
# 리뷰코드 : GC000277, 가게코드 : STORE_GC0058, ID : 1ev93f8, 리뷰 : None, 평점 : 1, 날짜 : 2021.06.29.
# 리뷰코드 : GC000278, 가게코드 : STORE_GC0058, ID : 1cnsurq, 리뷰 : 11시20분쯤 들어가려했더니 11시30분에 다시 오라고 하는 황당한 상황을 맞았음. 손님모시고 갔다가 급 당황. 임시로 자리에 앉힌 다음에 기다리게 하는게 맞는게 아닌가요. 개념없이 장사하는 곳. 다시는 안갈것임. 옛날 불친절 기억을 잊고 다시 갔는데. 이젠 절대로 안감, 평점 : 1, 날짜 : 2021.04.15.
# 리뷰코드 : GC000279, 가게코드 : STORE_GC0058, ID : 1csn7vl, 리뷰 : 별점이 좋아서 고민하다가 갔어요.  커플스시 먹었고, 흰살생선 스시는 괜찮았으나 다른 스시 컨디션은 별로였어요.  무엇보다 급하게 찾아가서 들어갔는데 넓은 좌석을 두고 제일 구석에 안내한 것부터 멀리서 온 손님 대접하는 자리였는데 일하시는 분들 제외한 메린 셰프님의 행동에 제가 다 무안했습니다.   이런 평과 댓글 남기고 싶지 않았는데 이런 대우 받을꺼라면..., 평점 : 1, 날짜 : 2021.03.26.
# 가게코드 : STORE_GC0059, 가계명 : 총각네부추곱창 독산동본점, 주소 : 서울 금천구 독산로75길 40, 지역 : (지번) 독산4동 196-22, 종류 : 곱창,막창
# #### 총각네부추곱창 독산동본점
# 리뷰코드 : GC000280, 가게코드 : STORE_GC0059, ID : 8uhi6o, 리뷰 : 곱창질기길래 빠짝익혔는데도 불구하고 엄청질김 맛은있는데 곱창만 안질기면 방송보고 맛있어보여서 왔는데 그리고  구워서 안나오고 자리에서 구워주는데 기름튀고 난리임 화상입을뻔 ㅜㅜ 곱창 없어서 못먹는 엄청난 곱창매니아에요 걍 딴데가겠음 , 평점 : 1, 날짜 : 2020.06.12.
# 리뷰코드 : GC000281, 가게코드 : STORE_GC0059, ID : 14h83kq, 리뷰 : 곱창 매니아임. 질기고 곱이 없음. 젓가락으로 들고 구멍으로 상대편 보기 가능.. 손님 많길래 가던곳 안가고 와봤는데 실망.. 맛있는 곱창 썼으면 좋겠음.. , 평점 : 2, 날짜 : 2020.04.17.
# 리뷰코드 : GC000282, 가게코드 : STORE_GC0059, ID : frnii8, 리뷰 : 곱은 고소한편이나 곱창자체가 너무 질김. 일하시는 직원분 바쁘셔서 그런거도 있겠지만 불친절하심. 다시 갈 계획은 없음., 평점 : 1, 날짜 : 2019.04.29.
# 리뷰코드 : GC000283, 가게코드 : STORE_GC0059, ID : None, 리뷰 : 가성비갑, 평점 : 5, 날짜 : 2018.07.27.
# 리뷰코드 : GC000284, 가게코드 : STORE_GC0059, ID : None, 리뷰 : 이모들이 친절하셔서 좋음 , 평점 : 3, 날짜 : 2017.08.25.
# 가게코드 : STORE_GC0060, 가계명 : 스타벅스 금천시흥점, 주소 : 서울 금천구 시흥대로 164, 지역 : (지번) 시흥동 904-22, 종류 : 커피전문점
# #### 스타벅스 금천시흥점
# 리뷰코드 : GC000285, 가게코드 : STORE_GC0060, ID : 1isa98o, 리뷰 : 매장도 넓어서 쾌적하고 좋네요, 평점 : 5, 날짜 : 2021.04.25.
# 리뷰코드 : GC000286, 가게코드 : STORE_GC0060, ID : n1gc3v, 리뷰 : 스벅말모~, 평점 : 5, 날짜 : 2021.02.23.
# 리뷰코드 : GC000287, 가게코드 : STORE_GC0060, ID : a4baaf, 리뷰 : 매장도 넓고 친절하고, 맛있다. 다만 아주머님들이 애들 관리 안하면 피곤하다., 평점 : 5, 날짜 : 2020.04.30.
# 리뷰코드 : GC000288, 가게코드 : STORE_GC0060, ID : 95c12b, 리뷰 : 친절함과 분위기 자체는 기본적으로 좋은 지점이예요. 그런데 운이 나쁘면 애들 데리고 온 엄마들 모임과 마주칠 수 있습니다. 다른 테이블에 애들 앉혀두고, 그 애들이 소리 치면서 뛰어 다니고 킥 보드 타는데도 말로만 그러지 마~ 이러고 말고 자기들끼리만 얘기하느라 바쁘시더군요. 애들이 여럿이라 더더욱 말리는 말들은 귓등으로도 안 들었구요. 오래도 있었어요. , 평점 : 4, 날짜 : 2020.04.20.
# 리뷰코드 : GC000289, 가게코드 : STORE_GC0060, ID : qq0nt1, 리뷰 : 자주 가고 싶은 곳이네요. 편하고, 아늑한 분위기, 평점 : 5, 날짜 : 2019.11.19.
# 가게코드 : STORE_GC0061, 가계명 : 로운샤브샤브 롯데마트금천점, 주소 : 서울 금천구 시흥대로 291 지하1층, 지역 : (지번) 독산동 산 221-3, 종류 : 샤브샤브
# #### 로운샤브샤브 롯데마트금천점
# 리뷰코드 : GC000290, 가게코드 : STORE_GC0061, ID : 14ak6mr, 리뷰 : .., 평점 : 1, 날짜 : 2020.11.19.
# 리뷰코드 : GC000291, 가게코드 : STORE_GC0061, ID : qqber9, 리뷰 : 고기 퀄이 떨어진다. 그게 좀 아쉽다., 평점 : 3, 날짜 : 2020.11.08.
# 리뷰코드 : GC000292, 가게코드 : STORE_GC0061, ID : 14fv9dl, 리뷰 : 그냥저냥.. 마실게 좀 부족해요 종이컵이고, 평점 : 3, 날짜 : 2020.08.04.
# 리뷰코드 : GC000293, 가게코드 : STORE_GC0061, ID : 7kmo30, 리뷰 : 사람 많지 않아서 좋아요 고기를 리필 하는 게 아니라 직접 가져다 먹어서 더 좋아요, 평점 : 4, 날짜 : 2020.07.20.
# 리뷰코드 : GC000294, 가게코드 : STORE_GC0061, ID : 7uq1g6, 리뷰 : 솔직히 두번째 방문했을때 샤브고기 위주로 먹었는데 그날 배가 너무 아펐음 와이프도 그렇고 애들은 안먹어서 모르겠지만 암튼 자중해야하겠음, 평점 : 1, 날짜 : 2020.06.27.
# 가게코드 : STORE_GC0062, 가계명 : 본가집가마솥설렁탕 금천구청본점, 주소 : 서울 금천구 시흥대로 269 1층, 지역 : (지번) 시흥동 108-62, 종류 : 설렁탕
# #### 본가집가마솥설렁탕 금천구청본점
# 리뷰코드 : GC000295, 가게코드 : STORE_GC0062, ID : v7296s, 리뷰 : 12,000원짜리 특 설렁탕, 가격 대비 갸우뚱하게 됨  국물맛은 일반 시제품 마냥 깊은 줄 모르겠고 특이라서 들어가는 도가니, 머릿고기 등등은 양도 그렇게 많지 않아서 조금 의아했음  적당히 먹을만하지만 12,000원 주고 먹기에는 조금 아까움..., 평점 : 2, 날짜 : 2021.06.11.
# 리뷰코드 : GC000296, 가게코드 : STORE_GC0062, ID : 117fk9g, 리뷰 : 방문한지는 몇개월되었는데  이제서야 문득 생각나 후기남김.여긴 가장 큰문제가 음식의양임  뚝배기 크기도 작은거 사용하면서 절반가량 담긴듯 먹다 남은듯한 느낌을 주는 양이다  다른리뷰사진도 보시길 절반가량 담겨있음  실제체감은 더큼  그나마 맛은 으뜸 집에서 어머니가 해주신듯한 구수한 진짜 설렁탕맛이다  여러브랜드 가보면 느끼는 인위적인 우윳빛에 노린내나는 ..., 평점 : 3, 날짜 : 2021.04.16.
# 리뷰코드 : GC000297, 가게코드 : STORE_GC0062, ID : e6tu94, 리뷰 : 불친절의 대명소 주문한다니까 “물 가져다준다고 “ 라고 반말 작렬 주문한다는데 갑자기 물이야기는... 무슨 이야기인지, 평점 : 1, 날짜 : 2020.09.30.
# 리뷰코드 : GC000298, 가게코드 : STORE_GC0062, ID : mrv0o3, 리뷰 : 설렁탕 맛있어요. 특설렁탕이었는게 도가니, 고기도 넉넉히 들어 있었어요. 그런데 후기대로 김치가 진!짜! 맛 없어요. 무랑 배추 둘 다. 설렁탕은 김치 먹으러 가는 건데 많이 아쉬워요. 기본 반찬으로 양고기를 주는 게 특이해요. , 평점 : 3, 날짜 : 2020.09.20.
# 리뷰코드 : GC000299, 가게코드 : STORE_GC0062, ID : 1bfuail, 리뷰 : 지금 때가 어느때인데 주방에서 음식 조리하시는 분이 마스크도 착용 안 하고 일하시고, 직원들이 점심식사 끝난 후에 들어가서 주문했는데 식사가 끝난 뒤에도 손님이 들어왔는데 마스크도 안 쓰고 마스크 벗은 채로 서로 침튀기며 이야기 하면서 손도 안 씻고 식사 셋팅 하셨어요. 음식 준비하는데 왜 마스크 안 쓰냐고 물으니 “밥 먹었잖아요!” 이러고, 그럼 주방에서..., 평점 : 1, 날짜 : 2020.08.25.
# 가게코드 : STORE_GC0063, 가계명 : 우시장3호집, 주소 : 서울 금천구 시흥대로 364 1층, 지역 : (지번) 독산동 1031-5, 종류 : 육류,고기
# #### 우시장3호집
# 리뷰코드 : GC000300, 가게코드 : STORE_GC0063, ID : gbnv0j, 리뷰 : 이인분 먹고 일인분 추가해서 먹었어요 근데 직원분이 잘못 알아들으시고 추가로 이인분을 주셨나봐요 저희는 일인분 추가했는데 양 많이주셨네 하고 먹고 계산하는데 총 사인분를 계산하시길래 일인분 추가한거라고 말씀드렸더니 사장님이 계속 이인분 드린거라고 하시더라구요 저희가 일인분 추가한거라고 잘못들으신 것 같다고하니 기분 나빠하시면서 포장하려던 고기 확 뺏으시고 ..., 평점 : 1, 날짜 : 2019.12.31.
# 리뷰코드 : GC000301, 가게코드 : STORE_GC0063, ID : 10uurgv, 리뷰 : None, 평점 : 5, 날짜 : 2019.09.02.
# 리뷰코드 : GC000302, 가게코드 : STORE_GC0063, ID : beqb6k, 리뷰 : 모듬은 양이 살짝의심, 고기 맛은 있어요. 사장포함 전체직원 “불친절”, 평점 : 2, 날짜 : 2017.12.10.
# 가게코드 : STORE_GC0064, 가계명 : 스타벅스 독산사거리점, 주소 : 서울 금천구 시흥대로 426, 지역 : (지번) 독산동 159-23, 종류 : 커피전문점
# #### 스타벅스 독산사거리점
# 리뷰코드 : GC000303, 가게코드 : STORE_GC0064, ID : 8umbik, 리뷰 : 스텝들이 친절해요~♡♡♡, 평점 : 5, 날짜 : 2020.12.20.
# ...
# 리뷰코드 : DJ000777, 가게코드 : STORE_DJ0158, ID : 18q6miu, 리뷰 : 이렇게 좋은 식사 할 곳이 있었는 줄 몰랐네요. 메뉴들이 완전 다양해서 푸짐하게 먹을 수 있어요!, 평점 : 5, 날짜 : 2020.05.29.
# 가게코드 : STORE_DJ0159, 가계명 : 움프, 주소 : 서울 동작구 상도로 341-2 1층, 지역 : (지번) 상도동 477-13, 종류 : 와인바
# #### 움프
# 리뷰코드 : DJ000778, 가게코드 : STORE_DJ0159, ID : o54sac, 리뷰 : None, 평점 : 5, 날짜 : 2021.08.03.
# 리뷰코드 : DJ000779, 가게코드 : STORE_DJ0159, ID : 1fggedd, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.31.
# 리뷰코드 : DJ000780, 가게코드 : STORE_DJ0159, ID : mupb1l, 리뷰 : 분위기 좋고 가성비 좋아요, 평점 : 3, 날짜 : 2021.07.16.
# 리뷰코드 : DJ000781, 가게코드 : STORE_DJ0159, ID : srheu4, 리뷰 : 분위기 좋아요, 평점 : 5, 날짜 : 2021.07.04.
# 리뷰코드 : DJ000782, 가게코드 : STORE_DJ0159, ID : 11dfedl, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.23.
# 가게코드 : STORE_DJ0160, 가계명 : 갤러리카페오누이, 주소 : 서울 동작구 시흥대로 676, 지역 : (지번) 신대방동 586-2, 종류 : 카페
# #### 갤러리카페오누이
# 리뷰코드 : DJ000783, 가게코드 : STORE_DJ0160, ID : 15q7peq, 리뷰 : 고객 응대가 형편없어요, 평점 : 1, 날짜 : 2021.07.26.
# 리뷰코드 : DJ000784, 가게코드 : STORE_DJ0160, ID : 18pbq8q, 리뷰 : 여기는 그림 보고 책 보러 가는 곳.  음료는 장소값… 맛은 기대하지 마세요., 평점 : 4, 날짜 : 2021.07.25.
# 리뷰코드 : DJ000785, 가게코드 : STORE_DJ0160, ID : 1j69jru, 리뷰 : 여기 오픈때부터 자주 갔던 사람인데  초반엔 진짜 좋았는데 갈수록 읭 스러운부분있음 커피맛이 항상 다름 어떤날은 땟국물이고 어떤날은 괜찮고 그럼 그리고 와이파이 잘 안됨 분위기가 9할 차지, 평점 : 4, 날짜 : 2021.06.24.
# 리뷰코드 : DJ000786, 가게코드 : STORE_DJ0160, ID : e4ielt, 리뷰 : 공부하기조아용, 평점 : 5, 날짜 : 2021.06.12.
# 리뷰코드 : DJ000787, 가게코드 : STORE_DJ0160, ID : bfbkd8, 리뷰 : 넓고 조용, 평점 : 5, 날짜 : 2020.06.13.
# 가게코드 : STORE_DJ0161, 가계명 : 라무진 이수점, 주소 : 서울 동작구 동작대로27길 16-5, 지역 : (지번) 사당동 132-20, 종류 : 육류,고기
# #### 라무진 이수점
# 리뷰코드 : DJ000788, 가게코드 : STORE_DJ0161, ID : 7o8bp7, 리뷰 : 등급 낮은 수입 소고기 맛을 한우 가격 주고 먹는  기분, 평점 : 1, 날짜 : 2020.11.30.
# 리뷰코드 : DJ000789, 가게코드 : STORE_DJ0161, ID : mckef1, 리뷰 : None, 평점 : 3, 날짜 : 2020.10.25.
# 리뷰코드 : DJ000790, 가게코드 : STORE_DJ0161, ID : vr7871, 리뷰 : 평범 ! , 평점 : 3, 날짜 : 2020.10.20.
# 리뷰코드 : DJ000791, 가게코드 : STORE_DJ0161, ID : n0lrbp, 리뷰 : 별로에요.. 다른지점은 고기 굽기정도도 물어봐주고 자리를 비우지않고 세심하게 구워줬는데 여기는 올려놓고 계속 자리 비우고 분명 덜익혀달라고 말했는데 너무 많이 익혀줘서 질겨서 못먹었네요..  같은가격 너무 다른서비스 이수점 다신 안갈듯, 평점 : 1, 날짜 : 2020.09.18.
# 리뷰코드 : DJ000792, 가게코드 : STORE_DJ0161, ID : 8ohind, 리뷰 : 정말 맛있지만 가격의 압박 ㅠㅠㅠ , 평점 : 4, 날짜 : 2019.01.01.
# 가게코드 : STORE_DJ0162, 가계명 : 카페브르브르, 주소 : 서울 동작구 사당로29가길 6, 지역 : (지번) 사당동 141-48, 종류 : 카페
# #### 카페브르브르
# 리뷰코드 : DJ000793, 가게코드 : STORE_DJ0162, ID : ug05s7, 리뷰 : 인스타용 카페 그 이상도 이하도 아님. 막상 가 보니 까페도 좁고 자리도 작고 좀 실망., 평점 : 2, 날짜 : 2021.07.30.
# 리뷰코드 : DJ000794, 가게코드 : STORE_DJ0162, ID : vm2rid, 리뷰 : 아메리카노가 산미가 덜해서 완전 제스타일이었어요! 분위기도 좋아요 사장님도 친절하시구요;), 평점 : 5, 날짜 : 2021.05.18.
# 리뷰코드 : DJ000795, 가게코드 : STORE_DJ0162, ID : 1h9pakl, 리뷰 : 예쁘고 분위기있고 음료들 다 맛있어요!!, 평점 : 5, 날짜 : 2021.03.09.
# 리뷰코드 : DJ000796, 가게코드 : STORE_DJ0162, ID : n0l3ab, 리뷰 : 걍 무난무난. 근처여서 들어갔는데 찾아보니 유명한 곳이어서 놀랐음. 아메리카노는 개인적으로 별로였지만 원래 케이크가 유명하다고 하니 재방문의사는 있음!, 평점 : 4, 날짜 : 2020.08.25.
# 리뷰코드 : DJ000797, 가게코드 : STORE_DJ0162, ID : 14hf43o, 리뷰 : 여기진짜 너무예뻐요 나만의 예쁜카페를 발견한 느낌입니다  여기 쿠키 진짜맛있어용 자세한 후기는 아래 블로그 링크에 있어요!!   [진꾸마을 블로그]  https://blog.naver.com/PostView.nhn?blogId=kandagi932&logNo=222039443015&categoryNo=54&parentCategoryNo=&from=thumbn..., 평점 : 4, 날짜 : 2020.08.05.
# 가게코드 : STORE_DJ0163, 가계명 : 타요키즈카페 보라매점, 주소 : 서울 동작구 보라매로5가길 16 보라매아카데미타워 6층, 지역 : (지번) 신대방동 395-69, 종류 : 키즈카페
# #### 타요키즈카페 보라매점
# 리뷰코드 : DJ000798, 가게코드 : STORE_DJ0163, ID : l89om5, 리뷰 : 시설이 커서 좋긴한데 너무낡고 관리도 잘안되는거 같아요. 재방문의사 없습니다., 평점 : 2, 날짜 : 2019.10.03.
# 리뷰코드 : DJ000799, 가게코드 : STORE_DJ0163, ID : bqonnm, 리뷰 : 좀 어수선한 분위기에 먼지, 눅눅한 냄새, 화장실 청소 상태 등 좋지 않아보였음. 위아래 이층으로 분리된 곳이 너무 많아서 아기 옆에 있다보면 허리아픔. 건물이 90년대 지어진 거 같은데 주차장 많이 노후돼보이고 주차하러 들어갈 때 동선이 다른 차들과 접촉위험이 유달리 많은 구조. 옛날 건물이라고 다 이런 거 아닌데 여긴 왜 그렇게 돼있는지 몰겠음.   저..., 평점 : 2, 날짜 : 2019.08.04.
# 리뷰코드 : DJ000800, 가게코드 : STORE_DJ0163, ID : na45jj, 리뷰 : 어떤점 랜드마크네요 완전 퍼펙트  안전도 좋고 ㆍ근데 예약제 아니라 아쉽네요ㆍ대기 30 분인게 한시간 ㆍ 컥 포기 7순위에 더기달렸다간 두시간에 주차증 ㆍ시간오버 돈이 커지네요ㆍ주말은 예약제로 바꿔주세요, 평점 : 5, 날짜 : 2019.03.23.
# 리뷰코드 : DJ000801, 가게코드 : STORE_DJ0163, ID : kvkbr8, 리뷰 : 깨끗하고 좋아요., 평점 : 5, 날짜 : 2018.09.20.
# 리뷰코드 : DJ000802, 가게코드 : STORE_DJ0163, ID : c296hv, 리뷰 : 와우 여태 가본 곳 중 제일 좋음. 테이블 수도 다른데 두 배 정도 됨., 평점 : 4, 날짜 : 2017.10.22.
# 가게코드 : STORE_DJ0164, 가계명 : 마루스시, 주소 : 서울 동작구 상도로37길 79, 지역 : (지번) 상도동 485, 종류 : 초밥,롤
# #### 마루스시
# 리뷰코드 : DJ000803, 가게코드 : STORE_DJ0164, ID : 1me2ddf, 리뷰 : 가성비 초대박 !!! 완전 맛집입니다.. 사진 찍는 것도 까먹고 그냥 흡입 포장으로 먹었는데 코로나 풀리면 매장 가서 먹을거에요ㅠ  , 평점 : 5, 날짜 : 2021.07.29.
# 리뷰코드 : DJ000804, 가게코드 : STORE_DJ0164, ID : fmvmv2, 리뷰 : None, 평점 : 4, 날짜 : 2021.06.07.
# 리뷰코드 : DJ000805, 가게코드 : STORE_DJ0164, ID : tdbflg, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.29.
# 리뷰코드 : DJ000806, 가게코드 : STORE_DJ0164, ID : c3t06p, 리뷰 : A코스 먹으면 양도 질도 너무 아쉽고, B코스는 정말 만족스러운데 좀 비싸서 자주는 어려울 것 같은 느낌., 평점 : 3, 날짜 : 2021.04.29.
# 리뷰코드 : DJ000807, 가게코드 : STORE_DJ0164, ID : e5jv63, 리뷰 : 추억이 담긴 마루스시. 여기서 초밥을 좋아하게 됐다., 평점 : 5, 날짜 : 2021.03.14.
# 가게코드 : STORE_DJ0165, 가계명 : 이수곱창, 주소 : 서울 동작구 동작대로27가길 6-4, 지역 : (지번) 사당동 139-87, 종류 : 곱창,막창
# #### 이수곱창
# 리뷰코드 : DJ000808, 가게코드 : STORE_DJ0165, ID : sp47nq, 리뷰 : None, 평점 : 1, 날짜 : 2021.04.04.
# 리뷰코드 : DJ000809, 가게코드 : STORE_DJ0165, ID : f5iirj, 리뷰 : None, 평점 : 5, 날짜 : 2021.03.26.
# 리뷰코드 : DJ000810, 가게코드 : STORE_DJ0165, ID : 1d9r5ap, 리뷰 : 먹고 있는데 뒤에 와서 청소하는거는 아닌거 같고 서비스 정신도 부족합니다, 평점 : 1, 날짜 : 2020.11.02.
# 리뷰코드 : DJ000811, 가게코드 : STORE_DJ0165, ID : l714fj, 리뷰 : 가지마세요. 맛 없습니다.  그냥 맛이가 없 어 요 일하시는 아주머니들 불친절해요 볶음밥 주방에서 후라이팬에 조리되어 나오는데 그 뜨거운거 들고 손님한테 조심성없이 들고오는 바람에 얼굴에 닿을뻔했네요 닿았으면 진짜 소송걸었습니다.  다시한번 말하지만 맛 없어요. 가보고싶으면 가보세요 돈날리고싶으면 가세요 마지막으로 말하지만 맛 없 습 니 다.  네 집가서 ..., 평점 : 1, 날짜 : 2020.04.07.
# 리뷰코드 : DJ000812, 가게코드 : STORE_DJ0165, ID : 17jlcfs, 리뷰 : 제가 먹었던 소곱창 중에 최악입니다 여기 갈 바엔 좀만 걸어가서 사당에 하얀돌곱창 가세요 곱창이 질긴 느낌은 없는데 곱 특유의 고소함도 거의 없고 곱창 대창 막창 모두 다 그냥 밋.밋 그 자체입니다 어떻게 맛 없을 수가 없는 곱창이 이렇게 밋밋하죠? 볶음밥은 이상한 오래된 김가루 냄새 나고 돈 아까워서 억지로 먹습니다 차라리 옆집 공평동꼼장어 가세요, 평점 : 1, 날짜 : 2020.04.07.
# 가게코드 : STORE_DJ0166, 가계명 : 스시준 NPC노량진점, 주소 : 서울 동작구 만양로14길 20, 지역 : (지번) 노량진동 211-47, 종류 : 초밥,롤
# #### 스시준 NPC노량진점
# 리뷰코드 : DJ000813, 가게코드 : STORE_DJ0166, ID : 115h6bn, 리뷰 : 초밥이 정말 쫀득쫀득... 적당한 찰기와 큼직한 회.. 너무 맛있다 ㅠㅠㅠ 주변에와서 초밥먹고싶으면 여기로가면 될 듯 근데 먹는 내내 빨간맛 노래 돌림노래 나와서 체할뽄함 ㅋㅋㅋㅋ 이것도 하나의 마케팅인가요? 배우고 갑니다 ㅎㅎ, 평점 : 4, 날짜 : 2021.06.12.
# 리뷰코드 : DJ000814, 가게코드 : STORE_DJ0166, ID : bm5dr8, 리뷰 : 모듬 특선 연6광4 왕새우4P 맛보았습니다. 특선은 플레이팅이 예쁘게 나오구요 종류도 다양하고 맛도 좋았어요 추천!!! 새우튀김은 튀김옷 얇고 양파고구마도 곁들여 나와서 예상보다 괜찮았습니다. 딱 새우4마리만 나올줄;;;ㅎㅎ 둘이가서 6만원 나왔는데 초밥뷔페가느니 이렇게 먹는게 더 기분이 좋네요  , 평점 : 5, 날짜 : 2021.04.12.
# 리뷰코드 : DJ000815, 가게코드 : STORE_DJ0166, ID : 7k8c1k, 리뷰 : 노량진동네 수준을 떠나 최소한 이정도 퀄은 되야 초밥이라 할수 있지 않을까.  보통 점주가 융통성 없어뵈면 답답하지만 반면 뚝심과 믿음의 퀄을 보장받지않나, 평점 : 4, 날짜 : 2021.03.01.
# 리뷰코드 : DJ000816, 가게코드 : STORE_DJ0166, ID : 1gtsn5i, 리뷰 : 배달로 먹었는데 가격대가 좀 있지만 맛있어요! 동네에서 연어초밥 먹고 싶을땐 자주 갈 것 같아요!!, 평점 : 4, 날짜 : 2021.02.26.
# 리뷰코드 : DJ000817, 가게코드 : STORE_DJ0166, ID : fo7b7b, 리뷰 : 맨날 만석이어서 못갔는데 드디어감. 밥위에 회들 개큼. 재료 신선하고 맛있었음. 노량진 초밥 2탑(하나는 바다마트 초밥)  개취: 밥에 초식초 조금만 덜들어가고 서비스 우동면도 조금만 더익혀주셨으면~  여담: 남자 사장님 초밥 맛집의 특유의 말투가 있어서 신뢰감, 평점 : 5, 날짜 : 2021.02.21.
# 가게코드 : STORE_DJ0167, 가계명 : 삼삼가마솥돈까스앤 칡불냉면, 주소 : 서울 동작구 만양로 90-1 1층, 지역 : (지번) 노량진동 119-144, 종류 : 돈까스,우동
# #### 삼삼가마솥돈까스앤 칡불냉면
# 리뷰코드 : DJ000818, 가게코드 : STORE_DJ0167, ID : 1m850hl, 리뷰 : 양 완전 대박 혼자 다 못먹음, 평점 : 4, 날짜 : 2021.08.07.
# 리뷰코드 : DJ000819, 가게코드 : STORE_DJ0167, ID : 1fpcnfc, 리뷰 : 20번넘게 사먹었었던 오랜팬으로서 아쉽다. 초심 잘 지켜라 포장으로 사가면  소스절반 양 쪼금주고 소스원래 가득가득많이줫었는데    가계 대환장파티 손님이 스프쏟아엎지르고  사장이손님한테 대놓고 소리지르고 신경질내고 막말폭언 당했다.손님한테 괜히 짜증내네  소스 한번더추가 얼마냐고돈  더내겟다고 햇느데 짜증내고 소리지르네 사장 너무불쾌하고 기분나빳음   바..., 평점 : 1, 날짜 : 2021.08.06.
# 리뷰코드 : DJ000820, 가게코드 : STORE_DJ0167, ID : 1ht65oi, 리뷰 : 너무너무 맛있네요. 단체 포장주문 했는데 포장도 깔끔하고 냉면도 많고 돈가스도 바삭바삭해요. 가성비 갑!!! 잘먹었습니다~~ ☆☆여름에 강추!!☆☆, 평점 : 5, 날짜 : 2021.07.27.
# 리뷰코드 : DJ000821, 가게코드 : STORE_DJ0167, ID : e3tp8e, 리뷰 : 여기 진짜 맛있어요, 평점 : 5, 날짜 : 2021.07.01.
# 리뷰코드 : DJ000822, 가게코드 : STORE_DJ0167, ID : 14f7i1p, 리뷰 : 바삭하고, 양념도 맛있음. 콜라도 천원이면 얼음까지 넣어서 무한.. 어떤 여자분 실수로 2개 주문한것도 친절하게 물어봐서 다시 결제해줌. 왜 리뷰가 낮은지 모르겠음, 평점 : 5, 날짜 : 2021.06.30.
# 가게코드 : STORE_DJ0168, 가계명 : 김명자당진동태아구찜탕, 주소 : 서울 동작구 사당로 229-1, 지역 : (지번) 사당동 265-18, 종류 : 아구
# #### 김명자당진동태아구찜탕
# 리뷰코드 : DJ000823, 가게코드 : STORE_DJ0168, ID : 1b1kuqc, 리뷰 : 가성비 최고의 아구찜 가게 맛도 좋다, 평점 : 5, 날짜 : 2021.06.21.
# 리뷰코드 : DJ000824, 가게코드 : STORE_DJ0168, ID : 9j5djc, 리뷰 : None, 평점 : 4, 날짜 : 2020.12.22.
# 리뷰코드 : DJ000825, 가게코드 : STORE_DJ0168, ID : 1d311l3, 리뷰 : 24시간 먹을수 있어서 좋음. 친절하고 양도 많고 가격도 저렴함., 평점 : 4, 날짜 : 2020.10.25.
# 리뷰코드 : DJ000826, 가게코드 : STORE_DJ0168, ID : n0oqu8, 리뷰 : 맛있고 양많아요 기다릴때 적는거 보다 확인해서 그냥 들어가는게 더빠름, 평점 : 5, 날짜 : 2020.10.25.
# 리뷰코드 : DJ000827, 가게코드 : STORE_DJ0168, ID : fkqltu, 리뷰 : 밑반찬 퀄리티 좋고 전반적으로 깔끔하고 서비스 좋음, 평점 : 4, 날짜 : 2020.10.19.
# 가게코드 : STORE_DJ0169, 가계명 : 명륜진사갈비 서울상도점, 주소 : 서울 동작구 상도로 128, 지역 : (지번) 상도동 355-15, 종류 : 갈비
# #### 명륜진사갈비 서울상도점
# 리뷰코드 : DJ000828, 가게코드 : STORE_DJ0169, ID : 1i5eipf, 리뷰 : None, 평점 : 5, 날짜 : 2021.04.12.
# 리뷰코드 : DJ000829, 가게코드 : STORE_DJ0169, ID : cifbg7, 리뷰 : 배터져용 꿀맛 임, 평점 : 5, 날짜 : 2021.02.19.
# 리뷰코드 : DJ000830, 가게코드 : STORE_DJ0169, ID : 134jdnl, 리뷰 : 고기도 별로 냉면도 밍밍 별로 갈비달라해도 전지 가져다주는 불판 갈아주는 서비스도 별로  다 별로 다신 안감, 평점 : 1, 날짜 : 2020.10.18.
# 리뷰코드 : DJ000831, 가게코드 : STORE_DJ0169, ID : o6dglj, 리뷰 : 진짜별로, 평점 : 1, 날짜 : 2020.09.02.
# 리뷰코드 : DJ000832, 가게코드 : STORE_DJ0169, ID : n1ti9p, 리뷰 : 고기맛은 다른곳과 같아요..하지만 불이 약해졌을때  숯을더 주지않고 가스만 올렸다고 하더라구요. 한판 굽는데 시간이 굉장히 오래걸려요. 다른곳은 숯도 잘넣어주고 떡이나 밑반찬도 훨씬 좋은거 같아요. 여기는 다시는 안옵니다, 평점 : 1, 날짜 : 2020.08.15.
# 가게코드 : STORE_DJ0170, 가계명 : 허수아비돈까스 노량진점, 주소 : 서울 동작구 만양로14가길 4 1층, 지역 : (지번) 노량진동 124-10, 종류 : 돈까스,우동
# #### 허수아비돈까스 노량진점
# 리뷰코드 : DJ000833, 가게코드 : STORE_DJ0170, ID : r0ocg8, 리뷰 : 맛있는데,, 가게에서 하수구냄새같은게 남..    ㅠㅠ 가격은 천원씩 올랐어요., 평점 : 3, 날짜 : 2021.08.07.
# 리뷰코드 : DJ000834, 가게코드 : STORE_DJ0170, ID : rgrkcu, 리뷰 : 옛날부터 노량진서 먹었는데 점점 더 맛있어짐 사장님이 연돈이 되고 싶으신게 틀림없다, 평점 : 5, 날짜 : 2021.07.30.
# 리뷰코드 : DJ000835, 가게코드 : STORE_DJ0170, ID : ura8ci, 리뷰 : 돈가스 전문점이라며 15000원씩 받는 서울 도둑놈식당들에 비해 퀄리티는 더 뛰어남. 로스보단 치킨이 더 맛있음., 평점 : 5, 날짜 : 2021.04.14.
# 리뷰코드 : DJ000836, 가게코드 : STORE_DJ0170, ID : tu0dm0, 리뷰 : 로스+쌀국수 8천원. 로스는 존맛, 쌀국수는 보통. 겨자까지 넣어 먹을 수 있으니 더 맛있는 듯, 평점 : 4, 날짜 : 2021.01.10.
# 리뷰코드 : DJ000837, 가게코드 : STORE_DJ0170, ID : vjshpp, 리뷰 : None, 평점 : 5, 날짜 : 2020.11.23.
# 가게코드 : STORE_DJ0171, 가계명 : 은행골 중대점, 주소 : 서울 동작구 흑석로 107, 지역 : (지번) 흑석동 184-5, 종류 : 초밥,롤
# #### 은행골 중대점
# 리뷰코드 : DJ000838, 가게코드 : STORE_DJ0171, ID : 191p6oq, 리뷰 : 은행골 진짜 너무너무 맛있어요(●⌒∇⌒●) 흑석동 초밥집 중에서 최고입니댱ㅎ-ㅎ, 평점 : 5, 날짜 : 2021.06.24.
# 리뷰코드 : DJ000839, 가게코드 : STORE_DJ0171, ID : 194782u, 리뷰 : 오뎅국물에 벌레 나옴 다 먹고 봐서 먹은거 다 토하고 싶었음, 평점 : 1, 날짜 : 2021.06.09.
# 리뷰코드 : DJ000840, 가게코드 : STORE_DJ0171, ID : 1cek4a5, 리뷰 : None, 평점 : 1, 날짜 : 2021.05.26.
# 리뷰코드 : DJ000841, 가게코드 : STORE_DJ0171, ID : fsdabl, 리뷰 : 밥이 많이 많이 달고 잘 부서짐 나쁘진 않지만 비슷한 가격에 근처 다른 초밥집 가는 게 조을듯..., 평점 : 3, 날짜 : 2021.05.17.
# 리뷰코드 : DJ000842, 가게코드 : STORE_DJ0171, ID : 19hbs9o, 리뷰 : None, 평점 : 3, 날짜 : 2021.01.15.
# 가게코드 : STORE_DJ0172, 가계명 : 곱분이곱창 이수점, 주소 : 서울 동작구 동작대로25길 37, 지역 : (지번) 사당동 144-7, 종류 : 곱창,막창
# #### 곱분이곱창 이수점
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-2fdf3240fdde> in search(place, local)
#     141
# --> 142                 crawling(place, local, place_lists)
#     143
#
# <ipython-input-5-2fdf3240fdde> in crawling(place, local, place_lists)
#     199         # 첫 페이지
# --> 200         extract_review(place_name, place_code , local) # 리뷰 추출
#     201
#
# <ipython-input-5-2fdf3240fdde> in extract_review(place_name, place_code, local)
#     248
# --> 249     html = driver.page_source
#     250     soup = BeautifulSoup(html, 'html.parser')
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     762         """
# --> 763         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     764
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response['value'] = self._unwrap_value(
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     239             raise exception_class(message, screen, stacktrace, alert_text)
# --> 240         raise exception_class(message, screen, stacktrace)
#     241
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=92.0.4515.131)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00E63733+2504499]
# 	Ordinal0 [0x00DFC401+2081793]
# 	Ordinal0 [0x00D024F0+1058032]
# 	Ordinal0 [0x00CF7584+1013124]
# 	Ordinal0 [0x00CF7D76+1015158]
# 	Ordinal0 [0x00CF94D5+1021141]
# 	Ordinal0 [0x00CF35F6+996854]
# 	Ordinal0 [0x00D03830+1062960]
# 	Ordinal0 [0x00D543D2+1393618]
# 	Ordinal0 [0x00D45D4B+1334603]
# 	Ordinal0 [0x00D222B4+1188532]
# 	Ordinal0 [0x00D23149+1192265]
# 	GetHandleVerifier [0x00FDFB8C+1512252]
# 	GetHandleVerifier [0x0108B0DF+2214031]
# 	GetHandleVerifier [0x00EE4BC3+484211]
# 	GetHandleVerifier [0x00EE3E69+480793]
# 	Ordinal0 [0x00E0218D+2105741]
# 	Ordinal0 [0x00E066E8+2123496]
# 	Ordinal0 [0x00E06827+2123815]
# 	Ordinal0 [0x00E0FB73+2161523]
# 	BaseThreadInitThunk [0x7643FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C67A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C67A4E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-2fdf3240fdde> in <module>
#     363 #### 메인 ####
#     364 if __name__ == "__main__":
# --> 365     main()
#
# <ipython-input-5-2fdf3240fdde> in main()
#      92
#      93         local = read_local_code(place)
# ---> 94         search(place, local)
#      95         create_csv_file(place)
#      96
#
# <ipython-input-5-2fdf3240fdde> in search(place, local)
#     151
#     152         finally:
# --> 153             search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')
#     154             search_area.clear()
#     155
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     429         """
#     430         warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# --> 431         return self.find_element(by=By.XPATH, value=xpath)
#     432
#     433     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1092         return self.execute(Command.FIND_ELEMENT, {
#    1093             'using': by,
# -> 1094             'value': value})['value']
#    1095
#    1096     def find_elements(self, by=By.ID, value=None):
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response['value'] = self._unwrap_value(
#     349                 response.get('value', None))
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     238                 alert_text = value['alert'].get('text')
#     239             raise exception_class(message, screen, stacktrace, alert_text)
# --> 240         raise exception_class(message, screen, stacktrace)
#     241
#     242     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=92.0.4515.131)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00E63733+2504499]
# 	Ordinal0 [0x00DFC401+2081793]
# 	Ordinal0 [0x00D024F0+1058032]
# 	Ordinal0 [0x00CF7584+1013124]
# 	Ordinal0 [0x00CF7D76+1015158]
# 	Ordinal0 [0x00CF94D5+1021141]
# 	Ordinal0 [0x00CF35F6+996854]
# 	Ordinal0 [0x00D03830+1062960]
# 	Ordinal0 [0x00D543D2+1393618]
# 	Ordinal0 [0x00D45D4B+1334603]
# 	Ordinal0 [0x00D222B4+1188532]
# 	Ordinal0 [0x00D23149+1192265]
# 	GetHandleVerifier [0x00FDFB8C+1512252]
# 	GetHandleVerifier [0x0108B0DF+2214031]
# 	GetHandleVerifier [0x00EE4BC3+484211]
# 	GetHandleVerifier [0x00EE3E69+480793]
# 	Ordinal0 [0x00E0218D+2105741]
# 	Ordinal0 [0x00E066E8+2123496]
# 	Ordinal0 [0x00E06827+2123815]
# 	Ordinal0 [0x00E0FB73+2161523]
# 	BaseThreadInitThunk [0x7643FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C67A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C67A4E+238]

# %%
rating_df
# Out:
#      review_code     ItemID UserID review Rating    Timestamp
# 0       GC000001        호세가   None   None   None  2021.06.14.
# 1       GC000002        호세가   None   None   None  2021.06.04.
# 2       GC000003        호세가   None   None   None  2021.06.02.
# 3       GC000004        호세가   None   None   None  2021.05.18.
# 4       GC000005        호세가   None   None   None  2021.05.15.
# ...          ...        ...    ...    ...    ...          ...
# 3229    GC003230  용호동낙지 가산점   None   None   None  2021.01.08.
# 3230    GC003231  용호동낙지 가산점   None   None   None  2020.01.31.
# 3231    GC003232  용호동낙지 가산점   None   None   None  2018.12.16.
# 3232    GC003233  용호동낙지 가산점   None   None   None  2018.08.29.
# 3233    GC003234  용호동낙지 가산점   None   None   None  2016.12.27.
#
# [3234 rows x 6 columns]
