# %%
# kakaoMap_crawling_2.ipynb 수정버전

# %%
import os

from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup

import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')

##########################################################################
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')


driver = webdriver.Chrome('./webdriver/chromedriver')

rating_df = pd.DataFrame()
restaurant_df = pd.DataFrame()


##### 가게 정보를 담는 클레스
class STORE_Info:
    place_name = ''
    place_address = ''
    place_local  = ''
    place_category  = ''
    
    # 생성자
    def __init__(self,  place_name = None, place_address = None, place_local = None, place_category = None):
        self.place_name =  place_name
        self.place_address = place_address
        self.place_local  = place_local
        self.place_category  = place_category
        
    # 데이터 확인
    def data_check(self):
        print('가계명 : %s, 주소 : %s, 지역 : %s, 종류 : %s' %(self.place_name, self.place_address, self.place_local, self.place_category))
        
        
##### 리뷰 정보를 담는 클레스
class REVIEW_Info:
    review_code = ''
    commen = ''
    rating = ''
    user_id  = ''
    timestamp  = ''

    
    # 생성자
    def __init__(self, review_code=None, comment = None, rating = None, user_id = None, timestamp = None):
        self.review_code = review_code
        self.comment =  comment
        self.rating = rating
        self.user_id  = user_id
        self.timestamp  = timestamp 

    # 데이터 확인
    def data_check(self):
        print('리뷰코드 : %s, ID : %s, 리뷰 : %s, 평점 : %s, 날짜 : %s' %(self.review_code, self.user_id, self.comment, self.rating, self.timestamp))

        
##### 메인 코드 #####
def main():
    global driver, load_wb, review_num, local, number

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

     #### 검색할 목록
#     place_infos = ['종로구 맛집', '중구 맛집', ' 용산구 맛집', '성동구 맛집', '광진구 맛집', '동대문구 맛집', '중랑구 맛집', '성북구 맛집', '강북구 맛집']
#     place_infos = ['도봉구 맛집', '노원구 맛집', '은평구 맛집', '서대문구 맛집', '마포구 맛집', '양천구 맛집', '강서구 맛집','구로구 맛집']
    place_infos = ['금천구 맛집', '영등포구 맛집', '동작구 맛집', '관악구 맛집', '서초구 맛집', '강남구 맛집', '송파구 맛집','강동구 맛집']
    
    for i, place in enumerate(place_infos):
        print("##### {0} : {1}".format(i,place))
        number = 0 
        
        local = read_local_code(place)
        search(place, local)
        create_csv_file(place)

    driver.quit()
    print("finish")


#### 가게 정보 찾기
def search(place, local):
    """
    검색한 페이지 음식점 정보 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    """
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER) # 더보기
    
    xPath = '//*[@id="info.search.page.no1"]'
    driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER) # 첫번째 페이지로 이동
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem') # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, local, place_lists)

    # 전체 페이지
    while True:
        try:
#            2~ 5페이지 읽기
            for i in range(2, 6):
                # 페이지 넘기기
                xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
                driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
                sleep(1)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                place_lists = soup.select('.placelist > .PlaceItem') # 장소 목록 list
                
                crawling(place, local, place_lists)
                
                # 다음 페이지 넘기기
                if i==5:
                    driver.find_element_by_xpath('//*[@id="info.search.page.next"]').send_keys(Keys.ENTER)

        except ElementNotInteractableException:
            print('end page')
            break
            
        finally:
            search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')
            search_area.clear()


#### 가게 정보 크롤링 하기
def crawling(place, local, place_lists):
    """
    페이지 목록을 받아서 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    :param place_lists : 페이지 내에 있는 음식점 목록
    """
    
    global restaurant_df

    while_flag = False
    for i, place in enumerate(place_lists):
        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address
        place_local = place.select('.info_item > .addr > .lot_number')[0].text
        place_category = place.select('.head_item > .subcategory')[0].text
        place_detail = place.select('.info_item > .contact> .moreview')[0].get('href') # place detail
        
        store_Info = STORE_Info(place_name, place_address, place_local, place_category)
        store_Info.data_check()
        
        #### DataFrame 저장 ####
        row = {"ItemID":place_name, "address": place_address, "local" : place_local, "category": place_category}
        row = pd.DataFrame(row, index=[1])
        restaurant_df = restaurant_df.append(row, ignore_index=True)
        
        #### 데이터 베이스 저장 #####

        
        
        
        driver.execute_script('window.open("about:blank", "_blank");')
        driver.switch_to.window(driver.window_handles[-1])
        driver.get(place_detail) # 상세정보 탭으로 변환
        sleep(1)
        
        print('####', place_name)
        sleep(1)
        # 첫 페이지
        extract_review(place_name, local) # 리뷰 추출

        # 2-5 페이지
        idx = 3
        try:
            page_num = len(driver.find_elements_by_class_name('link_page')) # 페이지 수 찾기
            for i in range(page_num-1):
                # css selector를 이용해 페이지 버튼 누르기
                driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name, local)
                idx += 1
            driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 5페이지가 넘는 경우 다음 버튼 누르기
            
            sleep(1)
            extract_review(place_name, local) # 리뷰 추출
            
            # 그 이후 페이지
            while True:
                idx = 4
                page_num = len(driver.find_elements_by_class_name('link_page')) #페이지 수 찾기
                for i in range(page_num-1):
                    driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                    sleep(1)
                    extract_review(place_name, local)
                    idx += 1
                driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 10페이지 이상으로 넘어가기 위한 다음 버튼 클릭
                sleep(1)
                extract_review(place_name, local) # 리뷰 추출            
            
        except (NoSuchElementException, ElementNotInteractableException):
            print("no review in crawling")

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환


#### 리뷰 크롤링 하기
def extract_review(place_name, local):
    """
    리뷰 크롤링 하는 함수
    :param place_place: 리뷰 정보 찾을 장소이름
    :param local : 지역구 코드
    """
    
    global driver, rating_df, number

    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')

    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        for i, review in enumerate(review_lists):
            comment = review.select('.txt_comment > span') # 리뷰
            rating = review.select('.grade_star > em') # 별점
            user_id = review.select('.append_item > a[data-userid]') # user-id 정보 html 파싱
#             user_name = review.select('.append_item > a[data-username]') # user-name 정보 html 파싱
            timestamp = review.select(' div > span.time_write') #시간정보
            number += 1
            
#             val = ''
#             if len(comment) != 0:
#                 if len(rating) != 0:
#                     val = comment[0].text + '/' + rating[0].text.replace('점', '')
#                 else:
#                     val = comment[0].text + '/0'
#                 print(val)                      

            #### 클래스 ####
            review_info = REVIEW_Info()
            
            review_info.review_code = local + str(number).zfill(6) # 리뷰 코드 (ex. GC000001)
            
            #### 클래스에 정보 담기 ####
            if len(comment) != 0:
                if comment[0].text:
                    review_info.comment = comment[0].text 
                else:
                    review_info.comment = None
            else:
                review_info.comment = None
            
            if len(rating) != 0:
                review_info.rating = rating[0].text.replace('점', '')
            else:
                review_info.rating = None

            if(len(user_id) != 0):
                if(user_id[0].get('data-userid')):
                    review_info.user_id = user_id[0].get('data-userid')
                else:
                    review_info.user_id = None
            else:
                review_info.user_id = None
            
             ### 원래 user_id -> None 과 null 값이 동시에 들어감
#             if len(user_id) != 0:
#                 review_info.user_id = user_id[0].get('data-userid')
#             else:
#                 review_info.user_id = None

            ### user_id 대체제로 생각 했으나 익명 보호를 위해 제외
#             if len(user_name) != 0 :
#                 review_info.user_name = user_name[0].get('data-username')
#             else:
#                 review_info.user_name = None

            if len(timestamp) != 0:
                review_info.timestamp = timestamp[0].text
            else:
                review_info.timestamp = None
                
            review_info.data_check()
            
            review_info.user_id
            
            #### DataFrame 에 정보 담기 ####
            try:
                row = {"review_code" : review_info.review_code, "ItemID": place_name, "UserID":review_info.user_id, "review" : review_info.comment,
                       "Rating":review_info.rating, "Timestamp":review_info.timestamp}
                row = pd.DataFrame(row, index=[i])
                rating_df = rating_df.append(row, ignore_index=True)
            
            except:
                row = {"review_code" : review_info.review_code, "ItemID":place_name, "UserID": None, "review" : None,
                       "Rating":None, "Timestamp":review_info.timestamp}
                row = pd.DataFrame(row, index=[i])
                rating_df = rating_df.append(row, ignore_index=True)
                
    else:
        print('no review in extract')
        ret = False

    return ret



#### CSV 파일로 저장 ####
def create_csv_file(place):
    global rating_df, restaurant_df

    rating_df.to_csv('%s_rating_df.csv' %place)
    rating_df.to_csv('%s_rating_df_ko.csv' %place, sep=',', na_rep='NaN', encoding='utf-8-sig')
        
    restaurant_df.to_csv('%s_restaurant_df.csv'  %place)
    restaurant_df.to_csv('%s_restaurant_df_ko.csv'  %place, sep=',', na_rep='NaN', encoding='utf-8-sig')
    
    

#### 지역구 코드 뽑아오기 ####
def read_local_code(place):
    
    local_place = place.split(' ')[0]

    local_code = pd.read_csv('local_code.csv', encoding='utf-8', index_col = 'local')
    return local_code.at[local_place, 'local_code']

#### 메인 ####
if __name__ == "__main__":
    main()
# Out:
# ##### 0 : 금천구 맛집
# 가계명 : 광고만두라, 주소 : 서울 금천구 시흥대로 97 BB53호, 지역 : (지번) 시흥동 984, 종류 : 한식
# #### 광고만두라
# 리뷰코드 : GC000001, ID : tghmif, 리뷰 : 드뎌열은듯? 전화가네 , 평점 : 4, 날짜 : 2021.08.12.
# 리뷰코드 : GC000002, ID : 1m4d6dq, 리뷰 : ㅜㅜ 방문했는데 아직 안열었네요ㅠㅠ 맛보고싶었는데ㅜ, 평점 : 4, 날짜 : 2021.07.22.
# 리뷰코드 : GC000003, ID : ssnvg6, 리뷰 : 주변 상인들 말로는 6월달부터 영업하신다고 전달받았는데 아직까지도 영업하지 않으심.. 5월 중순부터 3번은 찾아가본 듯 한데 언제쯤 먹어볼 수 있을지…, 평점 : 3, 날짜 : 2021.06.16.
# 리뷰코드 : GC000004, ID : 8uv76b, 리뷰 : 못먹어봐서 ㅠ 6월10일 어제 갔는데 개인 사정으로 당분간 쉰다고 적혀 있었어요 ㅠ 언제까지 쉬는지는 잘 모름 안적혀 있었음., 평점 : 3, 날짜 : 2021.06.11.
# 리뷰코드 : GC000005, ID : n1gc3v, 리뷰 : 만두로는 최고, 평점 : 5, 날짜 : 2021.05.19.
# 가계명 : 가산물갈비&백년불고기, 주소 : 서울 금천구 가산디지털1로 128 STXV타워 1층 110호, 지역 : (지번) 가산동 371-37, 종류 : 불고기,두루치기
# #### 가산물갈비&백년불고기
# 리뷰코드 : GC000006, ID : 1kbkdss, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.15.
# 리뷰코드 : GC000007, ID : kl3tq0, 리뷰 : 회식 장소로는 갸우뚱. 하지만 동성 친구끼리 가성비 있게 먹을 장소로 제격입니다. 양 많고 맛 좋고 서비스 괜찮아요., 평점 : 5, 날짜 : 2021.05.23.
# 리뷰코드 : GC000008, ID : tl6oe5, 리뷰 : 여기가 맛있어요? 회식장소로 좋아요? 아 내돈 내산은 안좋다는거죠 갔을때 먹고, 아 여긴 두번다시 안올맛이다. 싶어요 한약재로 만들었다고 하는데,그게 진짜 사족의맛 이에요., 평점 : 1, 날짜 : 2021.05.13.
# 리뷰코드 : GC000009, ID : 9hhb1j, 리뷰 : 회식장소로 좋구요 오징어튀김이 별미예요 엄청 바삭해요 , 평점 : 5, 날짜 : 2021.04.23.
# 리뷰코드 : GC000010, ID : td5904, 리뷰 : 맛있음, 평점 : 5, 날짜 : 2021.03.27.
# 가계명 : 동흥관, 주소 : 서울 금천구 시흥대로63길 20, 지역 : (지번) 시흥동 115-10, 종류 : 중화요리
# #### 동흥관
# 리뷰코드 : GC000011, ID : mup5gm, 리뷰 :  , 평점 : 5, 날짜 : 2021.08.11.
# 리뷰코드 : GC000012, ID : n3320u, 리뷰 : 가격도 그렇게 비싼것도 아니고 맛도 괜찮았어요, 평점 : 3, 날짜 : 2021.07.07.
# 리뷰코드 : GC000013, ID : 1604arb, 리뷰 : 일부러 갈곳은 절대아님! 지나가다 배고파 갈곳없을때나 가볼까 하는집. 친절. 위생꽝이네요. 좀친절하고 위생과 맛에신경쓰면 괜찮은 기본은 있는 집인데!, 평점 : 1, 날짜 : 2021.07.06.
# 리뷰코드 : GC000014, ID : 16ghll5, 리뷰 : 고등학교때부터 쭉 다녀왔지만 옛날의 친절함이 다 사라졌다. 주문을 해도 들은둥 마는둥... 뭘 좀 더 갖다달라고 하면 3번을 말해야 갖다준다. 심지어 옆테이블에게 갖다준다 ㅋㅋㅋㅋ 직원들은 벽에 기대어 핸드폰이나 하고 이런게 중국인 종특인가싶다. 다시는 가지 않을것 같다., 평점 : 1, 날짜 : 2021.07.05.
# 리뷰코드 : GC000015, ID : lnn9im, 리뷰 : 개인적으로는 너무 맛잇고 프라이빗 하게 만나기 너무 좋은데 직원들분이 그렇게 친절 하진 않아서 5 점 만점을 못 드리겠는 …? , 평점 : 4, 날짜 : 2021.06.23.
# 가계명 : 강강술래 시흥점, 주소 : 서울 금천구 시흥대로 193 금천ICT타워 2층, 지역 : (지번) 시흥동 991, 종류 : 육류,고기
# #### 강강술래 시흥점
# 리뷰코드 : GC000016, ID : 109p7k6, 리뷰 : None, 평점 : 4, 날짜 : 2021.06.14.
# 리뷰코드 : GC000017, ID : 18t6cjp, 리뷰 : 이전 이후 더 깔끔해지고 맛도 더 신경쓰시는 것 같습니다., 평점 : 4, 날짜 : 2021.05.30.
# 리뷰코드 : GC000018, ID : 19h1cpf, 리뷰 : 별 1점도 아까움. 고기 최악. 직원은 더 최악. 한우 질기고 맛없음. 직원 주문 받던 분이 빤히 쳐다보더니 위아래 흘겨봄. 다 먹지도 않았는데 불판 치워버림. 마감시간인줄. 비싼 돈 주고 먹다 체할뻔. 2번 다시는 안 옴. 손절. 그냥 줘도 안 먹음. 1성급이 5성급인 척 하는 느낌. 간만에 밥 먹고 기분 더럽., 평점 : 1, 날짜 : 2021.03.31.
# 리뷰코드 : GC000019, ID : obt6ck, 리뷰 : 돈 많이나올거 각오하고 가는 패밀리 고기 레스토랑, 평점 : 5, 날짜 : 2021.02.16.
# 리뷰코드 : GC000020, ID : bfk42a, 리뷰 : None, 평점 : 4, 날짜 : 2020.12.20.
# 가계명 : 도원, 주소 : 서울 금천구 범안로 1130 디지털엠파이어빌딩 101호, 지역 : (지번) 가산동 685, 종류 : 뷔페
# #### 도원
# 리뷰코드 : GC000021, ID : benk3h, 리뷰 : 가격 대비 퀄리티 좋은 중식뷔페입니다., 평점 : 5, 날짜 : 2021.08.04.
# 리뷰코드 : GC000022, ID : 16jsnri, 리뷰 : 오늘갓다왓는데 둥네앵간한 곳보다 맛납니다 혼자 오신 분들이.많더라구요 배불러서 많이 못먹은게.아쉽 ㅜㅜ, 평점 : 5, 날짜 : 2021.06.01.
# 리뷰코드 : GC000023, ID : muldnn, 리뷰 : 맛은 있다 없다 얘기하는게 별 의미가 없는 것 같습니다. 여러가지 중식을 가성비있게 먹을 수 있어 좋긴 합니다.  하지만 플라스틱 칸막이도 없이 거리두기하지 않고 손님을 받고 있고 손님들이 마스크를 쓰지 않고 음식을 받으러 돌아다녀도 별 말이 없습니다.   저녁시간 바쁜 건 알지만 인간적으로 코로나 상황에 갈 식당은 못된다고 봅니다.  제발 제가 간 날 코..., 평점 : 1, 날짜 : 2021.04.25.
# 리뷰코드 : GC000024, ID : 1itm3vi, 리뷰 : None, 평점 : 2, 날짜 : 2021.04.24.
# 리뷰코드 : GC000025, ID : 12bdjlk, 리뷰 : 가보고싶으니 저장, 평점 : 5, 날짜 : 2021.04.22.
# 가계명 : 쌍교숯불갈비 서울금천점, 주소 : 서울 금천구 시흥대로 435 1층, 지역 : (지번) 독산동 152-3, 종류 : 한식
# #### 쌍교숯불갈비 서울금천점
# 리뷰코드 : GC000026, ID : 1j85cf4, 리뷰 : 아이와함께하기좋아요. 냉면은비추, 평점 : 5, 날짜 : 2021.07.20.
# 리뷰코드 : GC000027, ID : uqh3f1, 리뷰 : 정말 맛있고 떡갈비가 엄청 부드러워요, 평점 : 5, 날짜 : 2021.07.16.
# 리뷰코드 : GC000028, ID : f77kv6, 리뷰 : 맛있어요 반찬도 맛나고 떡갈비랑 돼지갈비 시켰는데 다 구워서 나오고 맛있어요 진짜, 평점 : 5, 날짜 : 2021.07.11.
# 리뷰코드 : GC000029, ID : 10ibn7p, 리뷰 : 지인짜 맛난집!, 평점 : 5, 날짜 : 2021.06.28.
# 리뷰코드 : GC000030, ID : 126l72h, 리뷰 : 갈비구이>>갈비찜, 평점 : 5, 날짜 : 2021.06.28.
# 가계명 : 농장사람들, 주소 : 서울 금천구 벚꽃로 316 C&S타워 1층, 지역 : (지번) 가산동 777, 종류 : 육류,고기
# #### 농장사람들
# 리뷰코드 : GC000031, ID : 14lp7vt, 리뷰 : 넓은 공간,  친절한  서비스,  무엇보다 맛있는  소고기가 특히  좋았어요..가족  모임이라  시끌시끌했었는데  한결같이  친절했어요... 안심은  너무  부드러워  맛있었구요  채끝등심또한  너무  맛있게  먹었네요  후식  비빔냉면은  역시  매콤하면서  감칠맛  더할것없이  맛있는  식사였어요..., 평점 : 5, 날짜 : 2020.09.20.
# 리뷰코드 : GC000032, ID : 14u8ikd, 리뷰 : 넘나 맛있고 퀄히티도좋고 가성비굳!!!! 한우가 이가격에?, 평점 : 5, 날짜 : 2019.12.19.
# 리뷰코드 : GC000033, ID : 132utf4, 리뷰 : 굳굳, 평점 : 5, 날짜 : 2019.12.15.
# 리뷰코드 : GC000034, ID : 10jq375, 리뷰 : 부모님모시는 자리라 깔끔하고 맛좋은집찾다가 우연히 방문했는데 고기가 너무 맛있고!! 알바분들도 친절하셔서 기분좋게 먹고왔네요~^^!! 자주갈거같아요 ㅎㅎ, 평점 : 5, 날짜 : 2019.12.14.
# 리뷰코드 : GC000035, ID : None, 리뷰 : None, 평점 : 4, 날짜 : 2018.08.08.
# 가계명 : 순댕이네얼큰수제비, 주소 : 서울 금천구 시흥대로136길 1, 지역 : (지번) 독산동 160-17, 종류 : 수제비
# #### 순댕이네얼큰수제비
# 리뷰코드 : GC000036, ID : 124tggd, 리뷰 : 2021년 8월5일 방문했는데 개인적인사정에 의하여 하루쉽니다 라고붙어있음... 그래서 8월6일 다시 가볼라고 전화햇더니 안받음... 다시 확인차 전화햇더니 수신거부걸어놈.. 직원두명이 다 수신거부걸려서 전화만 걸면 통화중으로 나옴...내가 확인차 전화햇더니 전화가 걸림... 맛을떠나서 이런 인성을 가진사람들이 만드는 음식은 먹으면안됨!!!   전화받아서 ..., 평점 : 1, 날짜 : 2021.08.06.
# 리뷰코드 : GC000037, ID : 1j85cf4, 리뷰 : 줄서서먹을정도아님, 평점 : 3, 날짜 : 2021.07.05.
# 리뷰코드 : GC000038, ID : uqts70, 리뷰 : 아줌마 병원입원 갔다가 헛탕, 평점 : 2, 날짜 : 2021.06.19.
# 리뷰코드 : GC000039, ID : 12k9u82, 리뷰 : 맛은..좋은데 위생이 최악이에요 바닥에 떨어진 면을..물에 씻어서 넣는걸 보았음.., 평점 : 2, 날짜 : 2021.05.19.
# 리뷰코드 : GC000040, ID : 12980mk, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.13.
# 가계명 : 김사부샤브샤브, 주소 : 서울 금천구 가산로 132, 지역 : (지번) 가산동 145-24, 종류 : 샤브샤브
# #### 김사부샤브샤브
# 리뷰코드 : GC000041, ID : nvn8qn, 리뷰 : 꿔바로우 JMT 볶음면도 맛있음, 기대 안 했는데 이국적으로 매콤함 코로나 위생도 잘 지키심, 평점 : 4, 날짜 : 2021.08.06.
# 리뷰코드 : GC000042, ID : 1682m90, 리뷰 : 오랫동안 방문하고 싶은데 그냥그랬어요. 제가 묻고 싶은 게 있었지만 직원이 한국어 못 알아들어서 상황이 안 좋았어요. 설명하지 못하고 제가 추가 인분을 주문하고 싶었지만 결국 나갔어요. , 평점 : 2, 날짜 : 2021.07.20.
# 리뷰코드 : GC000043, ID : kmqmrt, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.30.
# 리뷰코드 : GC000044, ID : f15gk7, 리뷰 : 다른건 그냥 평타정도 근데 꿔바로우 진짜 여태껏 먹은것 중에 제일 맛있어서 이마 빡빡침 , 평점 : 4, 날짜 : 2021.05.29.
# 리뷰코드 : GC000045, ID : 18bqja1, 리뷰 : 너무 맛있는 음식 종업원분들과 약간 소통이 안되는 것 말고는 좋았어요!, 평점 : 4, 날짜 : 2021.02.14.
# 가계명 : 왕게수산, 주소 : 서울 금천구 시흥대로 182, 지역 : (지번) 시흥동 903-5, 종류 : 게,대게
# #### 왕게수산
# 리뷰코드 : GC000046, ID : 7mviov, 리뷰 : 직원들은 완전 좋은데 카운터는 개싹아지 ♬♬♬♩♩임.. 두번다시 안갈거임.. 갈때마다 현찰주는데.. 돈아까움..다른곳 뚤어야지, 평점 : 1, 날짜 : 2021.03.28.
# 리뷰코드 : GC000047, ID : 131k246, 리뷰 : 그냥 저냥, 평점 : 3, 날짜 : 2021.02.11.
# 리뷰코드 : GC000048, ID : cdmj9q, 리뷰 : 서비스의 질 이라든지 맛 이라든지, 종업원 분들의 손님접대 태도라든지 보통 입니다. 사랑받는 식당 되길 바랍니다~^^, 평점 : 3, 날짜 : 2020.10.04.
# 리뷰코드 : GC000049, ID : 102qqnp, 리뷰 : 어머니 생신때 킹크랩 키로당 노량진보다 너무비싸게삼 동네라 급해샀지 시간만 있었음 그냥노량진 가는게 훨쌈.., 평점 : 1, 날짜 : 2020.10.03.
# 리뷰코드 : GC000050, ID : 10g4lqj, 리뷰 : 가격대비 아쉬움, 평점 : 2, 날짜 : 2020.08.20.
# 가계명 : 채영진의명품생고기무한리필 독산점, 주소 : 서울 금천구 독산로 176, 지역 : (지번) 독산동 378-436, 종류 : 고기뷔페
# #### 채영진의명품생고기무한리필 독산점
# 리뷰코드 : GC000051, ID : 13fc3je, 리뷰 : 사장님 유도리도 없고 말투도 싸가지 없으시네요 더러워서 안먹습니다^^, 평점 : 1, 날짜 : 2021.08.08.
# 리뷰코드 : GC000052, ID : 1aq8ku9, 리뷰 : None, 평점 : 5, 날짜 : 2021.06.08.
# 리뷰코드 : GC000053, ID : 1802ss4, 리뷰 : None, 평점 : 5, 날짜 : 2021.05.02.
# 리뷰코드 : GC000054, ID : 14v3g46, 리뷰 : 직원이 불친절해요, 평점 : 1, 날짜 : 2021.04.30.
# 리뷰코드 : GC000055, ID : 1clemtd, 리뷰 : 리뷰 보아하니 한동안 못 갔는데 많이 개차반 되었나보네요.. 예전엔 두꺼워서 좋았는데 마지막으로 갔을때 작고 얇아지고.. 처음 갔을때부터 직원 두세분 앉아서 노가리 털고 있고 불친절하던거 그냥 고기가 맛있어서 넘어갔는데 두 세번째 갔을때도 바뀐건지 여전히 노가리 털고 고기 달라하면 귀찮은 식으로 반응 하고 체인점이라 역시 글러쳐먹었네요. 지인보고 가라했다가..., 평점 : 1, 날짜 : 2021.04.25.
# 가계명 : 개성손만두요리전문점 가산디지털점, 주소 : 서울 금천구 가산로9길 22, 지역 : (지번) 가산동 143-18, 종류 : 한식
# #### 개성손만두요리전문점 가산디지털점
# 리뷰코드 : GC000056, ID : 17532nq, 리뷰 : 양도 많고 맛도 있는 집, 평점 : 5, 날짜 : 2021.07.26.
# 리뷰코드 : GC000057, ID : uqh3f1, 리뷰 : 맛있어요, 평점 : 5, 날짜 : 2021.07.16.
# 리뷰코드 : GC000058, ID : 1634v98, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.12.
# 리뷰코드 : GC000059, ID : 13dfchl, 리뷰 : 국물 깔끔하고 시원해서 좋음 사장님은 매우 불친절 내용물(채소)은 줄거면 주고 말거면 말지 매우 조금나옴, 평점 : 3, 날짜 : 2021.06.09.
# 리뷰코드 : GC000060, ID : e4gbh1, 리뷰 : 만두 좋아하는데 전골 1인분 주문할 수 있는 곳은 처음이네요. 만두가 네 알 들어가고 김치는 여기서 담그신답니다. 저녁에는 2천원에 볶음밥도 추가 가능한데 기본으로 나오는 칼국수까지 먹고 나니 배불러서 안 했어요. 가격은 매장에서 드시면 8천원, 포장하면 7천원. 매장 앞에 5대 가량 주차 가능합니다., 평점 : 5, 날짜 : 2021.05.27.
# 가계명 : 두껍삼 가산직영점, 주소 : 서울 금천구 벚꽃로38길 43, 지역 : (지번) 가산동 87-225, 종류 : 삼겹살
# #### 두껍삼 가산직영점
# 리뷰코드 : GC000061, ID : 1634v98, 리뷰 : None, 평점 : 3, 날짜 : 2021.07.12.
# 리뷰코드 : GC000062, ID : f5n90h, 리뷰 : 믿고 먹는 두껍삼 후식으로 온국수 필수 회식 장소 추천, 평점 : 5, 날짜 : 2021.05.09.
# 리뷰코드 : GC000063, ID : 13fgd4s, 리뷰 : 최고에여, 평점 : 5, 날짜 : 2021.03.04.
# 리뷰코드 : GC000064, ID : csgujd, 리뷰 : 다소 비싸긴해도 서비스와 맛은 괜찮은편임, 평점 : 3, 날짜 : 2020.07.28.
# 리뷰코드 : GC000065, ID : dfg4be, 리뷰 : 편하게 먹는 건 좋지만 고기질이 아쉽습니다., 평점 : 3, 날짜 : 2020.05.13.
# 가계명 : 문정곱창, 주소 : 서울 금천구 디지털로12길 37 1층, 지역 : (지번) 가산동 143-20, 종류 : 곱창,막창
# #### 문정곱창
# 리뷰코드 : GC000066, ID : rjmus4, 리뷰 : None, 평점 : 5, 날짜 : 2021.08.08.
# 리뷰코드 : GC000067, ID : 19ap743, 리뷰 : 볶음밥 맛이 신기하다.. 그래서 주는 소스 넣고 볶아서 먹을만 했다. 근데평점이 왜이렇게 높은지 모르겠다 , 평점 : 1, 날짜 : 2021.06.24.
# 리뷰코드 : GC000068, ID : uk1fm6, 리뷰 : 존맛탱입ㄴ다 곱창이 찐이에요, 평점 : 5, 날짜 : 2021.06.10.
# 리뷰코드 : GC000069, ID : r6q0o1, 리뷰 : None, 평점 : 4, 날짜 : 2021.05.21.
# 리뷰코드 : GC000070, ID : 126l72h, 리뷰 : 양념장이 맛있네요.. 멀리서 와서 갈 곳은 아니고 누가 사주면 갈 정도.., 평점 : 4, 날짜 : 2021.04.25.
# 가계명 : 춘천옥, 주소 : 서울 금천구 디지털로12길 19, 지역 : (지번) 가산동 140-38, 종류 : 족발,보쌈
# #### 춘천옥
# 리뷰코드 : GC000071, ID : ae72me, 리뷰 : 깔끔하고 맛있어요., 평점 : 5, 날짜 : 2021.08.12.
# 리뷰코드 : GC000072, ID : 1634v98, 리뷰 : None, 평점 : 3, 날짜 : 2021.07.12.
# 리뷰코드 : GC000073, ID : qs9i8p, 리뷰 : 이 코로나 시국에 주방안에 두사람 (남1, 여1) 계속 마스크도 안하고 조리 하시더라고요. 먹는내내 자꾸 눈앞에 보여서 먹다가 나왔습니다., 평점 : 1, 날짜 : 2021.07.06.
# 리뷰코드 : GC000074, ID : 17gmpu1, 리뷰 : 후회, 평점 : 1, 날짜 : 2021.01.15.
# 리뷰코드 : GC000075, ID : lneiso, 리뷰 : 와서 먹어보면 알수있지만...비추, 평점 : 1, 날짜 : 2021.01.15.
# 가계명 : 은행골 시흥분점, 주소 : 서울 금천구 시흥대로 198 지하1층, 지역 : (지번) 시흥동 890-10, 종류 : 초밥,롤
# #### 은행골 시흥분점
# 리뷰코드 : GC000076, ID : 14e5f0l, 리뷰 : 먹어본 초밥집 중에 가성비는 둘째치고 맛으로 손 꼽히는 초밥집입니다 매달 2-3번 정도 가는데 진짜 왠만하면 평타 이상 무조건 치고 가끔 특정 초밥이 비정상적으로 맛있는 경우가 있어요 뜬금없이 광어초밥?이 미친 맛을 낸다던가ㅋㅋ, 평점 : 5, 날짜 : 2021.08.02.
# 리뷰코드 : GC000077, ID : 16il1dq, 리뷰 : 핵존맛탱 회도 두툼하고 맛도 좋았어요 그리고 무지 친절하심, 평점 : 5, 날짜 : 2021.06.28.
# 리뷰코드 : GC000078, ID : 1je2d52, 리뷰 : 맛있고 친절했음. 서비스 초밥은 말씀안드려도 항상 주셨었음., 평점 : 5, 날짜 : 2021.05.13.
# 리뷰코드 : GC000079, ID : v3894s, 리뷰 : 맛있긴한데 서비스정신 개구림ㅋㅋㅋ, 평점 : 1, 날짜 : 2021.05.07.
# 리뷰코드 : GC000080, ID : jti6dn, 리뷰 : 서빙진짜 개열받음 서비스초밥 달라니까 던질듯툭놓고감  아진짜 오래갔었는데 진짜 실망이다 그간 손님뒷담 겁나까는것도 듣고 대수롭지 않게 생각했는데 그때부터 알아봤어야함., 평점 : 1, 날짜 : 2021.04.14.
# ##### 1 : 영등포구 맛집
# 가계명 : 정인면옥, 주소 : 서울 영등포구 국회대로76길 10 1층, 지역 : (지번) 여의도동 13-1, 종류 : 냉면
# #### 정인면옥
# 리뷰코드 : YDP000001, ID : cer18s, 리뷰 : 평냉 정석의 맛… 뭐 더할나위 없음. 일반 평냉보다 순면 육수가 더 간이 된 느낌이었는데 순면이 더 맛있었음(가격도 비쌈…) 만두도 무난하고 좋았음. 다만 주방이 너무 시끄럽고;; 직원들끼리 다투는(?)소리가 들리는 등 정신이 없음… 빨리 먹고 나오기엔 괜찮지만 어른들 모시고 갈 곳은 아니라고 봄, 평점 : 5, 날짜 : 2021.08.12.
# 리뷰코드 : YDP000002, ID : e4o04n, 리뷰 : 키 작은 여직원 정말 4가지가 없네요., 평점 : 1, 날짜 : 2021.07.21.
# 리뷰코드 : YDP000003, ID : e4hhh1, 리뷰 : 맛 좋은 편 줄이 너무 길어요 ㅠ, 평점 : 3, 날짜 : 2021.07.21.
# 리뷰코드 : YDP000004, ID : sim66r, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.19.
# 리뷰코드 : YDP000005, ID : v0e2u8, 리뷰 : 여의도 초기부터 단골집. 광명때 부터 못 간 거이 아숩~ 개인적 Top Level 평랭 집. 사장님 부천점 지도 좀 해주세요 본점하고 너무 차이가 나요~ , 평점 : 5, 날짜 : 2021.07.09.
# 가계명 : 진주집, 주소 : 서울 영등포구 국제금융로6길 33 여의도백화점 지하1층, 지역 : (지번) 여의도동 36-2, 종류 : 국수
# #### 진주집
# 리뷰코드 : YDP000006, ID : rk45hg, 리뷰 : 콩국수 맛집으로 유명한 이유는 알겠음. 진주회관이랑 비교하면 진주회관이 더 입맛에 맞음. 콩물은 진하고 비교적 심심한데 강한 김치맛으로 균형조절해서 먹다보면 질림. 음식은 4점 근데 주차권 현금으로 받는거랑 응대에서 1점 빼고 3점드림., 평점 : 3, 날짜 : 2021.08.07.
# 리뷰코드 : YDP000007, ID : vvgcf3, 리뷰 : 얘들아 7월27일까지 휴무다, 평점 : 4, 날짜 : 2021.07.23.
# 리뷰코드 : YDP000008, ID : 13ac0m4, 리뷰 : 방금갔는데 27일까지 휴무라고 적혀있네요..., 평점 : 4, 날짜 : 2021.07.22.
# 리뷰코드 : YDP000009, ID : beqece, 리뷰 : 21년 7월 21일까지 휴무래요. 가격만 괜찮으면 5점일텐데ㅜ, 평점 : 4, 날짜 : 2021.07.17.
# 리뷰코드 : YDP000010, ID : 10e79ea, 리뷰 : 그냥 그랬다 만두는 안먹을듯, 평점 : 3, 날짜 : 2021.07.17.
# 가계명 : 또순이네, 주소 : 서울 영등포구 선유로47길 16, 지역 : (지번) 양평동4가 81, 종류 : 육류,고기
# #### 또순이네
# 리뷰코드 : YDP000011, ID : 1f484fn, 리뷰 : 가슴이 웅장해지는맛! 마음까지 두둑해짐 ㅎㅎ, 평점 : 5, 날짜 : 2021.08.09.
# 리뷰코드 : YDP000012, ID : 1m39v20, 리뷰 : 괜찮았습니다~, 평점 : 4, 날짜 : 2021.07.21.
# 리뷰코드 : YDP000013, ID : f80ms4, 리뷰 : None, 평점 : 4, 날짜 : 2021.07.20.
# 리뷰코드 : YDP000014, ID : 1c13aci, 리뷰 : 직원들이 넘 불친절 너무 덥고.맛은 그냥.... 특이 함은 있음, 평점 : 1, 날짜 : 2021.07.19.
# 리뷰코드 : YDP000015, ID : 1ejk3ph, 리뷰 : 개불친절함, 주차요원쓰레기, 평점 : 1, 날짜 : 2021.07.18.
# 가계명 : 대한옥, 주소 : 서울 영등포구 영등포로51길 6, 지역 : (지번) 영등포동2가 221-1, 종류 : 설렁탕
# #### 대한옥
# 리뷰코드 : YDP000016, ID : vhkipb, 리뷰 : 참 어이없어 후기 남깁니다. 부모님과 같이 식사하기 위해 꼬리찜 대자 2개,꼬리곰탕 1개 133,000원어치 포장해서 집까지 30분정도 가서 식사하려는데 포장해준 부추에서 비닐을 풀자마자 상한 악취가 나서 먹지도 못하고 버렸습니다.그래도 포장해간 고기로 그냥그냥 식사를 마치고 다른 손님들에게는 상한 야채 드리지 말라고 전화하니 전화받은 사장딸이라는 분이 상..., 평점 : 1, 날짜 : 2021.08.06.
# 리뷰코드 : YDP000017, ID : gbftl3, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.27.
# 리뷰코드 : YDP000018, ID : lujqts, 리뷰 : 너무 기대를 해서일까 실망이 컸던 곳... 기다렸던 게 아까울 정도로 맛없었다, 평점 : 1, 날짜 : 2021.07.23.
# 리뷰코드 : YDP000019, ID : vrd9so, 리뷰 : 말이 필요 없는 곳. 흐릿한 날 낮술하기에 이곳만한 곳이 없다. (면 사리는 무조건 맛봐야 함), 평점 : 5, 날짜 : 2021.07.20.
# 리뷰코드 : YDP000020, ID : 11hvam8, 리뷰 : 가격이 너무 올랐다...ㅠ 그리고 미리 만들어 놓는지 시키자마자 나오는데 문제는 고기가 좀 말랐다 그리고 생각보다 간이 약하고 국수사리 양도 적음 ㅠㅠ 위생도 별로 에어컨도 없고 양도 적도 비싸고 맛도 기대이하라 재방문의사는 거의 없다.. 내돈주고 사먹을 거 같진 않고 누가 사준다면 다시 갈 거 같음,,, , 평점 : 2, 날짜 : 2021.07.18.
# 가계명 : 세상의모든아침 여의도점, 주소 : 서울 영등포구 여의대로 24 전경련회관 50, 51층, 지역 : (지번) 여의도동 28-1, 종류 : 양식
# #### 세상의모든아침 여의도점
# 리뷰코드 : YDP000021, ID : ega249, 리뷰 : 특별한 곳 같지만, 특별한 것이 없는 곳., 평점 : 3, 날짜 : 2021.07.25.
# 리뷰코드 : YDP000022, ID : 1m39ttn, 리뷰 : 특별한날 가면 뷰도 좋고 음식맛도 좋아서 기분 좋을 것 같아요, 평점 : 5, 날짜 : 2021.07.21.
# 리뷰코드 : YDP000023, ID : 1bvgprn, 리뷰 : None, 평점 : 4, 날짜 : 2021.07.09.
# 리뷰코드 : YDP000024, ID : 103ki0t, 리뷰 : 뷰 미쳣, 평점 : 5, 날짜 : 2021.07.09.
# 리뷰코드 : YDP000025, ID : 1gl2cqi, 리뷰 : 이렇게 맛없는 크림 페투치니 처음 먹어요 ㅠㅠ 뷰가 제일 맛있네요, 평점 : 1, 날짜 : 2021.07.06.
# 가계명 : 코끼리베이글, 주소 : 서울 영등포구 선유로 176 수화공단 1층 60호, 지역 : (지번) 양평동3가 69, 종류 : 제과,베이커리
# #### 코끼리베이글
# 리뷰코드 : YDP000026, ID : flue3f, 리뷰 : 유명세에 비해 빵 자체는 그닥 매력있지 않았어요. 왜이렇게 인기가 많은지 의아한 가게. 빵 맛은 나쁘진 않지만 그렇다고 엄청 맛있지도 않고, 모양만 그렇지 일반적인 베이글과는 거리가 좀 멀다고 느껴쟜어요., 평점 : 2, 날짜 : 2021.08.05.
# 리뷰코드 : YDP000027, ID : 15j1vjg, 리뷰 : 쫀득쫀득 쫀맛.., 평점 : 5, 날짜 : 2021.07.28.
# 리뷰코드 : YDP000028, ID : uk5q64, 리뷰 : 제가 베이글을 안좋아해서 베이글은 잘 안먹어봤는데 여기 갓직히 라떼존맛집임, 평점 : 5, 날짜 : 2021.07.19.
# 리뷰코드 : YDP000029, ID : d667lc, 리뷰 : 알바생 싸가지 환장함ㅋㅋㅋ 줄선건지 주문 기다리는건지 모를 손님들이 많길래 주문 기다려야되냐 물어봤는데 소리지름. 사장은 그 광경을 보고도 별 생각 없는걸 보니 배짱장사 하는 듯. 성격대로 개지X을 하려다가 날도 덥고 사람도 많고 여자친구도 같이 있어서 꾹 참고 나왔다. 맛은 좋은데 혼나는 취미 있는 사람이 가면 잘 맞음, 평점 : 1, 날짜 : 2021.07.11.
# 리뷰코드 : YDP000030, ID : u54ttj, 리뷰 : 주말이라 배달도 안되서  일인당 8개 제한 있다는거는 알고갔지만 참 배짱장사하네요  칼로리 제한때문에 토핑있는거2개 플레인6개 사려했는데 플레인베이글은 2개밖에 안판답니다 왜 안되냐니 그냥 안된대요 점점 서비스마인드가 나빠지는데  재방문은 글쎄요, 평점 : 1, 날짜 : 2021.07.03.
# 가계명 : 원조호수삼계탕 본점, 주소 : 서울 영등포구 도림로 274-1, 지역 : (지번) 신길동 342-325, 종류 : 삼계탕
# #### 원조호수삼계탕 본점
# 리뷰코드 : YDP000031, ID : 19tofkm, 리뷰 : 닭들이 살아생전에 못먹고 자랐네 유난히 갔었던 날은 다른 날보다 더 작었네요, 평점 : 1, 날짜 : 2021.08.10.
# 리뷰코드 : YDP000032, ID : mj5kha, 리뷰 : 뭐 맛은 그럭저럭인데 가격은 15000 임 게다가 주차비 현금으로 따로 받음, 평점 : 3, 날짜 : 2021.08.04.
# 리뷰코드 : YDP000033, ID : m8pu3a, 리뷰 : 들깨 삼계탕이란 점이 특이함  원래 삼계탕이 더 맛있긴한데 가까우면 자주 갈듯, 평점 : 3, 날짜 : 2021.08.03.
# 리뷰코드 : YDP000034, ID : 149lnhd, 리뷰 : 비싸다, 평점 : 1, 날짜 : 2021.07.28.
# 리뷰코드 : YDP000035, ID : None, 리뷰 : 호구들만 가는 집이지., 평점 : 1, 날짜 : 2021.07.25.
# 가계명 : 영일분식, 주소 : 서울 영등포구 도림로141가길 34-1, 지역 : (지번) 문래동4가 8-26, 종류 : 국수
# #### 영일분식
# 리뷰코드 : YDP000036, ID : 13fb5q4, 리뷰 : 칼국수는 솔직히 별로. 여긴 칼비빔이 짱이에요. 처음부터 와 존맛! 이런 맛은 아니었지만 어느날 생각나는 맛임..... 근데 예전엔 가격도 저렴하고 한번씩 리필도 돼서 가성비까지 짱이었는데  어느순간 가격이 올라가서 그닥 저렴하진 않아졌고 리필된다는 안내문이 사라졌더라구요. 해달라면 해주는진 모르겠지만. 가성비는 사라진 느낌. 그치만 맛있어서 종종 가요., 평점 : 4, 날짜 : 2021.07.27.
# 리뷰코드 : YDP000037, ID : 16h5lqb, 리뷰 : 문래의 자존심… 비빔 하나 물 하나 만두 하나. 극락좌표, 평점 : 5, 날짜 : 2021.07.08.
# 리뷰코드 : YDP000038, ID : bnf6ev, 리뷰 : None, 평점 : 5, 날짜 : 2021.06.26.
# 리뷰코드 : YDP000039, ID : muubjk, 리뷰 : 맛있게 잘 먹었습니다. 소주가 어울리는 칼국수. , 평점 : 5, 날짜 : 2021.06.25.
# 리뷰코드 : YDP000040, ID : 13mhqte, 리뷰 : 칼국수비빔 맛이 좋아요. 다만 방송 탄 집이라 사람이 많아서 좀 정신없음., 평점 : 4, 날짜 : 2021.06.17.
# 가계명 : 카페1953위드오드리, 주소 : 서울 영등포구 경인로77가길 12, 지역 : (지번) 문래동2가 34-10, 종류 : 카페
# #### 카페1953위드오드리
# 리뷰코드 : YDP000041, ID : bk075l, 리뷰 : 싸지 않은데 커피도 별로고 그냥 시판빵에 조리되는것조차 맛없네요 ㅠ, 평점 : 1, 날짜 : 2021.07.30.
# 리뷰코드 : YDP000042, ID : 92mv8j, 리뷰 : 좋아요, 평점 : 5, 날짜 : 2021.07.23.
# 리뷰코드 : YDP000043, ID : 1m39ttn, 리뷰 : 애정하는 카페, 평점 : 5, 날짜 : 2021.07.21.
# 리뷰코드 : YDP000044, ID : bfpnu9, 리뷰 : None, 평점 : 5, 날짜 : 2021.06.11.
# 리뷰코드 : YDP000045, ID : 1avp723, 리뷰 : 조용하고 예쁩니다, 평점 : 4, 날짜 : 2021.06.03.
# 가계명 : 양키통닭, 주소 : 서울 영등포구 도림로139길 13 1층, 지역 : (지번) 문래동2가 49-1, 종류 : 치킨
# #### 양키통닭
# 리뷰코드 : YDP000046, ID : 1jgqldo, 리뷰 : 여기 맛있고 건강한 맛!!!, 평점 : 5, 날짜 : 2021.08.11.
# 리뷰코드 : YDP000047, ID : rtoejh, 리뷰 : 너무 맛있어요.... 분위기 좋고 재방문의사 있습니당, 평점 : 5, 날짜 : 2021.08.09.
# 리뷰코드 : YDP000048, ID : mgg971, 리뷰 : 1호점 남직원들 싸가지없는편, 평점 : 2, 날짜 : 2021.08.05.
# 리뷰코드 : YDP000049, ID : 15c5v1c, 리뷰 : 맛은 평범한 누룽지통닭 전기통닭 류 맛인데 분위기가 좋아서 인기가 많나봐요 ㅎㅎ, 평점 : 3, 날짜 : 2021.07.29.
# 리뷰코드 : YDP000050, ID : 10ldv7r, 리뷰 : 매콤이더맛잇다, 평점 : 5, 날짜 : 2021.07.25.
# 가계명 : 이한스시, 주소 : 서울 영등포구 선유로22길 3 유선빌딩 2층, 지역 : (지번) 양평동1가 9-37, 종류 : 초밥,롤
# #### 이한스시
# 리뷰코드 : YDP000051, ID : 14dtlsh, 리뷰 : 맛과 별개로 직원들의 태도나 말투가 매우 불친절하여 기분이 상했다., 평점 : 1, 날짜 : 2021.07.30.
# 리뷰코드 : YDP000052, ID : ubv9tt, 리뷰 : 영등포의 자랑 가성비+맛 최고, 평점 : 5, 날짜 : 2021.07.18.
# 리뷰코드 : YDP000053, ID : uhu1od, 리뷰 : 불친절하다는 평이 많은데 홀 계신 분 중에 그냥 좀 무뚝뚝하신 분이 있으신 정도? 개인적으로 불평할만큼의 불친절은 겪어보지 못함. 위생문제가 있거나 종업원이 손님 욕을 한다던가 하는 정도가 아니면 이 음식에 이 가격이면 별 5개 안주기는 좀 어렵다고 봄., 평점 : 5, 날짜 : 2021.07.15.
# 리뷰코드 : YDP000054, ID : 1lbpkmf, 리뷰 : 가성비 좋고 맛있음. 다만 불친절함.  불친절해도 싸게 많이 먹는거 좋아하시는 분이면 방문 추천. 차라리 기존 사장님이셨을 때가 편하고 맛났음. 장사를 위한 회전율은 이해하지만 좀 심함. 또 가고 싶지는 않음., 평점 : 2, 날짜 : 2021.07.02.
# 리뷰코드 : YDP000055, ID : 126kre5, 리뷰 : None, 평점 : 3, 날짜 : 2021.06.30.
# 가계명 : 그믐족발 본점, 주소 : 서울 영등포구 경인로79길 21 1층, 지역 : (지번) 문래동2가 48-6, 종류 : 족발,보쌈
# #### 그믐족발 본점
# 리뷰코드 : YDP000056, ID : v0e2u8, 리뷰 : 괜춘~, 평점 : 3, 날짜 : 2021.06.30.
# 리뷰코드 : YDP000057, ID : 1dao14d, 리뷰 : 괜찮더라구요, 평점 : 2, 날짜 : 2021.06.16.
# 리뷰코드 : YDP000058, ID : spm4kb, 리뷰 : 그르지마요.. , 평점 : 1, 날짜 : 2021.05.26.
# 리뷰코드 : YDP000059, ID : 10375st, 리뷰 : 오픈시간 맞춰 가서 웨이팅도 없었구 맛있었어요!  꽈리고추 덕에 생각보다 느끼하지 않아서 좋았어요 웨이팅을 하면서까지 먹을 정도인지는 모르겠으나 오픈시간 맞춰서 또 가 볼 의향은 있는 곳 :), 평점 : 5, 날짜 : 2021.05.26.
# 리뷰코드 : YDP000060, ID : 90gb4i, 리뷰 : 포장해서 기대보다는 별로였어요 식으면 너무 느끼합니다, 평점 : 2, 날짜 : 2021.05.23.
# 가계명 : 송죽장, 주소 : 서울 영등포구 문래로 203, 지역 : (지번) 영등포동4가 98-12, 종류 : 중화요리
# #### 송죽장
# 리뷰코드 : YDP000061, ID : m71q2a, 리뷰 : 소문만큼 맛있지도않고 2층에 계셨던 종업원 아주머니가 불친절함. 딱 옛날 탕수육맛과 그냥 고추들어간 쟁반짜장맛! 식탁 닦던 행주로 물병 감싸쥐고 서빙하는거보구 밥맛 뚝떨어짐.., 평점 : 3, 날짜 : 2021.08.03.
# 리뷰코드 : YDP000062, ID : 143lvh2, 리뷰 : 이전 후 쟁반짜장 짬뽕 맛이 상당히 변함..안녕 송죽장, 평점 : 1, 날짜 : 2021.07.30.
# 리뷰코드 : YDP000063, ID : 1537jk3, 리뷰 : 차라리 타임스퀘어 안에 있는 신차이가 맛있습니다, 평점 : 1, 날짜 : 2021.07.05.
# 리뷰코드 : YDP000064, ID : va87in, 리뷰 : 초심을  잃고 손님을 그저 돈으루 보는가게 먹으러와서 줄서 있는 사람들을 마치 짐짝취급하며   중국인 직원들이 인상쓰는 얼굴보면  음식맛 떨어짐..., 평점 : 1, 날짜 : 2021.06.30.
# 리뷰코드 : YDP000065, ID : t3b6ji, 리뷰 : 불친절은 기본이고, 맛?? 솔직히 맛없음 볶음밥 재료에 아주 저렴한 햄조각이 몇개 들어가있고, 탕수육은 미리 튀겨진 상태에서 소스만 부어서 나오는데 바삭함도 없고 그렇다고 쫄깃함도 없다. 퍽퍽한 탕수육 맥주잔도 좀 깨끗이 씻어서 나오면 좋을텐데 대충 물로 행궈서 나오는지 새컵에서 꼬릿한 냄새가난다. 여기 도대체 누가 맛집이라 칭하는가?? 차라리 백화점 안에..., 평점 : 1, 날짜 : 2021.06.28.
# 가계명 : 삼거리먼지막순대국, 주소 : 서울 영등포구 시흥대로185길 11, 지역 : (지번) 대림동 963-9, 종류 : 순대
# #### 삼거리먼지막순대국
# 리뷰코드 : YDP000066, ID : n3kss2, 리뷰 : 미친 정도는 아니에요... 순대2개 들어있고 내장 짱 많아요. 근데 냄새나고 질기고 오돌뼈 많아요. 맛집이라서 많이 가는거는 아니구 5천원가성비 때문인듯, 평점 : 3, 날짜 : 2021.08.05.
# 리뷰코드 : YDP000067, ID : 10ldv7r, 리뷰 : 미쳤다, 평점 : 5, 날짜 : 2021.07.25.
# 리뷰코드 : YDP000068, ID : d667lc, 리뷰 : 가격, 맛, 푸짐함 등 뭐하나 빠지는게 없다. 국밥 온도도 너무 펄펄 끓지 않고, 꼭 토렴한 듯 한 온도라 더욱 맛있었음. 머릿고기는 꼭 시키셈, 평점 : 5, 날짜 : 2021.07.11.
# 리뷰코드 : YDP000069, ID : t4pddb, 리뷰 : 이가격에 이퀄리티 최고네요  가격생각하면 진짜 별 다섯개가 맞아요 , 평점 : 5, 날짜 : 2021.07.01.
# 리뷰코드 : YDP000070, ID : 1gupla7, 리뷰 : 깔끔하게 맛있어요, 평점 : 5, 날짜 : 2021.06.26.
# 가계명 : 올드문래, 주소 : 서울 영등포구 도림로 433-6 1층, 지역 : (지번) 문래동2가 14-28, 종류 : 호프,요리주점
# #### 올드문래
# 리뷰코드 : YDP000071, ID : rtoejh, 리뷰 : 음악소리때문에 대화가 안돼요 직원들도 불친절, 평점 : 3, 날짜 : 2021.08.09.
# 리뷰코드 : YDP000072, ID : 7kd4hn, 리뷰 : 음악소리 좀만 줄여주면 정말 좋을듯! 맥주 맛있어요, 평점 : 4, 날짜 : 2021.08.07.
# 리뷰코드 : YDP000073, ID : 1dao14d, 리뷰 : 분위기 좋은곳, 평점 : 5, 날짜 : 2021.06.16.
# 리뷰코드 : YDP000074, ID : 15h4ra7, 리뷰 : 분위기 좋음 근데 엄청 시끄러움 말소리 안들림 맛은 그냥저냥 ~!!!, 평점 : 5, 날짜 : 2021.06.12.
# 리뷰코드 : YDP000075, ID : 1gl5679, 리뷰 : None, 평점 : 5, 날짜 : 2021.06.08.
# ##### 2 : 동작구 맛집
# 가계명 : 전주전집, 주소 : 서울 동작구 동작대로7길 19, 지역 : (지번) 사당동 1032-1, 종류 : 한식
# #### 전주전집
# 리뷰코드 : DJ000001, ID : bepcfe, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.18.
# 리뷰코드 : DJ000002, ID : eq7jtg, 리뷰 : 포장했는데 너무 맛있어요 직원분들도 너무 친절하네요!! 전집은 무조건 여기로 가야겠어요., 평점 : 5, 날짜 : 2021.07.04.
# 리뷰코드 : DJ000003, ID : r8ca3s, 리뷰 : 전은 고만고만함 근데 장사마인드가 싸가지가 바가지네 술맛 떨어짐 진짜, 평점 : 1, 날짜 : 2021.06.22.
# 리뷰코드 : DJ000004, ID : 1attg59, 리뷰 : 양도 많고, 맛도 있고, 거격도 저렴하고, 거기다가 친절하기까지 함!! 여기 사장님이 대인배임 멋지심!!, 평점 : 5, 날짜 : 2021.06.15.
# 리뷰코드 : DJ000005, ID : nqkmnc, 리뷰 : 엄청 푸짐 양도 많고 맛도 있고, 평점 : 4, 날짜 : 2021.05.02.
# 가계명 : 서일순대국, 주소 : 서울 동작구 여의대방로24길 10-4, 지역 : (지번) 신대방동 377-1, 종류 : 순대
# #### 서일순대국
# 리뷰코드 : DJ000006, ID : l6krhs, 리뷰 : None, 평점 : 3, 날짜 : 2021.08.11.
# 리뷰코드 : DJ000007, ID : k2cdc9, 리뷰 : 뭔맛인지모루겠음...;;;, 평점 : 1, 날짜 : 2021.08.05.
# 리뷰코드 : DJ000008, ID : g86iub, 리뷰 : None, 평점 : 5, 날짜 : 2021.08.03.
# 리뷰코드 : DJ000009, ID : 7mj864, 리뷰 : 평범한맛,  계산받으시는 여자분(사장님 이신가?) 상당히 불친절. 불친절할만큼 맛집은 아님, 평점 : 1, 날짜 : 2021.07.04.
# 리뷰코드 : DJ000010, ID : ucmlv2, 리뷰 : 맛있습니다. 잡내가 없어요., 평점 : 5, 날짜 : 2021.06.28.
# 가계명 : 방배김밥, 주소 : 서울 동작구 동작대로27길 59-16, 지역 : (지번) 사당동 127-27, 종류 : 분식
# #### 방배김밥
# 리뷰코드 : DJ000011, ID : v47tfs, 리뷰 : 김밥맛은 좀 강하고  결제 시스템이나 불친절함에 기분이 안좋네요.김밥 옆구리가 자주 터져요.3개샀는데 3개다 옆구리 터져서 먹는데 너무 불편했어요.ㅠ, 평점 : 2, 날짜 : 2021.07.30.
# 리뷰코드 : DJ000012, ID : 15bm7h9, 리뷰 : 여기 왜 유명해요? 노맛 , 평점 : 1, 날짜 : 2021.07.23.
# 리뷰코드 : DJ000013, ID : ta2n1p, 리뷰 : 유명한걸로 유명한 김밥집, 평점 : 2, 날짜 : 2021.05.11.
# 리뷰코드 : DJ000014, ID : nkh3sk, 리뷰 : 코스트코인가? 신한카드만?ㅎㅎ, 평점 : 1, 날짜 : 2021.04.25.
# 리뷰코드 : DJ000015, ID : fkpebu, 리뷰 : 여기 진짜 정말 맛있다고 사먹는건가요..? 너무 짜고 하나먹고 소금 씹혀서 뱉었습니다.. 옛날이랑 맛이 변했다고 하는데 안타깝네요, 평점 : 2, 날짜 : 2021.04.21.
# 가계명 : 시간을들이다, 주소 : 서울 동작구 국사봉5길 4 1층, 지역 : (지번) 상도동 304-12, 종류 : 제과,베이커리
# #### 시간을들이다
# 리뷰코드 : DJ000016, ID : 10hd2ei, 리뷰 : 서울에서 유명한 크로와상은 다 먹어봤는데 여기 미만잡.  택배로도 여러번 시켜 먹었지만 역시 매장에서 바로 사오는 편이 가장 맛있습니다. 그런데 매장 접근성이 너무 떨어짐 ㅠㅠ....사장님 번창하셔서 역 가까이에 분점 내주세요.. 맛은 기본크로와상(논외) > 우유크림 > 초코 >>>> 나머지로 상위권 기본 맛이 진짜 맛있습니다. 홍차, 말차 계열은 취향탈 ..., 평점 : 5, 날짜 : 2021.07.23.
# 리뷰코드 : DJ000017, ID : 1a6tt7g, 리뷰 : 지도 잘못보고 제빵소로 찾아감 와우 개쪽팔려 간판이 있어도 여기가 빵집이 맞나 긴가민가 한 곳은 매장이 아닙니다,,,,, 평점 : 5, 날짜 : 2021.07.12.
# 리뷰코드 : DJ000018, ID : 1569l60, 리뷰 : 맛있음 초코가 생각보다 안달아서 더 맛있는듯, 평점 : 4, 날짜 : 2021.06.10.
# 리뷰코드 : DJ000019, ID : 10gg641, 리뷰 : 홍차크림 쓰고 미끄덩하고 좀 느끼함 친구는 짜고 맛없다그랬음, 평점 : 1, 날짜 : 2021.06.02.
# 리뷰코드 : DJ000020, ID : k6ussv, 리뷰 : 물리는 맛 그렇지만 한 번은 먹어볼맛, 평점 : 5, 날짜 : 2021.05.30.
# 가계명 : 동작노을카페, 주소 : 서울 동작구 동작대로 335 3,4층, 지역 : (지번) 동작동 316-3, 종류 : 카페
# #### 동작노을카페
# 리뷰코드 : DJ000021, ID : 7kojcc, 리뷰 : None, 평점 : 5, 날짜 : 2021.03.01.
# 리뷰코드 : DJ000022, ID : 1glvvma, 리뷰 : 불친절 테이블당 2명까지 앉을 수있으면 써놓으세요~, 평점 : 1, 날짜 : 2021.02.21.
# 리뷰코드 : DJ000023, ID : 14eqjq8, 리뷰 : None, 평점 : 5, 날짜 : 2020.09.30.
# 리뷰코드 : DJ000024, ID : 1339tgd, 리뷰 : 도라이브 겸 한번 들렀는데 야경이 나쁘지 않네요. 좋은 자리가 얼마 없긴 하지만 비싸지 않은 가격에 스무스, 평점 : 4, 날짜 : 2020.09.11.
# 리뷰코드 : DJ000025, ID : 156u65t, 리뷰 : 알바 불친절하구 청소상태별로에여 화장실도 지금은 잠겨서 이용도못하네요~, 평점 : 1, 날짜 : 2020.08.09.
# 가계명 : 스시로로, 주소 : 서울 동작구 동작대로23길 29, 지역 : (지번) 사당동 1006-5, 종류 : 초밥,롤
# #### 스시로로
# 리뷰코드 : DJ000026, ID : jsl1q6, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.05.
# 리뷰코드 : DJ000027, ID : 1dr7n5l, 리뷰 : 맛있고 제법 합리적. 전통적인 스시와는 조금 다름. 밥알 안 뭉쳐져있다고 불평하시는 분들 많은데 이런 분들은 전통적인 스시를 생각하고 방문한 듯함. 테이블에 앉으면 애초에 밥알 잘 안 뭉쳐진다 명시되어있고 먹는법 친절하게 써있음. 생선 크기도 크고 괜찮은 퀄리티의 가게. 한번쯤 가볼만한 곳!, 평점 : 5, 날짜 : 2021.06.25.
# 리뷰코드 : DJ000028, ID : 1ekv1r3, 리뷰 : 스시야를 나름 꽤 다녔다고 자처하는 데, 오마카세가 아닌 집 중에 이 정도로 고퀄리티 합리적 가격의 스시야는 없는 거 같습니다., 평점 : 5, 날짜 : 2021.06.07.
# 리뷰코드 : DJ000029, ID : e50f5u, 리뷰 : 아니 평점이 3점대인게 말이되나요? 인생초밥맛집, 평점 : 5, 날짜 : 2021.05.19.
# 리뷰코드 : DJ000030, ID : 16bjtcv, 리뷰 : 완전 안상맛집 연어짱, 평점 : 5, 날짜 : 2021.05.18.
# 가계명 : 광안리, 주소 : 서울 동작구 동작대로7길 5 1층, 지역 : (지번) 사당동 1031-37, 종류 : 해물,생선
# #### 광안리
# 리뷰코드 : DJ000031, ID : 13kfnpv, 리뷰 : None, 평점 : 4, 날짜 : 2021.08.07.
# 리뷰코드 : DJ000032, ID : o3g7tn, 리뷰 : 그냥 연어랑 육회맛인데 심히 비쌈.. 자리도 너무 빼곡빼곡해서 코로나 걸리기 좋음. , 평점 : 2, 날짜 : 2021.06.04.
# 리뷰코드 : DJ000033, ID : cvtipc, 리뷰 : 빨리 나가야 할 것 같은, 평점 : 3, 날짜 : 2021.03.22.
# 리뷰코드 : DJ000034, ID : mugono, 리뷰 : 적당히 만족스러움!, 평점 : 3, 날짜 : 2021.03.10.
# 리뷰코드 : DJ000035, ID : f69n3f, 리뷰 : 맛있지만 가격을 생각하게 된다. 코로나시국에 너무 가까운 좌석이 우려스러움. 너무 시끄러워 대화하기가 힘들다., 평점 : 4, 날짜 : 2021.02.09.
# 가계명 : 등나무집, 주소 : 서울 동작구 대림로 52, 지역 : (지번) 신대방동 687-14, 종류 : 육류,고기
# #### 등나무집
# 리뷰코드 : DJ000036, ID : 19o57ub, 리뷰 : 맛있어용 파가 미텼음 근데 가격도 미친듯 ㅎ, 평점 : 4, 날짜 : 2021.08.03.
# 리뷰코드 : DJ000037, ID : utm8cl, 리뷰 : 이집 소꼬리찜은 한국인이라면 먹어보아야 하는 메뉴다 손가락 쪽쪽빨며 맛의.신세계를 경험했다 , 평점 : 5, 날짜 : 2021.07.31.
# 리뷰코드 : DJ000038, ID : epkqrv, 리뷰 : 맛은 좋은데 가격이 많이 비싼편이네요ㅎㅎ 그래서 별하나 깝니다!, 평점 : 4, 날짜 : 2021.07.06.
# 리뷰코드 : DJ000039, ID : kpe4d8, 리뷰 : 국물이 아주 걸쭉하고 진하다. 이집은 꼬리수육이 대표메뉴지만 그걸 우려낸 곰탕도 탁월하다. 국물 2종류를 선택할 수 있다. 신대방 쪽의 오래된 터줏대감으로 아는 사람들은 다 아는 최상급 노포. , 평점 : 5, 날짜 : 2021.05.22.
# 리뷰코드 : DJ000040, ID : keibpt, 리뷰 : 가격이 너무마니 올랐음, 평점 : 1, 날짜 : 2021.04.26.
# 가계명 : 다래식당, 주소 : 서울 동작구 만양로2길 2, 지역 : (지번) 상도동 17-61, 종류 : 한식
# #### 다래식당
# 리뷰코드 : DJ000041, ID : alad84, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.18.
# 리뷰코드 : DJ000042, ID : clcf9v, 리뷰 : None, 평점 : 4, 날짜 : 2021.06.16.
# 리뷰코드 : DJ000043, ID : e4j0fu, 리뷰 : None, 평점 : 2, 날짜 : 2021.06.06.
# 리뷰코드 : DJ000044, ID : t3rp8d, 리뷰 : 어머니의 손맛이예요~~^^, 평점 : 5, 날짜 : 2021.05.22.
# 리뷰코드 : DJ000045, ID : n2erfg, 리뷰 : 청국장이 부드러워서 거부감없이 먹을 수 있는 맛집 주물럭도 가마솥에 구워서 먹을만해여 밑반찬과 쌈과 먹으면 맛있음, 평점 : 4, 날짜 : 2021.05.08.
# 가계명 : 상남스시, 주소 : 서울 동작구 여의대방로24길 64 1층, 지역 : (지번) 신대방동 361-50, 종류 : 초밥,롤
# #### 상남스시
# 리뷰코드 : DJ000046, ID : 8v2gql, 리뷰 : 이가격에 이구성.. 저만 알고 싶습니다 ㅠㅜ 예약하기 너무 힘들어졌어욧, 평점 : 5, 날짜 : 2021.06.16.
# 리뷰코드 : DJ000047, ID : 10tj0fo, 리뷰 : 이 가격에 이정도 퀄이면 미친겁니다., 평점 : 5, 날짜 : 2021.06.06.
# 리뷰코드 : DJ000048, ID : n17fic, 리뷰 : 분위기를 기대하고 가면 안되지만, 맛은 정말 있고 코스도 길어요. 특히 저 계란…. 계란 보시면 어떤 초밥집인지 고수들은 아시죠?, 평점 : 4, 날짜 : 2021.05.25.
# 리뷰코드 : DJ000049, ID : v462qs, 리뷰 : 가성비 좋고 맛도 아주좋아요, 평점 : 5, 날짜 : 2021.05.17.
# 리뷰코드 : DJ000050, ID : 12mvifk, 리뷰 : 사장님이 친절하시고 코스도 김 술없이 배가 부를정도 맛 하나하나 정성이 들어간맛집, 평점 : 5, 날짜 : 2021.05.16.
# 가계명 : 대성관, 주소 : 서울 동작구 여의대방로 204-1 1층, 지역 : (지번) 대방동 384-7, 종류 : 중화요리
# #### 대성관
# 리뷰코드 : DJ000051, ID : l6krhs, 리뷰 : None, 평점 : 5, 날짜 : 2021.08.11.
# 리뷰코드 : DJ000052, ID : 1chcmr7, 리뷰 : None, 평점 : 5, 날짜 : 2021.08.07.
# 리뷰코드 : DJ000053, ID : e4rt5d, 리뷰 : 맛은 평범하고 재료가 좋지는 않고, 문제는 청결도와 위생입니다.  아파트근처라 자주 갔었는데, 여름되니 더 심각해요. 물은 녹슨 수도물 냄새가 나고(정수기 안보임), 젓가락은 둥근통에 한꺼번에 담아서 세워져있는데, 손으로 꺼낼때 다른 것들도 만질수 밖에 없어요.  누가 손으로 만진 젓가락을 내 입에 넣는 꼴이니 이 여름에 배탈 안난게 다행..ㅎ 바퀴벌레도 ..., 평점 : 1, 날짜 : 2021.07.21.
# 리뷰코드 : DJ000054, ID : 1givqcu, 리뷰 : 알바들 댓글 많이들 올려놨네... 내나이 오십중반에 서울에서 이렇게 맛없는 중국집도 처음이다.. 삼선 볶은밥 먹었는데 기름끼 쩔어 짬뽕국물은 짜기만 하고 먹는 물은 수돗물인지 뭔지 냄새가 나고 주인장 할매는 계산에만 눈이멀어 돈만 밝히는 노인네고 정말이지 돈이 아깝다... , 평점 : 1, 날짜 : 2021.05.21.
# 리뷰코드 : DJ000055, ID : 1deig1m, 리뷰 : 영화속에 나올 법한 분위기의 노포 화상.  , 평점 : 4, 날짜 : 2021.05.12.
# 가계명 : 다독이네숯불구이, 주소 : 서울 동작구 노량진로 106-5 1층, 지역 : (지번) 노량진동 40-34, 종류 : 육류,고기
# #### 다독이네숯불구이
# 리뷰코드 : DJ000056, ID : 19v83ti, 리뷰 : 너무맛있게먹고갑니다 노량진핫플, 평점 : 5, 날짜 : 2021.08.06.
# 리뷰코드 : DJ000057, ID : v60gg4, 리뷰 : None, 평점 : 5, 날짜 : 2021.07.28.
# 리뷰코드 : DJ000058, ID : bobldv, 리뷰 : 요 근래 먹은 고기 중 최고임(몽탄보다 낫다)  단 코시국에 너무 좁고 사람 많음, 평점 : 4, 날짜 : 2021.07.26.
# 리뷰코드 : DJ000059, ID : 1lm2cu7, 리뷰 : 고기맛은 먹을만한데 줄서면서까지 먹을만 한지는 의문임.., 평점 : 4, 날짜 : 2021.07.10.
# 리뷰코드 : DJ000060, ID : eqcb2n, 리뷰 : 진짜 맛있어요! 부드럽고 육즙 좔좔 ㅠ 그리고 일하시는분들이 다들 친절해서 기분좋았어요!!, 평점 : 5, 날짜 : 2021.07.09.
# 가계명 : 조가네갑오징어 사당직영3호점, 주소 : 서울 동작구 남부순환로271길 24, 지역 : (지번) 사당동 1041-5, 종류 : 해물,생선
# #### 조가네갑오징어 사당직영3호점
# 리뷰코드 : DJ000061, ID : cdpcm9, 리뷰 : ★추가 피해자를 막기 위해 없어져야함 ★★내돈주곤 다시 안감 ★★★누가 사주면 감 맛/특징이 생각 안나는 무색무취 ★★★★재방문 의사 있음 ★★★★★맛/특징이 기억 나고 자신있게 추천 가능  종업원이 불친절하긴 한데 맛은 있어요, 평점 : 4, 날짜 : 2021.07.04.
# 리뷰코드 : DJ000062, ID : 1ftvfi2, 리뷰 : None, 평점 : 3, 날짜 : 2021.06.28.
# 리뷰코드 : DJ000063, ID : edhksv, 리뷰 : 갑오징어 전골 갠잔네, 평점 : 3, 날짜 : 2021.05.21.
# 리뷰코드 : DJ000064, ID : 1bejeji, 리뷰 : 아 대박~~~ 종업원이 별로라는 밑에 글 보고 반신반의 했는데 진짜 쌈닭이었음. 계산문제로 손님하고 다투다가 더 오버해서 난리침~~~ 와~~ 난리 난리 그렇게 응대하는 사람 처음봄 혀를 내두름 시끄러워서 죽을뻔 했음.맛은 둘째치고 그런집은 다시는 방문 안함 사장님은 종업원 관리 하셔야 할듯, 평점 : 1, 날짜 : 2021.05.20.
# 리뷰코드 : DJ000065, ID : bfe7v9, 리뷰 : 탱글탱글한게 식감은 정말 좋음, 평점 : 4, 날짜 : 2021.05.06.
# 가계명 : 카페퍼블리코 본점, 주소 : 서울 동작구 상도로 47 헬로우빌딩 1,2층, 지역 : (지번) 대방동 395-18, 종류 : 카페
# #### 카페퍼블리코 본점
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-13-eb1ecb0b2aed> in <module>
#     355 #### 메인 ####
#     356 if __name__ == "__main__":
# --> 357     main()
#
# <ipython-input-13-eb1ecb0b2aed> in main()
#      85
#      86         local = read_local_code(place)
# ---> 87         search(place, local)
#      88         create_csv_file(place)
#      89
#
# <ipython-input-13-eb1ecb0b2aed> in search(place, local)
#     117
#     118     # 검색된 첫 페이지 장소 목록 크롤링하기
# --> 119     crawling(place, local, place_lists)
#     120
#     121     # 전체 페이지
#
# <ipython-input-13-eb1ecb0b2aed> in crawling(place, local, place_lists)
#     191         sleep(1)
#     192         # 첫 페이지
# --> 193         extract_review(place_name, local) # 리뷰 추출
#     194
#     195 #         # 2-5 페이지
#
# <ipython-input-13-eb1ecb0b2aed> in extract_review(place_name, local)
#     240     ret = True
#     241
# --> 242     html = driver.page_source
#     243     soup = BeautifulSoup(html, 'html.parser')
#     244
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     761                 driver.page_source
#     762         """
# --> 763         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     764
#     765     def close(self):
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response['value'] = self._unwrap_value(
#     349                 response.get('value', None))
#
# ~\anaconda3\envs\multi\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     238                 alert_text = value['alert'].get('text')
#     239             raise exception_class(message, screen, stacktrace, alert_text)
# --> 240         raise exception_class(message, screen, stacktrace)
#     241
#     242     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=92.0.4515.131)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x010E3733+2504499]
# 	Ordinal0 [0x0107C401+2081793]
# 	Ordinal0 [0x00F824F0+1058032]
# 	Ordinal0 [0x00F77584+1013124]
# 	Ordinal0 [0x00F77D76+1015158]
# 	Ordinal0 [0x00F794D5+1021141]
# 	Ordinal0 [0x00F735F6+996854]
# 	Ordinal0 [0x00F83830+1062960]
# 	Ordinal0 [0x00FD43D2+1393618]
# 	Ordinal0 [0x00FC5D4B+1334603]
# 	Ordinal0 [0x00FA22B4+1188532]
# 	Ordinal0 [0x00FA3149+1192265]
# 	GetHandleVerifier [0x0125FB8C+1512252]
# 	GetHandleVerifier [0x0130B0DF+2214031]
# 	GetHandleVerifier [0x01164BC3+484211]
# 	GetHandleVerifier [0x01163E69+480793]
# 	Ordinal0 [0x0108218D+2105741]
# 	Ordinal0 [0x010866E8+2123496]
# 	Ordinal0 [0x01086827+2123815]
# 	Ordinal0 [0x0108FB73+2161523]
# 	BaseThreadInitThunk [0x7643FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C67A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C67A4E+238]

# %%
rating_df
# Out:
#      review_code     ItemID UserID review Rating    Timestamp
# 0       GC000001        호세가   None   None   None  2021.06.14.
# 1       GC000002        호세가   None   None   None  2021.06.04.
# 2       GC000003        호세가   None   None   None  2021.06.02.
# 3       GC000004        호세가   None   None   None  2021.05.18.
# 4       GC000005        호세가   None   None   None  2021.05.15.
# ...          ...        ...    ...    ...    ...          ...
# 3229    GC003230  용호동낙지 가산점   None   None   None  2021.01.08.
# 3230    GC003231  용호동낙지 가산점   None   None   None  2020.01.31.
# 3231    GC003232  용호동낙지 가산점   None   None   None  2018.12.16.
# 3232    GC003233  용호동낙지 가산점   None   None   None  2018.08.29.
# 3233    GC003234  용호동낙지 가산점   None   None   None  2016.12.27.
#
# [3234 rows x 6 columns]
